# %% [markdown]
# # Neurips, s2d1, raw proteins

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
import umap

from ridgeplot import ridgeplot

import warnings

warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %%
#raw protein data, all datasets

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/healthy_malig_!m.h5ad')

# %%
adata_neurips=adata[adata.obs['SAMPLE_SET'] == 'N' ]

adata_neurips
# Out:
# View of AnnData object with n_obs × n_vars = 80998 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_neurips.obs['POOL'].unique().tolist()
# Out:
# ['s4d1',
#  's3d6',
#  's1d2',
#  's2d1',
#  's3d7',
#  's2d4',
#  's1d1',
#  's4d9',
#  's4d8',
#  's2d5',
#  's3d1',
#  's1d3']

# %%
adata_neurips.obs['cell_type'].unique().tolist()
# Out:
# ['NK',
#  'CD8+ T CD69+ CD45RA+',
#  'NK CD158e1+',
#  'HSC',
#  'CD14+ Mono',
#  'B1 B IGKC+',
#  'CD4+ T activated',
#  'CD8+ T CD69+ CD45RO+',
#  'G/M prog',
#  'Naive CD20+ B IGKC-',
#  'CD8+ T CD49f+',
#  'Naive CD20+ B IGKC+',
#  'CD4+ T naive',
#  'CD8+ T naive',
#  'CD4+ T activated integrinB7+',
#  'cDC2',
#  'gdT TCRVD2+',
#  'CD8+ T TIGIT+ CD45RO+',
#  'CD16+ Mono',
#  'Erythroblast',
#  'MAIT',
#  'T reg',
#  'gdT CD158b+',
#  'Transitional B',
#  'Proerythroblast',
#  'CD8+ T CD57+ CD45RO+',
#  'Plasmablast IGKC+',
#  'ILC1',
#  'Lymph prog',
#  'ILC',
#  'MK/E prog',
#  'Normoblast',
#  'CD8+ T CD57+ CD45RA+',
#  'pDC',
#  'B1 B IGKC-',
#  'Plasma cell IGKC-',
#  'Plasmablast IGKC-',
#  'Plasma cell IGKC+',
#  'CD8+ T TIGIT+ CD45RA+',
#  'CD8+ T naive CD127+ CD26- CD101-',
#  'CD4+ T CD314+ CD45RA+',
#  'cDC1',
#  'T prog cycling',
#  'dnT']

# %%
#select sample from Neurips dataset

adata_sample=adata_neurips[adata_neurips.obs['POOL'] == 's2d1']

# %%
adata_sample.copy()
# Out:
# AnnData object with n_obs × n_vars = 9684 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs['cell_type'].unique().tolist()
# Out:
# ['Naive CD20+ B IGKC+',
#  'CD14+ Mono',
#  'CD16+ Mono',
#  'Naive CD20+ B IGKC-',
#  'CD4+ T naive',
#  'T reg',
#  'Erythroblast',
#  'CD8+ T naive',
#  'CD4+ T activated',
#  'NK',
#  'CD8+ T CD69+ CD45RO+',
#  'CD8+ T TIGIT+ CD45RO+',
#  'B1 B IGKC-',
#  'CD8+ T CD57+ CD45RA+',
#  'CD8+ T CD69+ CD45RA+',
#  'cDC2',
#  'Plasma cell IGKC-',
#  'pDC',
#  'CD4+ T activated integrinB7+',
#  'B1 B IGKC+',
#  'Lymph prog',
#  'NK CD158e1+',
#  'MK/E prog',
#  'HSC',
#  'ILC1',
#  'Transitional B',
#  'CD8+ T CD57+ CD45RO+',
#  'Plasma cell IGKC+',
#  'CD8+ T CD49f+',
#  'Proerythroblast',
#  'MAIT',
#  'Plasmablast IGKC-',
#  'Plasmablast IGKC+',
#  'ILC',
#  'G/M prog',
#  'gdT TCRVD2+',
#  'Normoblast']

# %%
adata_sample.obs['POOL'].unique().tolist()
# Out:
# ['s2d1']

# %%
#Select only NK-cells (based on new_cell_type annotations)

adata_nk=adata_sample[adata_sample.obs['new_cell_type'] == 'NK' ]

# %%
adata_nk.copy()
# Out:
# AnnData object with n_obs × n_vars = 529 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
#Two types of NK cells annotated by Seurat

adata_nk.obs['cell_type']
# Out:
# TCACTATCATCTTCGC-1-s2d1             NK
# CACGGGTAGGACACTG-1-s2d1             NK
# AGAGCCCCAACTCCCT-1-s2d1             NK
# TTTACGTTCATGGCCG-1-s2d1             NK
# AAGCCATTCATCGCTC-1-s2d1    NK CD158e1+
#                               ...
# TGGTGATTCACCATAG-1-s2d1             NK
# CACCAAAAGACACACG-1-s2d1    NK CD158e1+
# ATGGAGGGTGCGCTCA-1-s2d1    NK CD158e1+
# GCACGGTGTACCCGCA-1-s2d1    NK CD158e1+
# AGATGAAAGTATGAGT-1-s2d1             NK
# Name: cell_type, Length: 529, dtype: category
# Categories (2, object): ['NK', 'NK CD158e1+']

# %%
#surface protein expression of NK-cells
nk_prot=adata_nk.obsm['protein_expression']

# %%
#surface protein expression whole sample
prot=adata_sample.obsm['protein_expression']

# %%
#NK cells in sample
nk_prot.shape
# Out:
# (529, 141)

# %%
#All cells in sample

prot.shape
# Out:
# (9684, 141)

# %%
#sorting by mean, all cell types

index_sort = prot.mean().sort_values().index
df_sorted_all = prot[index_sort]

# %%
#sorting by mean, NK cells

index_sort = nk_prot.mean().sort_values().index
df_sorted_nk = nk_prot[index_sort]

# %%
#All cell types

cells= len(prot)

print("In total:", cells, " cells in the sample" )

#From 100 to 134
plt.figure(figsize=(30,10))
plt.ylim(0, 800)
a=sns.boxplot(data=df_sorted_all.iloc[0:26775,100:134],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types 100-134", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

#From 70 to 100

plt.figure(figsize=(30,10))
plt.ylim(0, 800)
b=sns.boxplot(data=df_sorted_all.iloc[0:26775,70:100],  fliersize=0)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)
plt.title("All cell types 70-100", fontsize=30)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)

#From 30 to 70
plt.figure(figsize=(30,10))
plt.ylim(0, 800)
c=sns.boxplot(data=df_sorted_all.iloc[0:26775,30:70],  fliersize=0)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)
plt.title("All cell types 30-70", fontsize=30)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)

#From 0 to 30
plt.figure(figsize=(30,10))
plt.ylim(0, 800)
d=sns.boxplot(data=df_sorted_all.iloc[0:26775,0:30],  fliersize=0)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
plt.title("All cell types 0-30", fontsize=30)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
# Out:
# In total: 9684  cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK-cells in the sample" )

#From 100 to 134
plt.figure(figsize=(30,10))
plt.ylim(0, 400)
a=sns.boxplot(data=df_sorted_all.iloc[0:26775,100:134],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK cells 100-134", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

#From 70 to 100

plt.figure(figsize=(30,10))
plt.ylim(0, 400)
b=sns.boxplot(data=df_sorted_all.iloc[0:26775,70:100],  fliersize=0)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)
plt.title("NK cells 70-100", fontsize=30)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)

#From 30 to 70
plt.figure(figsize=(30,10))
plt.ylim(0, 400)
c=sns.boxplot(data=df_sorted_all.iloc[0:26775,30:70],  fliersize=0)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)
plt.title("NK cells 30-70", fontsize=30)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)

#From 0 to 30
plt.figure(figsize=(30,10))
plt.ylim(0, 400)
d=sns.boxplot(data=df_sorted_all.iloc[0:26775,0:30],  fliersize=0)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
plt.title("NK cells 0-30", fontsize=30)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
# Out:
# In total: 529 NK-cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK-cells in the sample" )

#From 100 to 134
plt.figure(figsize=(40,20))
plt.ylim(0, 500)
a=sns.violinplot(data=df_sorted_all.iloc[0:26775,100:134],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK cells 100-134", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

#From 70 to 100

plt.figure(figsize=(40,20))
plt.ylim(0, 500)
b=sns.violinplot(data=df_sorted_all.iloc[0:26775,70:100],  fliersize=0)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)
plt.title("NK cells 70-100", fontsize=30)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)

#From 30 to 70
plt.figure(figsize=(40,20))
plt.ylim(0, 500)
c=sns.violinplot(data=df_sorted_all.iloc[0:26775,30:70],  fliersize=0)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)
plt.title("NK cells 30-70", fontsize=30)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)

#From 0 to 30
plt.figure(figsize=(40,20))
plt.ylim(0, 500)
d=sns.violinplot(data=df_sorted_all.iloc[0:26775,0:30],  fliersize=0)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
plt.title("NK cells 0-30", fontsize=30)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
# Out:
# In total: 529 NK-cells in the sample

# %%
#To exclude columns that contain only zeros, all cell types included

prot = pd.DataFrame(prot)
prot != 0
(prot != 0).any(axis=0)
prot.loc[:, (prot != 0).any(axis=0)]
prot = prot.loc[:, (prot != 0).any(axis=0)]

for col in prot:
    print(col)
# Out:
# CD86
# CD274
# CD270
# CD155
# CD112
# CD47
# CD48
# CD40
# CD154
# CD52
# CD3
# CD8
# CD56
# CD19
# CD33
# CD11c
# HLA-A-B-C
# CD45RA
# CD123
# CD7
# CD105
# CD49f
# CD194
# CD4
# CD44
# CD14
# CD16
# CD25
# CD45RO
# CD279
# TIGIT
# CD20
# CD335
# CD31
# Podoplanin
# CD146
# IgM
# CD5
# CD195
# CD32
# CD196
# CD185
# CD103
# CD69
# CD62L
# CD161
# CD152
# CD223
# KLRG1
# CD27
# CD107a
# CD95
# CD134
# HLA-DR
# CD1c
# CD11b
# CD64
# CD141
# CD1d
# CD314
# CD35
# CD57
# CD272
# CD278
# CD58
# CD39
# CX3CR1
# CD24
# CD21
# CD11a
# CD79b
# CD244
# CD169
# integrinB7
# CD268
# CD42b
# CD54
# CD62P
# CD119
# TCR
# CD192
# CD122
# FceRIa
# CD41
# CD137
# CD163
# CD83
# CD124
# CD13
# CD2
# CD226
# CD29
# CD303
# CD49b
# CD81
# IgD
# CD18
# CD28
# CD38
# CD127
# CD45
# CD22
# CD71
# CD26
# CD115
# CD63
# CD304
# CD36
# CD172a
# CD72
# CD158
# CD93
# CD49a
# CD49d
# CD73
# CD9
# TCRVa7.2
# TCRVd2
# LOX-1
# CD158b
# CD158e1
# CD142
# CD319
# CD352
# CD94
# CD162
# CD85j
# CD23
# CD328
# HLA-E
# CD82
# CD101
# CD88
# CD224

# %%
#To exclude columns that contain only zeros from NK-only file

nk_prot = pd.DataFrame(nk_prot)
nk_prot != 0
(nk_prot != 0).any(axis=0)
nk_prot.loc[:, (nk_prot != 0).any(axis=0)]
nk_prot = nk_prot.loc[:, (nk_prot != 0).any(axis=0)]

for col in nk_prot:
    print(col)
# Out:
# CD86
# CD274
# CD270
# CD155
# CD112
# CD47
# CD48
# CD40
# CD154
# CD52
# CD3
# CD8
# CD56
# CD19
# CD33
# CD11c
# HLA-A-B-C
# CD45RA
# CD123
# CD7
# CD105
# CD49f
# CD194
# CD4
# CD44
# CD14
# CD16
# CD25
# CD45RO
# CD279
# TIGIT
# CD20
# CD335
# CD31
# Podoplanin
# CD146
# IgM
# CD5
# CD195
# CD32
# CD196
# CD185
# CD103
# CD69
# CD62L
# CD161
# CD152
# CD223
# KLRG1
# CD27
# CD107a
# CD95
# CD134
# HLA-DR
# CD1c
# CD11b
# CD64
# CD141
# CD1d
# CD314
# CD35
# CD57
# CD272
# CD278
# CD58
# CD39
# CX3CR1
# CD24
# CD21
# CD11a
# CD79b
# CD244
# CD169
# integrinB7
# CD268
# CD42b
# CD54
# CD62P
# CD119
# TCR
# CD192
# CD122
# FceRIa
# CD41
# CD137
# CD163
# CD83
# CD124
# CD13
# CD2
# CD226
# CD29
# CD303
# CD49b
# CD81
# IgD
# CD18
# CD28
# CD38
# CD127
# CD45
# CD22
# CD71
# CD26
# CD115
# CD63
# CD304
# CD36
# CD172a
# CD72
# CD158
# CD93
# CD49a
# CD49d
# CD73
# CD9
# TCRVa7.2
# TCRVd2
# LOX-1
# CD158b
# CD158e1
# CD142
# CD319
# CD352
# CD94
# CD162
# CD85j
# CD23
# CD328
# HLA-E
# CD82
# CD101
# CD88
# CD224

# %%
#All cells
matrix1=prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix1, figsize=(20,20))
plt.title('All cell types', fontsize = 50) ;

# %%
#NK cells
matrix3=nk_prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix3, figsize=(20,20))
plt.title('NK-cells', fontsize = 50) ;

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_sample.obs
b = prot

neurips_umap=pd.concat([a, b], axis=1)

adata_sample.obs=neurips_umap
adata_sample
# Out:
# AnnData object with n_obs × n_vars = 9684 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD86', 'CD274', 'CD270', 'CD155', 'CD112', 'CD47', 'CD48', 'CD40', 'CD154', 'CD52', 'CD3', 'CD8', 'CD56', 'CD19', 'CD33', 'CD11c', 'HLA-A-B-C', 'CD45RA', 'CD123', 'CD7', 'CD105', 'CD49f', 'CD194', 'CD4', 'CD44', 'CD14', 'CD16', 'CD25', 'CD45RO', 'CD279', 'TIGIT', 'CD20', 'CD335', 'CD31', 'Podoplanin', 'CD146', 'IgM', 'CD5', 'CD195', 'CD32', 'CD196', 'CD185', 'CD103', 'CD69', 'CD62L', 'CD161', 'CD152', 'CD223', 'KLRG1', 'CD27', 'CD107a', 'CD95', 'CD134', 'HLA-DR', 'CD1c', 'CD11b', 'CD64', 'CD141', 'CD1d', 'CD314', 'CD35', 'CD57', 'CD272', 'CD278', 'CD58', 'CD39', 'CX3CR1', 'CD24', 'CD21', 'CD11a', 'CD79b', 'CD244', 'CD169', 'integrinB7', 'CD268', 'CD42b', 'CD54', 'CD62P', 'CD119', 'TCR', 'CD192', 'CD122', 'FceRIa', 'CD41', 'CD137', 'CD163', 'CD83', 'CD124', 'CD13', 'CD2', 'CD226', 'CD29', 'CD303', 'CD49b', 'CD81', 'IgD', 'CD18', 'CD28', 'CD38', 'CD127', 'CD45', 'CD22', 'CD71', 'CD26', 'CD115', 'CD63', 'CD304', 'CD36', 'CD172a', 'CD72', 'CD158', 'CD93', 'CD49a', 'CD49d', 'CD73', 'CD9', 'TCRVa7.2', 'TCRVd2', 'LOX-1', 'CD158b', 'CD158e1', 'CD142', 'CD319', 'CD352', 'CD94', 'CD162', 'CD85j', 'CD23', 'CD328', 'HLA-E', 'CD82', 'CD101', 'CD88', 'CD224'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs
# Out:
#                                    cell_type  n_genes  percent_mito  \
# CTACATTTCGCAGATT-1-s2d1  Naive CD20+ B IGKC+      663      0.083374
# ACGTACAAGTAGAATC-1-s2d1           CD14+ Mono     1677      0.107663
# TGGGAAGAGTCTGCGC-1-s2d1           CD16+ Mono     1488      0.073832
# ATCCGTCAGCAGTCTT-1-s2d1  Naive CD20+ B IGKC-      850      0.099423
# GGGACAATCCACTGAA-1-s2d1         CD4+ T naive      917      0.050502
# ...                                      ...      ...           ...
# TCATTCAGTCACCGAC-1-s2d1         Erythroblast     1742      0.030420
# GGAGAACAGCCAAGCA-1-s2d1           CD14+ Mono     1631      0.080668
# TGCGACGGTAGAATGT-1-s2d1         CD4+ T naive      840      0.057111
# TCCTGCAGTCATGACT-1-s2d1         CD4+ T naive      974      0.064919
# CCACGAGTCATCTATC-1-s2d1           CD14+ Mono     2403      0.076255
#
#                          percent_ribo     n_counts leiden_r2  \
# CTACATTTCGCAGATT-1-s2d1      0.456617  4209.473633         6
# ACGTACAAGTAGAATC-1-s2d1      0.180711  2900.865723         1
# TGGGAAGAGTCTGCGC-1-s2d1      0.179128  2804.285400        12
# ATCCGTCAGCAGTCTT-1-s2d1      0.386152  4335.795410         9
# GGGACAATCCACTGAA-1-s2d1      0.488896  5033.294922         0
# ...                               ...          ...       ...
# TCATTCAGTCACCGAC-1-s2d1      0.075154  8341.214844        13
# GGAGAACAGCCAAGCA-1-s2d1      0.191238  3341.931641         3
# TGCGACGGTAGAATGT-1-s2d1      0.468085  4517.503906         0
# TCCTGCAGTCATGACT-1-s2d1      0.450999  4723.080078         0
# CCACGAGTCATCTATC-1-s2d1      0.189901  2755.661377         4
#
#                          leiden_r2_n_genes_MAD_diff  \
# CTACATTTCGCAGATT-1-s2d1                    0.677419
# ACGTACAAGTAGAATC-1-s2d1                    1.077551
# TGGGAAGAGTCTGCGC-1-s2d1                    0.525843
# ATCCGTCAGCAGTCTT-1-s2d1                    1.627660
# GGGACAATCCACTGAA-1-s2d1                    1.509259
# ...                                             ...
# TCATTCAGTCACCGAC-1-s2d1                    0.330206
# GGAGAACAGCCAAGCA-1-s2d1                    1.129870
# TGCGACGGTAGAATGT-1-s2d1                    0.796296
# TCCTGCAGTCATGACT-1-s2d1                    2.037037
# CCACGAGTCATCTATC-1-s2d1                    3.856250
#
#                          leiden_r2_n_counts_MAD_diff  \
# CTACATTTCGCAGATT-1-s2d1                     0.479130
# ACGTACAAGTAGAATC-1-s2d1                     0.815778
# TGGGAAGAGTCTGCGC-1-s2d1                     1.388936
# ATCCGTCAGCAGTCTT-1-s2d1                     0.058492
# GGGACAATCCACTGAA-1-s2d1                     0.213455
# ...                                              ...
# TCATTCAGTCACCGAC-1-s2d1                     0.194356
# GGAGAACAGCCAAGCA-1-s2d1                     3.331093
# TGCGACGGTAGAATGT-1-s2d1                     1.554901
# TCCTGCAGTCATGACT-1-s2d1                     1.020248
# CCACGAGTCATCTATC-1-s2d1                     1.599554
#
#                          leiden_r2_percent_mito_MAD_diff filter  ... CD94  \
# CTACATTTCGCAGATT-1-s2d1                         0.773204  False  ...    3
# ACGTACAAGTAGAATC-1-s2d1                         1.299746  False  ...    2
# TGGGAAGAGTCTGCGC-1-s2d1                         1.257821  False  ...    3
# ATCCGTCAGCAGTCTT-1-s2d1                         0.509865  False  ...    3
# GGGACAATCCACTGAA-1-s2d1                         1.130319  False  ...    1
# ...                                                  ...    ...  ...  ...
# TCATTCAGTCACCGAC-1-s2d1                         0.021573  False  ...    3
# GGAGAACAGCCAAGCA-1-s2d1                         0.417479  False  ...    4
# TGCGACGGTAGAATGT-1-s2d1                         0.642251  False  ...    2
# TCCTGCAGTCATGACT-1-s2d1                         0.065628  False  ...    1
# CCACGAGTCATCTATC-1-s2d1                         0.942818  False  ...    0
#
#                         CD162 CD85j CD23 CD328 HLA-E CD82 CD101 CD88 CD224
# CTACATTTCGCAGATT-1-s2d1     1     0    2     0     1    7     0    2     1
# ACGTACAAGTAGAATC-1-s2d1    21     3    1    14     2    5    12    4     5
# TGGGAAGAGTCTGCGC-1-s2d1    98     8    5     5     7    2    32   14     9
# ATCCGTCAGCAGTCTT-1-s2d1     2     2    5     0     1    2     1    2     0
# GGGACAATCCACTGAA-1-s2d1     9     1    0     0     2   14     3    0     1
# ...                       ...   ...  ...   ...   ...  ...   ...  ...   ...
# TCATTCAGTCACCGAC-1-s2d1     0     4    8     1     7   28     1   50     0
# GGAGAACAGCCAAGCA-1-s2d1    24     6    7    16     7    5    28    4     9
# TGCGACGGTAGAATGT-1-s2d1    13     1    1     0     3    8     3    2     3
# TCCTGCAGTCATGACT-1-s2d1     9     3    9     0     0    2     2    4     1
# CCACGAGTCATCTATC-1-s2d1    31     0    4     2     4    7     4    2     9
#
# [9684 rows x 157 columns]

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_nk.obs
b = nk_prot

adata_nk_umap=pd.concat([a, b], axis=1)

adata_nk.obs=adata_nk_umap

adata_nk
# Out:
# AnnData object with n_obs × n_vars = 529 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD86', 'CD274', 'CD270', 'CD155', 'CD112', 'CD47', 'CD48', 'CD40', 'CD154', 'CD52', 'CD3', 'CD8', 'CD56', 'CD19', 'CD33', 'CD11c', 'HLA-A-B-C', 'CD45RA', 'CD123', 'CD7', 'CD105', 'CD49f', 'CD194', 'CD4', 'CD44', 'CD14', 'CD16', 'CD25', 'CD45RO', 'CD279', 'TIGIT', 'CD20', 'CD335', 'CD31', 'Podoplanin', 'CD146', 'IgM', 'CD5', 'CD195', 'CD32', 'CD196', 'CD185', 'CD103', 'CD69', 'CD62L', 'CD161', 'CD152', 'CD223', 'KLRG1', 'CD27', 'CD107a', 'CD95', 'CD134', 'HLA-DR', 'CD1c', 'CD11b', 'CD64', 'CD141', 'CD1d', 'CD314', 'CD35', 'CD57', 'CD272', 'CD278', 'CD58', 'CD39', 'CX3CR1', 'CD24', 'CD21', 'CD11a', 'CD79b', 'CD244', 'CD169', 'integrinB7', 'CD268', 'CD42b', 'CD54', 'CD62P', 'CD119', 'TCR', 'CD192', 'CD122', 'FceRIa', 'CD41', 'CD137', 'CD163', 'CD83', 'CD124', 'CD13', 'CD2', 'CD226', 'CD29', 'CD303', 'CD49b', 'CD81', 'IgD', 'CD18', 'CD28', 'CD38', 'CD127', 'CD45', 'CD22', 'CD71', 'CD26', 'CD115', 'CD63', 'CD304', 'CD36', 'CD172a', 'CD72', 'CD158', 'CD93', 'CD49a', 'CD49d', 'CD73', 'CD9', 'TCRVa7.2', 'TCRVd2', 'LOX-1', 'CD158b', 'CD158e1', 'CD142', 'CD319', 'CD352', 'CD94', 'CD162', 'CD85j', 'CD23', 'CD328', 'HLA-E', 'CD82', 'CD101', 'CD88', 'CD224'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs["CD56"]
# Out:
# TCACTATCATCTTCGC-1-s2d1    91
# CACGGGTAGGACACTG-1-s2d1    11
# AGAGCCCCAACTCCCT-1-s2d1    18
# TTTACGTTCATGGCCG-1-s2d1     2
# AAGCCATTCATCGCTC-1-s2d1     9
#                            ..
# TGGTGATTCACCATAG-1-s2d1     1
# CACCAAAAGACACACG-1-s2d1    16
# ATGGAGGGTGCGCTCA-1-s2d1     8
# GCACGGTGTACCCGCA-1-s2d1    14
# AGATGAAAGTATGAGT-1-s2d1     6
# Name: CD56, Length: 529, dtype: int64

# %%
#NK-cell markers

markers=["CD56", "CD16"]

# %%
#All cell types
sc.pl.umap(adata_sample, color= "cell_type", color_map= 'viridis')

# %%
#NK-cells

sc.pl.umap(adata_nk, color = "cell_type", color_map = 'viridis')

# %%
#All cell types

sc.pl.umap(adata_sample, color= markers, color_map= 'viridis')

# %%
#NK-cells

sc.pl.umap(adata_nk, color = markers, color_map = 'viridis')

# %%
#NK-cells

for column_name in markers:
    fig, ax =plt.subplots(1,2 ,tight_layout=True, figsize=(15, 5), sharex=True)
    fig.show()

    ax1 = sns.kdeplot(data=prot, x=column_name, multiple="stack", ax=ax[0]) ;
    ax2 = sns.kdeplot(data=nk_prot, x=column_name, color = "g", multiple="stack", ax=ax[1]) ;


    ax1.title.set_text('All cell types')    
    ax2.title.set_text('NK-cells')
    
    plt.show()

# %%
#NK markers

plt.figure(figsize=(20,10))
a=sns.violinplot(data=nk_prot[markers],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK-cell markers", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

# %% [markdown]
# # Neurips, s2d5, raw proteins

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
import umap

from ridgeplot import ridgeplot

import warnings

warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %%
#raw protein data, all datasets

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/healthy_malig_!m.h5ad')

# %%
adata_neurips=adata[adata.obs['SAMPLE_SET'] == 'N' ]

adata_neurips
# Out:
# View of AnnData object with n_obs × n_vars = 80998 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_neurips.obs['POOL'].unique().tolist()
# Out:
# ['s4d1',
#  's3d6',
#  's1d2',
#  's2d1',
#  's3d7',
#  's2d4',
#  's1d1',
#  's4d9',
#  's4d8',
#  's2d5',
#  's3d1',
#  's1d3']

# %%
adata_neurips.obs['cell_type'].unique().tolist()
# Out:
# ['NK',
#  'CD8+ T CD69+ CD45RA+',
#  'NK CD158e1+',
#  'HSC',
#  'CD14+ Mono',
#  'B1 B IGKC+',
#  'CD4+ T activated',
#  'CD8+ T CD69+ CD45RO+',
#  'G/M prog',
#  'Naive CD20+ B IGKC-',
#  'CD8+ T CD49f+',
#  'Naive CD20+ B IGKC+',
#  'CD4+ T naive',
#  'CD8+ T naive',
#  'CD4+ T activated integrinB7+',
#  'cDC2',
#  'gdT TCRVD2+',
#  'CD8+ T TIGIT+ CD45RO+',
#  'CD16+ Mono',
#  'Erythroblast',
#  'MAIT',
#  'T reg',
#  'gdT CD158b+',
#  'Transitional B',
#  'Proerythroblast',
#  'CD8+ T CD57+ CD45RO+',
#  'Plasmablast IGKC+',
#  'ILC1',
#  'Lymph prog',
#  'ILC',
#  'MK/E prog',
#  'Normoblast',
#  'CD8+ T CD57+ CD45RA+',
#  'pDC',
#  'B1 B IGKC-',
#  'Plasma cell IGKC-',
#  'Plasmablast IGKC-',
#  'Plasma cell IGKC+',
#  'CD8+ T TIGIT+ CD45RA+',
#  'CD8+ T naive CD127+ CD26- CD101-',
#  'CD4+ T CD314+ CD45RA+',
#  'cDC1',
#  'T prog cycling',
#  'dnT']

# %%
#select sample from Neurips dataset

adata_sample=adata_neurips[adata_neurips.obs['POOL'] == 's2d5']

# %%
adata_sample.copy()
# Out:
# AnnData object with n_obs × n_vars = 8725 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs['cell_type'].unique().tolist()
# Out:
# ['CD8+ T CD49f+',
#  'NK',
#  'CD4+ T naive',
#  'CD14+ Mono',
#  'CD8+ T TIGIT+ CD45RA+',
#  'CD4+ T activated integrinB7+',
#  'NK CD158e1+',
#  'CD8+ T TIGIT+ CD45RO+',
#  'CD16+ Mono',
#  'CD4+ T activated',
#  'cDC2',
#  'Plasmablast IGKC+',
#  'Erythroblast',
#  'Naive CD20+ B IGKC+',
#  'B1 B IGKC+',
#  'B1 B IGKC-',
#  'CD8+ T CD57+ CD45RA+',
#  'CD8+ T naive',
#  'pDC',
#  'CD8+ T CD57+ CD45RO+',
#  'ILC1',
#  'HSC',
#  'Naive CD20+ B IGKC-',
#  'MAIT',
#  'Transitional B',
#  'Plasma cell IGKC+',
#  'MK/E prog',
#  'Plasmablast IGKC-',
#  'G/M prog',
#  'Plasma cell IGKC-',
#  'Normoblast',
#  'Lymph prog',
#  'ILC']

# %%
adata_sample.obs['POOL'].unique().tolist()
# Out:
# ['s2d5']

# %%
#Select only NK-cells (based on new_cell_type annotations)

adata_nk=adata_sample[adata_sample.obs['new_cell_type'] == 'NK' ]

# %%
adata_nk.copy()
# Out:
# AnnData object with n_obs × n_vars = 1814 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
#Two types of NK cells annotated by Seurat

adata_nk.obs['cell_type']
# Out:
# TGTAGACGTAAGCTCT-1-s2d5             NK
# ACTTCGCCAATACAGA-1-s2d5             NK
# GCACTAACACCAGTAT-1-s2d5             NK
# CGAAGTTCACCCAATA-1-s2d5             NK
# GGGTAGATCTCGACGG-1-s2d5             NK
#                               ...
# GAGACTTTCGCCGAGT-1-s2d5    NK CD158e1+
# GCAGCCATCCATAGAC-1-s2d5    NK CD158e1+
# ATCGTGACAACGTAAA-1-s2d5             NK
# TCCGGGAGTTGGGTTT-1-s2d5             NK
# TTGGATGAGGTGCCAA-1-s2d5    NK CD158e1+
# Name: cell_type, Length: 1814, dtype: category
# Categories (2, object): ['NK', 'NK CD158e1+']

# %%
#surface protein expression of NK-cells
nk_prot=adata_nk.obsm['protein_expression']

# %%
#surface protein expression whole sample
prot=adata_sample.obsm['protein_expression']

# %%
#NK cells in sample
nk_prot.shape
# Out:
# (1814, 141)

# %%
#All cells in sample

prot.shape
# Out:
# (8725, 141)

# %%
#sorting by mean, all cell types

index_sort = prot.mean().sort_values().index
df_sorted_all = prot[index_sort]

# %%
#sorting by mean, NK cells

index_sort = nk_prot.mean().sort_values().index
df_sorted_nk = nk_prot[index_sort]

# %%
#All cell types

cells= len(prot)

print("In total:", cells, " cells in the sample" )

#From 100 to 134
plt.figure(figsize=(30,10))
plt.ylim(0, 800)
a=sns.boxplot(data=df_sorted_all.iloc[0:26775,100:134],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types 100-134", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

#From 70 to 100

plt.figure(figsize=(30,10))
plt.ylim(0, 800)
b=sns.boxplot(data=df_sorted_all.iloc[0:26775,70:100],  fliersize=0)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)
plt.title("All cell types 70-100", fontsize=30)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)

#From 30 to 70
plt.figure(figsize=(30,10))
plt.ylim(0, 800)
c=sns.boxplot(data=df_sorted_all.iloc[0:26775,30:70],  fliersize=0)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)
plt.title("All cell types 30-70", fontsize=30)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)

#From 0 to 30
plt.figure(figsize=(30,10))
plt.ylim(0, 800)
d=sns.boxplot(data=df_sorted_all.iloc[0:26775,0:30],  fliersize=0)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
plt.title("All cell types 0-30", fontsize=30)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
# Out:
# In total: 8725  cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK-cells in the sample" )

#From 100 to 134
plt.figure(figsize=(30,10))
plt.ylim(0, 1000)
a=sns.boxplot(data=df_sorted_all.iloc[0:26775,100:134],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK cells 100-134", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

#From 70 to 100

plt.figure(figsize=(30,10))
plt.ylim(0, 400)
b=sns.boxplot(data=df_sorted_all.iloc[0:26775,70:100],  fliersize=0)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)
plt.title("NK cells 70-100", fontsize=30)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)

#From 30 to 70
plt.figure(figsize=(30,10))
plt.ylim(0, 400)
c=sns.boxplot(data=df_sorted_all.iloc[0:26775,30:70],  fliersize=0)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)
plt.title("NK cells 30-70", fontsize=30)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)

#From 0 to 30
plt.figure(figsize=(30,10))
plt.ylim(0, 400)
d=sns.boxplot(data=df_sorted_all.iloc[0:26775,0:30],  fliersize=0)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
plt.title("NK cells 0-30", fontsize=30)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
# Out:
# In total: 1814 NK-cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK-cells in the sample" )

#From 100 to 134
plt.figure(figsize=(40,20))
plt.ylim(0, 1000)
a=sns.violinplot(data=df_sorted_all.iloc[0:26775,100:134],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK cells 100-134", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

#From 70 to 100

plt.figure(figsize=(40,20))
plt.ylim(0, 500)
b=sns.violinplot(data=df_sorted_all.iloc[0:26775,70:100],  fliersize=0)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)
plt.title("NK cells 70-100", fontsize=30)

b.set_xticklabels(b.get_xticklabels(),rotation=45) 
b.tick_params(axis='x', labelsize=20)

#From 30 to 70
plt.figure(figsize=(40,20))
plt.ylim(0, 500)
c=sns.violinplot(data=df_sorted_all.iloc[0:26775,30:70],  fliersize=0)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)
plt.title("NK cells 30-70", fontsize=30)

c.set_xticklabels(c.get_xticklabels(),rotation=45) 
c.tick_params(axis='x', labelsize=20)

#From 0 to 30
plt.figure(figsize=(40,20))
plt.ylim(0, 500)
d=sns.violinplot(data=df_sorted_all.iloc[0:26775,0:30],  fliersize=0)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
plt.title("NK cells 0-30", fontsize=30)

d.set_xticklabels(d.get_xticklabels(),rotation=45) 
d.tick_params(axis='x', labelsize=20)
# Out:
# In total: 1814 NK-cells in the sample

# %%
#To exclude columns that contain only zeros, all cell types included

prot = pd.DataFrame(prot)
prot != 0
(prot != 0).any(axis=0)
prot.loc[:, (prot != 0).any(axis=0)]
prot = prot.loc[:, (prot != 0).any(axis=0)]

for col in prot:
    print(col)
# Out:
# CD86
# CD274
# CD270
# CD155
# CD112
# CD47
# CD48
# CD40
# CD154
# CD52
# CD3
# CD8
# CD56
# CD19
# CD33
# CD11c
# HLA-A-B-C
# CD45RA
# CD123
# CD7
# CD105
# CD49f
# CD194
# CD4
# CD44
# CD14
# CD16
# CD25
# CD45RO
# CD279
# TIGIT
# CD20
# CD335
# CD31
# Podoplanin
# CD146
# IgM
# CD5
# CD195
# CD32
# CD196
# CD185
# CD103
# CD69
# CD62L
# CD161
# CD152
# CD223
# KLRG1
# CD27
# CD107a
# CD95
# CD134
# HLA-DR
# CD1c
# CD11b
# CD64
# CD141
# CD1d
# CD314
# CD35
# CD57
# CD272
# CD278
# CD58
# CD39
# CX3CR1
# CD24
# CD21
# CD11a
# CD79b
# CD244
# CD169
# integrinB7
# CD268
# CD42b
# CD54
# CD62P
# CD119
# TCR
# CD192
# CD122
# FceRIa
# CD41
# CD137
# CD163
# CD83
# CD124
# CD13
# CD2
# CD226
# CD29
# CD303
# CD49b
# CD81
# IgD
# CD18
# CD28
# CD38
# CD127
# CD45
# CD22
# CD71
# CD26
# CD115
# CD63
# CD304
# CD36
# CD172a
# CD72
# CD158
# CD93
# CD49a
# CD49d
# CD73
# CD9
# TCRVa7.2
# TCRVd2
# LOX-1
# CD158b
# CD158e1
# CD142
# CD319
# CD352
# CD94
# CD162
# CD85j
# CD23
# CD328
# HLA-E
# CD82
# CD101
# CD88
# CD224

# %%
#To exclude columns that contain only zeros from NK-only file

nk_prot = pd.DataFrame(nk_prot)
nk_prot != 0
(nk_prot != 0).any(axis=0)
nk_prot.loc[:, (nk_prot != 0).any(axis=0)]
nk_prot = nk_prot.loc[:, (nk_prot != 0).any(axis=0)]

for col in nk_prot:
    print(col)
# Out:
# CD86
# CD274
# CD270
# CD155
# CD112
# CD47
# CD48
# CD40
# CD154
# CD52
# CD3
# CD8
# CD56
# CD19
# CD33
# CD11c
# HLA-A-B-C
# CD45RA
# CD123
# CD7
# CD105
# CD49f
# CD194
# CD4
# CD44
# CD14
# CD16
# CD25
# CD45RO
# CD279
# TIGIT
# CD20
# CD335
# CD31
# Podoplanin
# CD146
# IgM
# CD5
# CD195
# CD32
# CD196
# CD185
# CD103
# CD69
# CD62L
# CD161
# CD152
# CD223
# KLRG1
# CD27
# CD107a
# CD95
# CD134
# HLA-DR
# CD1c
# CD11b
# CD64
# CD141
# CD1d
# CD314
# CD35
# CD57
# CD272
# CD278
# CD58
# CD39
# CX3CR1
# CD24
# CD21
# CD11a
# CD79b
# CD244
# CD169
# integrinB7
# CD268
# CD42b
# CD54
# CD62P
# CD119
# TCR
# CD192
# CD122
# FceRIa
# CD41
# CD137
# CD163
# CD83
# CD124
# CD13
# CD2
# CD226
# CD29
# CD303
# CD49b
# CD81
# IgD
# CD18
# CD28
# CD38
# CD127
# CD45
# CD22
# CD71
# CD26
# CD115
# CD63
# CD304
# CD36
# CD172a
# CD72
# CD158
# CD93
# CD49a
# CD49d
# CD73
# CD9
# TCRVa7.2
# TCRVd2
# LOX-1
# CD158b
# CD158e1
# CD142
# CD319
# CD352
# CD94
# CD162
# CD85j
# CD23
# CD328
# HLA-E
# CD82
# CD101
# CD88
# CD224

# %%
#All cells
matrix1=prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix1, figsize=(20,20))
plt.title('All cell types', fontsize = 50) ;

# %%
#NK cells
matrix3=nk_prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix3, figsize=(20,20))
plt.title('NK-cells', fontsize = 50) ;

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_sample.obs
b = prot

neurips_umap=pd.concat([a, b], axis=1)

adata_sample.obs=neurips_umap
adata_sample
# Out:
# AnnData object with n_obs × n_vars = 8725 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD86', 'CD274', 'CD270', 'CD155', 'CD112', 'CD47', 'CD48', 'CD40', 'CD154', 'CD52', 'CD3', 'CD8', 'CD56', 'CD19', 'CD33', 'CD11c', 'HLA-A-B-C', 'CD45RA', 'CD123', 'CD7', 'CD105', 'CD49f', 'CD194', 'CD4', 'CD44', 'CD14', 'CD16', 'CD25', 'CD45RO', 'CD279', 'TIGIT', 'CD20', 'CD335', 'CD31', 'Podoplanin', 'CD146', 'IgM', 'CD5', 'CD195', 'CD32', 'CD196', 'CD185', 'CD103', 'CD69', 'CD62L', 'CD161', 'CD152', 'CD223', 'KLRG1', 'CD27', 'CD107a', 'CD95', 'CD134', 'HLA-DR', 'CD1c', 'CD11b', 'CD64', 'CD141', 'CD1d', 'CD314', 'CD35', 'CD57', 'CD272', 'CD278', 'CD58', 'CD39', 'CX3CR1', 'CD24', 'CD21', 'CD11a', 'CD79b', 'CD244', 'CD169', 'integrinB7', 'CD268', 'CD42b', 'CD54', 'CD62P', 'CD119', 'TCR', 'CD192', 'CD122', 'FceRIa', 'CD41', 'CD137', 'CD163', 'CD83', 'CD124', 'CD13', 'CD2', 'CD226', 'CD29', 'CD303', 'CD49b', 'CD81', 'IgD', 'CD18', 'CD28', 'CD38', 'CD127', 'CD45', 'CD22', 'CD71', 'CD26', 'CD115', 'CD63', 'CD304', 'CD36', 'CD172a', 'CD72', 'CD158', 'CD93', 'CD49a', 'CD49d', 'CD73', 'CD9', 'TCRVa7.2', 'TCRVd2', 'LOX-1', 'CD158b', 'CD158e1', 'CD142', 'CD319', 'CD352', 'CD94', 'CD162', 'CD85j', 'CD23', 'CD328', 'HLA-E', 'CD82', 'CD101', 'CD88', 'CD224'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs
# Out:
#                                    cell_type  n_genes  percent_mito  \
# GGTGGCTAGTCGAGGT-1-s2d5        CD8+ T CD49f+     1174      0.063279
# TGTAGACGTAAGCTCT-1-s2d5                   NK      883      0.086619
# GCATGATTCATTTCCA-1-s2d5         CD4+ T naive     1368      0.044267
# ACTTCGCCAATACAGA-1-s2d5                   NK      565      0.069239
# GCACTAACACCAGTAT-1-s2d5                   NK      874      0.082857
# ...                                      ...      ...           ...
# TCCGGGAGTTGGGTTT-1-s2d5                   NK      837      0.056687
# TTGGATGAGGTGCCAA-1-s2d5          NK CD158e1+      831      0.074454
# ACAGAAACACAGCGCT-1-s2d5  Naive CD20+ B IGKC+      949      0.074313
# CACACAAGTCTAATCG-1-s2d5         CD4+ T naive      823      0.049880
# GTCCACTAGCTACGTT-1-s2d5         CD4+ T naive      765      0.047013
#
#                          percent_ribo     n_counts leiden_r2  \
# GGTGGCTAGTCGAGGT-1-s2d5      0.462741  4665.699707        10
# TGTAGACGTAAGCTCT-1-s2d5      0.199334  3076.548340         0
# GCATGATTCATTTCCA-1-s2d5      0.467707  5146.752441         4
# ACTTCGCCAATACAGA-1-s2d5      0.182747  2736.770996         0
# GCACTAACACCAGTAT-1-s2d5      0.178857  3110.555664         0
# ...                               ...          ...       ...
# TCCGGGAGTTGGGTTT-1-s2d5      0.216841  3433.329346         0
# TTGGATGAGGTGCCAA-1-s2d5      0.204108  3045.360352         0
# ACAGAAACACAGCGCT-1-s2d5      0.412284  4630.454102        11
# CACACAAGTCTAATCG-1-s2d5      0.491572  5484.218750         4
# GTCCACTAGCTACGTT-1-s2d5      0.553379  6441.796875         4
#
#                          leiden_r2_n_genes_MAD_diff  \
# GGTGGCTAGTCGAGGT-1-s2d5                    1.863415
# TGTAGACGTAAGCTCT-1-s2d5                    0.097561
# GCATGATTCATTTCCA-1-s2d5                    5.662857
# ACTTCGCCAATACAGA-1-s2d5                    3.004878
# GCACTAACACCAGTAT-1-s2d5                    0.009756
# ...                                             ...
# TCCGGGAGTTGGGTTT-1-s2d5                    0.351220
# TTGGATGAGGTGCCAA-1-s2d5                    0.409756
# ACAGAAACACAGCGCT-1-s2d5                    0.280374
# CACACAAGTCTAATCG-1-s2d5                    0.565714
# GTCCACTAGCTACGTT-1-s2d5                    1.228571
#
#                          leiden_r2_n_counts_MAD_diff  \
# GGTGGCTAGTCGAGGT-1-s2d5                     0.461179
# TGTAGACGTAAGCTCT-1-s2d5                     0.537477
# GCATGATTCATTTCCA-1-s2d5                     0.266756
# ACTTCGCCAATACAGA-1-s2d5                     3.006418
# GCACTAACACCAGTAT-1-s2d5                     0.290368
# ...                                              ...
# TCCGGGAGTTGGGTTT-1-s2d5                     2.055017
# TTGGATGAGGTGCCAA-1-s2d5                     0.764100
# ACAGAAACACAGCGCT-1-s2d5                     0.453511
# CACACAAGTCTAATCG-1-s2d5                     0.691687
# GTCCACTAGCTACGTT-1-s2d5                     3.411319
#
#                          leiden_r2_percent_mito_MAD_diff filter  ... CD94  \
# GGTGGCTAGTCGAGGT-1-s2d5                         1.004559  False  ...    1
# TGTAGACGTAAGCTCT-1-s2d5                         1.423168  False  ...   33
# GCATGATTCATTTCCA-1-s2d5                         1.435721  False  ...    2
# ACTTCGCCAATACAGA-1-s2d5                         0.096088  False  ...   11
# GCACTAACACCAGTAT-1-s2d5                         1.135944  False  ...   28
# ...                                                  ...    ...  ...  ...
# TCCGGGAGTTGGGTTT-1-s2d5                         0.862441  False  ...    4
# TTGGATGAGGTGCCAA-1-s2d5                         0.494306  False  ...    4
# ACAGAAACACAGCGCT-1-s2d5                         0.097515  False  ...    3
# CACACAAGTCTAATCG-1-s2d5                         0.888199  False  ...    1
# GTCCACTAGCTACGTT-1-s2d5                         1.167871  False  ...    3
#
#                         CD162 CD85j CD23 CD328 HLA-E CD82 CD101 CD88 CD224
# GGTGGCTAGTCGAGGT-1-s2d5    13     0    2     0     4    2    17    3     2
# TGTAGACGTAAGCTCT-1-s2d5    25     0    7    10     4    0     1    4     1
# GCATGATTCATTTCCA-1-s2d5    33     0    7     1     4    9     5    0     3
# ACTTCGCCAATACAGA-1-s2d5    13     0    1    15     2    4     2    1     0
# GCACTAACACCAGTAT-1-s2d5    36     2    4     7     4    1     3    1     1
# ...                       ...   ...  ...   ...   ...  ...   ...  ...   ...
# TCCGGGAGTTGGGTTT-1-s2d5    15     1    3     2     1    0     2    0     3
# TTGGATGAGGTGCCAA-1-s2d5    14     0    7    14     5    2     0    1     0
# ACAGAAACACAGCGCT-1-s2d5     2     1    9     1     2   47     5    6     2
# CACACAAGTCTAATCG-1-s2d5    24     0    4     1     4    1     6    1     1
# GTCCACTAGCTACGTT-1-s2d5    11     0    1     0     0    1     0    0     1
#
# [8725 rows x 157 columns]

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_nk.obs
b = nk_prot

adata_nk_umap=pd.concat([a, b], axis=1)

adata_nk.obs=adata_nk_umap

adata_nk
# Out:
# AnnData object with n_obs × n_vars = 1814 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD86', 'CD274', 'CD270', 'CD155', 'CD112', 'CD47', 'CD48', 'CD40', 'CD154', 'CD52', 'CD3', 'CD8', 'CD56', 'CD19', 'CD33', 'CD11c', 'HLA-A-B-C', 'CD45RA', 'CD123', 'CD7', 'CD105', 'CD49f', 'CD194', 'CD4', 'CD44', 'CD14', 'CD16', 'CD25', 'CD45RO', 'CD279', 'TIGIT', 'CD20', 'CD335', 'CD31', 'Podoplanin', 'CD146', 'IgM', 'CD5', 'CD195', 'CD32', 'CD196', 'CD185', 'CD103', 'CD69', 'CD62L', 'CD161', 'CD152', 'CD223', 'KLRG1', 'CD27', 'CD107a', 'CD95', 'CD134', 'HLA-DR', 'CD1c', 'CD11b', 'CD64', 'CD141', 'CD1d', 'CD314', 'CD35', 'CD57', 'CD272', 'CD278', 'CD58', 'CD39', 'CX3CR1', 'CD24', 'CD21', 'CD11a', 'CD79b', 'CD244', 'CD169', 'integrinB7', 'CD268', 'CD42b', 'CD54', 'CD62P', 'CD119', 'TCR', 'CD192', 'CD122', 'FceRIa', 'CD41', 'CD137', 'CD163', 'CD83', 'CD124', 'CD13', 'CD2', 'CD226', 'CD29', 'CD303', 'CD49b', 'CD81', 'IgD', 'CD18', 'CD28', 'CD38', 'CD127', 'CD45', 'CD22', 'CD71', 'CD26', 'CD115', 'CD63', 'CD304', 'CD36', 'CD172a', 'CD72', 'CD158', 'CD93', 'CD49a', 'CD49d', 'CD73', 'CD9', 'TCRVa7.2', 'TCRVd2', 'LOX-1', 'CD158b', 'CD158e1', 'CD142', 'CD319', 'CD352', 'CD94', 'CD162', 'CD85j', 'CD23', 'CD328', 'HLA-E', 'CD82', 'CD101', 'CD88', 'CD224'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs["CD56"]
# Out:
# TGTAGACGTAAGCTCT-1-s2d5     9
# ACTTCGCCAATACAGA-1-s2d5     7
# GCACTAACACCAGTAT-1-s2d5    16
# CGAAGTTCACCCAATA-1-s2d5    18
# GGGTAGATCTCGACGG-1-s2d5    19
#                            ..
# GAGACTTTCGCCGAGT-1-s2d5    14
# GCAGCCATCCATAGAC-1-s2d5    18
# ATCGTGACAACGTAAA-1-s2d5    11
# TCCGGGAGTTGGGTTT-1-s2d5    19
# TTGGATGAGGTGCCAA-1-s2d5    24
# Name: CD56, Length: 1814, dtype: int64

# %%
#NK-cell markers

markers=["CD56", "CD16"]

# %%
#All cell types
sc.pl.umap(adata_sample, color= "cell_type", color_map= 'viridis')

# %%
#NK-cells

sc.pl.umap(adata_nk, color = "cell_type", color_map = 'viridis')

# %%
#All cell types

sc.pl.umap(adata_sample, color= markers, color_map= 'viridis')

# %%
#NK-cells

sc.pl.umap(adata_nk, color = markers, color_map = 'viridis')

# %%
#NK-cells

for column_name in markers:
    fig, ax =plt.subplots(1,2 ,tight_layout=True, figsize=(15, 5), sharex=True)
    fig.show()

    ax1 = sns.kdeplot(data=prot, x=column_name, multiple="stack", ax=ax[0]) ;
    ax2 = sns.kdeplot(data=nk_prot, x=column_name, color = "g", multiple="stack", ax=ax[1]) ;


    ax1.title.set_text('All cell types')    
    ax2.title.set_text('NK-cells')
    
    plt.show()

# %%
#NK markers

plt.figure(figsize=(20,10))
a=sns.violinplot(data=nk_prot[markers],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK-cell markers", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

# %% [markdown]
# # UMAPs Neurips samples, NK cells

# %% [markdown]
# Different NK cell markers and corresponding gene expression is visualised in UMAPs generated based on latent space.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
import umap

from ridgeplot import ridgeplot
from pySankey import sankey

import warnings

warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %% [markdown]
# # 1. Preparations

# %%
#Neurips

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_seurat_norm.h5ad')

# %%
adata = adata.copy()

# %%
#Both NK cell types selected  + one sample is selected

adata = adata[(adata.obs['cell_type'] == "NK")]

# %%
#Selecting only one sample

adata =adata[adata.obs['POOL'] == "Seurat"]

# %%
adata.shape
# Out:
# (1226, 8051)

# %%
#protein information saved

adata_prot=adata.obsm['protein_expression_clr_seurat']

# %%
df = adata_prot

# %%
df=adata.obsm['protein_expression_clr_seurat'].astype(float)

# %%
#selecting nonzero columns (at least some expression detected), these are removed next

nonzero = df.columns[(~(df == 0)).sum() != 0]

#RNA data (zero columns removed) is added to obs 

df=df.loc[:,nonzero]

# %%
df.shape
# Out:
# (1226, 25)

# %%
#empty anndata file with correct shape (for protein data)

adata_new_prot = ad.AnnData(np.random.poisson(1, size=(1226, 25)))

# %%
#adata file where X = CLR normalized protein 
adata_new_prot.X=df

# %%
#obs and var names identified

adata_new_prot.obs_names = df.index
adata_new_prot.var_names = df.columns

# %%
adata_new_prot
# Out:
# AnnData object with n_obs × n_vars = 1226 × 25

# %%
#RNA expression to df

df_rna = adata.to_df()

# %%
#selecting nonzero columns (at least some expression detected), these are removed next

nonzero = df_rna.columns[(~(df_rna == 0)).sum() != 0]

# %%
#RNA data (zero columns removed) is added to obs 

df_rna=adata.to_df().loc[:,nonzero]

# %%
df_rna.shape
# Out:
# (1226, 7964)

# %%
#empty anndata file with correct shape (for RNA data)

adata_new_rna = ad.AnnData(np.random.poisson(1, size=(1226, 7964)))

# %%
#adata file where X = RNA expression

adata_new_rna.X=df_rna

# %%
#obs and var names identified

adata_new_rna.obs_names = df_rna.index
adata_new_rna.var_names = df_rna.columns

# %%
adata_new_rna
# Out:
# AnnData object with n_obs × n_vars = 1226 × 7964

# %%
import muon as mu

# %%
#Combine previous two adata files into one muon object

mdata = mu.MuData({'rna': adata_new_rna, 'adt': adata_new_prot})

# %%
mdata.obsm
# Out:
# MuAxisArrays with keys: rna, adt

# %%
#anndata file containing only RNA expression
adata_gex = mdata.mod['rna'].copy()

# %%
#anndata file containing only CLR normalized protein counts

adata_adt = mdata.mod['adt'].copy()

# %%
#Neurips, latent

adata_latent = adata.copy()

# %%
adata_latent
# Out:
# AnnData object with n_obs × n_vars = 1226 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr_seurat'
#     obsp: 'connectivities', 'distances'

# %%
prot=adata_latent.obsm['protein_expression_clr_seurat']

# %%
#some proteins and genes have same names, here _prot added after protein names
prot=prot.rename(columns={'CD2': 'CD2_prot', 'CX3CR1': 'CX3CR1_prot', 'CD226':'CD226_prot', 'TIGIT':'TIGIT_prot', 'CD27':'CD27_prot', 'CD38': 'CD38_prot', 'CD224': 'CD224_prot', 'CD7': 'CD7_prot', 'CD44': 'CD44_prot', 'CD34': 'CD34_prot','CD5': 'CD5_prot'})

# %%
prot=adata_latent.obsm['protein_expression_clr_seurat']

# %%
#Some genes have same names, so _prot added after some proteins

prot=prot.rename(columns={'CD2': 'CD2_prot', 'CD83': 'CD83_prot', 'HLA-E': 'HLA-E_prot', 'CD163': 'CD163_prot', 'CX3CR1': 'CX3CR1_prot', 'CD52': 'CD52_prot', 'CD24': 'CD24_prot', 'KLRG1': 'KLRG1_prot', 'CD69': 'CD69_prot', 'CD226':'CD226_prot', 'CD47': 'CD47_prot', 'TIGIT':'TIGIT_prot', 'CD27':'CD27_prot', 'CD38': 'CD38_prot', 'CD224': 'CD224_prot', 'CD7': 'CD7_prot', 'CD44': 'CD44_prot', 'CD34': 'CD34_prot','CD5': 'CD5_prot'})

# %%
#adding protein information to obs

a = adata_latent.obs
b = prot

adata_eg=pd.concat([a, b], axis=1)
adata_latent.obs=adata_eg

# %%
adata_latent
# Out:
# AnnData object with n_obs × n_vars = 1226 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD86', 'CD274', 'CD270', 'CD155', 'CD112', 'CD47_prot', 'CD48', 'CD40', 'CD154', 'CD52_prot', 'CD3', 'CD8', 'CD56', 'CD19', 'CD33', 'CD11c', 'HLA-A-B-C', 'CD45RA', 'CD123', 'CD7_prot', 'CD105', 'CD49f', 'CD194', 'CD4', 'CD44_prot', 'CD14', 'CD16', 'CD25', 'CD45RO', 'CD279', 'TIGIT_prot', 'CD20', 'CD335', 'CD31', 'Podoplanin', 'CD146', 'IgM', 'CD5_prot', 'CD195', 'CD32', 'CD196', 'CD185', 'CD103', 'CD69_prot', 'CD62L', 'CD161', 'CD152', 'CD223', 'KLRG1_prot', 'CD27_prot', 'CD107a', 'CD95', 'CD134', 'HLA-DR', 'CD1c', 'CD11b', 'CD64', 'CD141', 'CD1d', 'CD314', 'CD35', 'CD57', 'CD272', 'CD278', 'CD58', 'CD39', 'CX3CR1_prot', 'CD24_prot', 'CD21', 'CD11a', 'CD79b', 'CD244', 'CD169', 'integrinB7', 'CD268', 'CD42b', 'CD54', 'CD62P', 'CD119', 'TCR', 'CD192', 'CD122', 'FceRIa', 'CD41', 'CD137', 'CD163_prot', 'CD83_prot', 'CD124', 'CD13', 'CD2_prot', 'CD226_prot', 'CD29', 'CD303', 'CD49b', 'CD81', 'IgD', 'CD18', 'CD28', 'CD38_prot', 'CD127', 'CD45', 'CD22', 'CD71', 'CD26', 'CD115', 'CD63', 'CD304', 'CD36', 'CD172a', 'CD72', 'CD158', 'CD93', 'CD49a', 'CD49d', 'CD73', 'CD9', 'TCRVa7.2', 'TCRVd2', 'LOX-1', 'CD158b', 'CD158e1', 'CD142', 'CD319', 'CD352', 'CD94', 'CD162', 'CD85j', 'CD23', 'CD328', 'HLA-E_prot', 'CD82', 'CD101', 'CD88', 'CD224_prot', 'CD197', 'CD34_prot', 'CD10', 'CD90', 'CD15', 'CD117', 'CD66ace'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr_seurat'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# # UMAPs

# %%
#Calculating neighbors for UMAPs

sc.pp.neighbors(adata_latent, use_rep="X_totalVI")   
sc.tl.umap(adata_latent)

# %%
#proteins + corresponding genes

sc.pl.umap(adata_latent, color = ['CD56', 'CD16','CD57', 'CD94', 'CD127', 'CD62L'], color_map = 'viridis', vmax="p99" )

sc.pl.umap(adata_latent, color = ['NCAM1', 'FCGR3A', 'B3GAT', 'KLRD1', 'IL7R', 'SELL'], color_map = 'viridis', vmax="p99" )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [57], line 5
#       1 #Immature CD56bright
#       3 sc.pl.umap(adata_latent, color = ['CD56', 'CD16','CD57'], color_map = 'viridis', vmax="p99" )
# ----> 5 sc.pl.umap(adata_latent, color = ['NCAM1', 'FCGR3A', 'B3GAT'], color_map = 'viridis', vmax="p99" )
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:669, in umap(adata, **kwargs)
#     610 @_wraps_plot_scatter
#     611 @_doc_params(
#     612     adata_color_etc=doc_adata_color_etc,
#    (...)
#     616 )
#     617 def umap(adata, **kwargs) -> Union[Axes, List[Axes], None]:
#     618     """\
#     619     Scatter plot in UMAP basis.
#     620
#    (...)
#     667     tl.umap
#     668     """
# --> 669     return embedding(adata, 'umap', **kwargs)
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:257, in embedding(adata, basis, color, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     250 # use itertools.product to make a plot for each color and for each component
#     251 # For example if color=[gene1, gene2] and components=['1,2, '2,3'].
#     252 # The plots are: [
#     253 #     color=gene1, components=[1,2], color=gene1, components=[2,3],
#     254 #     color=gene2, components = [1, 2], color=gene2, components=[2,3],
#     255 # ]
#     256 for count, (value_to_plot, dims) in enumerate(zip(color, dimensions)):
# --> 257     color_source_vector = _get_color_source_vector(
#     258         adata,
#     259         value_to_plot,
#     260         layer=layer,
#     261         use_raw=use_raw,
#     262         gene_symbols=gene_symbols,
#     263         groups=groups,
#     264     )
#     265     color_vector, categorical = _color_vector(
#     266         adata,
#     267         value_to_plot,
#    (...)
#     270         na_color=na_color,
#     271     )
#     273     # Order points
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1169, in _get_color_source_vector(adata, value_to_plot, use_raw, gene_symbols, layer, groups)
#    1167     values = adata.raw.obs_vector(value_to_plot)
#    1168 else:
# -> 1169     values = adata.obs_vector(value_to_plot, layer=layer)
#    1170 if groups and is_categorical_dtype(values):
#    1171     values = values.replace(values.categories.difference(groups), np.nan)
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/anndata/_core/anndata.py:1397, in AnnData.obs_vector(self, k, layer)
#    1391         warnings.warn(
#    1392             "In a future version of AnnData, access to `.X` by passing"
#    1393             " `layer='X'` will be removed. Instead pass `layer=None`.",
#    1394             FutureWarning,
#    1395         )
#    1396         layer = None
# -> 1397 return get_vector(self, k, "obs", "var", layer=layer)
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/anndata/_core/index.py:179, in get_vector(adata, k, coldim, idxdim, layer)
#     175     raise ValueError(
#     176         f"Key {k} could be found in both .{idxdim}_names and .{coldim}.columns"
#     177     )
#     178 elif (in_col + in_idx) == 0:
# --> 179     raise KeyError(
#     180         f"Could not find key {k} in .{idxdim}_names or .{coldim}.columns."
#     181     )
#     182 elif in_col:
#     183     return getattr(adata, coldim)[k].values
#
# KeyError: 'Could not find key NCAM1 in .var_names or .obs.columns.'

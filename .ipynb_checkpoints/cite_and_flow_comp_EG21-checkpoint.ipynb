# %% [markdown]
# # EG21 CITE-seq and flow cytometry comparisons

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
from ridgeplot import ridgeplot

import sklearn.mixture

import warnings

warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %% [markdown]
# Sample used in this notebook is EG21.
#
# ### Sample information:
# - ALL
# - collected at diagnosis
# - 95% of bonemarrow cells are blasts

# %%
#raw protein data, all datasets

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/healthy_malig_!m.h5ad')

adata.shape
# Out:
# (298991, 8051)

# %%
adata_prot_clr= sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_prot_clr (1).h5ad')

# %%
adata_prot_clr.shape
# Out:
# (147889, 33)

# %%
#convert excel to csv (flow data)

#read_file = pd.read_excel (r'/Users/tiinatuononen/Desktop/Thesis/Project/data/flow.xlsx')
#read_file.to_csv (r'/Users/tiinatuononen/Desktop/Thesis/Project/data/flow.csv', index = None, header=True)

# %%
#get flow data

flow= pd.read_csv('/Users/tiinatuononen/Desktop/Thesis/Project/data/flow.csv')

# %%
#Selecting EG21 sample
eg=adata[adata.obs['eg_code'] == 'EG21']

eg.obs
# Out:
#                         cell_type  n_genes  percent_mito  percent_ribo  \
# AAACCTGAGTCAAGGC-1-132   leukemic     3502      0.027531      0.221687
# AAACCTGCAATGTAAG-1-132   leukemic      963      0.031618      0.234346
# AAACCTGCATGCAACT-1-132   leukemic      559      0.049102      0.209581
# AAACCTGGTCTGGTCG-1-132   leukemic     3995      0.018124      0.319445
# AAACCTGGTGCAACGA-1-132   leukemic     3180      0.033350      0.311335
# ...                           ...      ...           ...           ...
# TTTGTCACAGTCGTGC-1-132   leukemic     2414      0.023199      0.260652
# TTTGTCAGTCTCATCC-1-132   leukemic      512      0.072323      0.205841
# TTTGTCAGTGCGCTTG-1-132   leukemic     2869      0.016867      0.273290
# TTTGTCAGTTGGACCC-1-132   leukemic     1466      0.037591      0.231752
# TTTGTCATCAAACGGG-1-132  doublets?      689      0.034579      0.219626
#
#                         n_counts leiden_r2  leiden_r2_n_genes_MAD_diff  \
# AAACCTGAGTCAAGGC-1-132   11841.0       NaN                         NaN
# AAACCTGCAATGTAAG-1-132    1613.0       NaN                         NaN
# AAACCTGCATGCAACT-1-132     835.0       NaN                         NaN
# AAACCTGGTCTGGTCG-1-132   13849.0       NaN                         NaN
# AAACCTGGTGCAACGA-1-132    9925.0       NaN                         NaN
# ...                          ...       ...                         ...
# TTTGTCACAGTCGTGC-1-132    6595.0       NaN                         NaN
# TTTGTCAGTCTCATCC-1-132     719.0       NaN                         NaN
# TTTGTCAGTGCGCTTG-1-132    7589.0       NaN                         NaN
# TTTGTCAGTTGGACCC-1-132    2740.0       NaN                         NaN
# TTTGTCATCAAACGGG-1-132    1070.0       NaN                         NaN
#
#                         leiden_r2_n_counts_MAD_diff  \
# AAACCTGAGTCAAGGC-1-132                          NaN
# AAACCTGCAATGTAAG-1-132                          NaN
# AAACCTGCATGCAACT-1-132                          NaN
# AAACCTGGTCTGGTCG-1-132                          NaN
# AAACCTGGTGCAACGA-1-132                          NaN
# ...                                             ...
# TTTGTCACAGTCGTGC-1-132                          NaN
# TTTGTCAGTCTCATCC-1-132                          NaN
# TTTGTCAGTGCGCTTG-1-132                          NaN
# TTTGTCAGTTGGACCC-1-132                          NaN
# TTTGTCATCAAACGGG-1-132                          NaN
#
#                         leiden_r2_percent_mito_MAD_diff filter  ...  \
# AAACCTGAGTCAAGGC-1-132                              NaN  False  ...
# AAACCTGCAATGTAAG-1-132                              NaN  False  ...
# AAACCTGCATGCAACT-1-132                              NaN  False  ...
# AAACCTGGTCTGGTCG-1-132                              NaN  False  ...
# AAACCTGGTGCAACGA-1-132                              NaN  False  ...
# ...                                                 ...    ...  ...
# TTTGTCACAGTCGTGC-1-132                              NaN  False  ...
# TTTGTCAGTCTCATCC-1-132                              NaN  False  ...
# TTTGTCAGTGCGCTTG-1-132                              NaN  False  ...
# TTTGTCAGTTGGACCC-1-132                              NaN  False  ...
# TTTGTCATCAAACGGG-1-132                              NaN  False  ...
#
#                        SAMPLE_SET SAMPLE_TYPE SAMPLE_TISSUE DIAGNOSIS  \
# AAACCTGAGTCAAGGC-1-132          F          dg            BM     B-ALL
# AAACCTGCAATGTAAG-1-132          F          dg            BM     B-ALL
# AAACCTGCATGCAACT-1-132          F          dg            BM     B-ALL
# AAACCTGGTCTGGTCG-1-132          F          dg            BM     B-ALL
# AAACCTGGTGCAACGA-1-132          F          dg            BM     B-ALL
# ...                           ...         ...           ...       ...
# TTTGTCACAGTCGTGC-1-132          F          dg            BM     B-ALL
# TTTGTCAGTCTCATCC-1-132          F          dg            BM     B-ALL
# TTTGTCAGTGCGCTTG-1-132          F          dg            BM     B-ALL
# TTTGTCAGTTGGACCC-1-132          F          dg            BM     B-ALL
# TTTGTCATCAAACGGG-1-132          F          dg            BM     B-ALL
#
#                                             SUBTYPE STATUS eg_code leiden_r1  \
# AAACCTGAGTCAAGGC-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        10
# AAACCTGCAATGTAAG-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        20
# AAACCTGCATGCAACT-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        20
# AAACCTGGTCTGGTCG-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        10
# AAACCTGGTGCAACGA-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        10
# ...                                             ...    ...     ...       ...
# TTTGTCACAGTCGTGC-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        10
# TTTGTCAGTCTCATCC-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        20
# TTTGTCAGTGCGCTTG-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        10
# TTTGTCAGTTGGACCC-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        20
# TTTGTCATCAAACGGG-1-132  t(9;22)(q34;q11.2);BCR-ABL1    NaN    EG21        20
#
#                        new_cell_type batch_group
# AAACCTGAGTCAAGGC-1-132      leukemic        Easi
# AAACCTGCAATGTAAG-1-132      leukemic        Easi
# AAACCTGCATGCAACT-1-132      leukemic        Easi
# AAACCTGGTCTGGTCG-1-132      leukemic        Easi
# AAACCTGGTGCAACGA-1-132      leukemic        Easi
# ...                              ...         ...
# TTTGTCACAGTCGTGC-1-132      leukemic        Easi
# TTTGTCAGTCTCATCC-1-132      leukemic        Easi
# TTTGTCAGTGCGCTTG-1-132      leukemic        Easi
# TTTGTCAGTTGGACCC-1-132      leukemic        Easi
# TTTGTCATCAAACGGG-1-132     doublets?        Easi
#
# [2394 rows x 23 columns]

# %%
eg.obs['new_cell_type']
# Out:
# AAACCTGAGTCAAGGC-1-132     leukemic
# AAACCTGCAATGTAAG-1-132     leukemic
# AAACCTGCATGCAACT-1-132     leukemic
# AAACCTGGTCTGGTCG-1-132     leukemic
# AAACCTGGTGCAACGA-1-132     leukemic
#                             ...
# TTTGTCACAGTCGTGC-1-132     leukemic
# TTTGTCAGTCTCATCC-1-132     leukemic
# TTTGTCAGTGCGCTTG-1-132     leukemic
# TTTGTCAGTTGGACCC-1-132     leukemic
# TTTGTCATCAAACGGG-1-132    doublets?
# Name: new_cell_type, Length: 2394, dtype: category
# Categories (5, object): ['NK', 'doublets?', 'leukemic', 'leukemic?', 'non-leukemic']

# %%
eg_blasts=eg[eg.obs['new_cell_type'] == 'leukemic']

# %%
#selecting only leukemic cells

eg_blasts=eg[eg.obs['new_cell_type'] == 'leukemic']

eg_blasts.obs['new_cell_type']
# Out:
# AAACCTGAGTCAAGGC-1-132    leukemic
# AAACCTGCAATGTAAG-1-132    leukemic
# AAACCTGCATGCAACT-1-132    leukemic
# AAACCTGGTCTGGTCG-1-132    leukemic
# AAACCTGGTGCAACGA-1-132    leukemic
#                             ...
# TTTGGTTTCGCGGATC-1-132    leukemic
# TTTGTCACAGTCGTGC-1-132    leukemic
# TTTGTCAGTCTCATCC-1-132    leukemic
# TTTGTCAGTGCGCTTG-1-132    leukemic
# TTTGTCAGTTGGACCC-1-132    leukemic
# Name: new_cell_type, Length: 2105, dtype: category
# Categories (1, object): ['leukemic']

# %% [markdown]
# ### Depending on used dataset, celltype annotations are varying (made by different groups). "new_cell_types" is made based on these, it is a "standardized" version of cell type annotations.

# %%
#Cell types offered by new_cell_type

adata.obs['new_cell_type'].unique().tolist()
# Out:
# ['NK',
#  'T',
#  'Prog',
#  'Myel',
#  'B',
#  'DC',
#  'E',
#  'Normoblast',
#  'Stromal',
#  'Megakaryocyte',
#  nan,
#  'non-leukemic',
#  'preleukemic',
#  'non-leukemic?',
#  'leukemic',
#  'leukemic?',
#  'doublets?',
#  'unknown',
#  '0',
#  'preleukemic?']

# %%
#cell type annotations offered by cell_type

adata.obs['cell_type'].unique().tolist()
# Out:
# ['NK',
#  'CD8+ T CD69+ CD45RA+',
#  'NK CD158e1+',
#  'HSC',
#  'CD14+ Mono',
#  'B1 B IGKC+',
#  'CD4+ T activated',
#  'CD8+ T CD69+ CD45RO+',
#  'G/M prog',
#  'Naive CD20+ B IGKC-',
#  'CD8+ T CD49f+',
#  'Naive CD20+ B IGKC+',
#  'CD4+ T naive',
#  'CD8+ T naive',
#  'CD4+ T activated integrinB7+',
#  'cDC2',
#  'gdT TCRVD2+',
#  'CD8+ T TIGIT+ CD45RO+',
#  'CD16+ Mono',
#  'Erythroblast',
#  'MAIT',
#  'T reg',
#  'gdT CD158b+',
#  'Transitional B',
#  'Proerythroblast',
#  'CD8+ T CD57+ CD45RO+',
#  'Plasmablast IGKC+',
#  'ILC1',
#  'Lymph prog',
#  'ILC',
#  'MK/E prog',
#  'Normoblast',
#  'CD8+ T CD57+ CD45RA+',
#  'pDC',
#  'B1 B IGKC-',
#  'Plasma cell IGKC-',
#  'Plasmablast IGKC-',
#  'Plasma cell IGKC+',
#  'CD8+ T TIGIT+ CD45RA+',
#  'CD8+ T naive CD127+ CD26- CD101-',
#  'CD4+ T CD314+ CD45RA+',
#  'cDC1',
#  'T prog cycling',
#  'dnT',
#  'Prog_RBC',
#  'gdT',
#  'CD4 Naive',
#  'CD4 Memory',
#  'CD14 Mono',
#  'Naive B',
#  'CD8 Naive',
#  'Treg',
#  'CD8 Effector_2',
#  'GMP',
#  'CD8 Effector_1',
#  'CD16 Mono',
#  'CD8 Memory_1',
#  'Memory B',
#  'CD56 bright NK',
#  'Prog_B 2',
#  'Prog_Mk',
#  'CD8 Memory_2',
#  'Plasmablast',
#  'LMPP',
#  'Prog_DC',
#  'Prog_B 1',
#  'CD4+ T 1',
#  'CD14+ monocyte 1',
#  'Pre B',
#  'Pro B',
#  'CD8+ T',
#  'Promonocyte',
#  'CD14+ monocyte 2',
#  'Plasmacytoid dendritic cell',
#  'NK T 2',
#  'Immature B',
#  'Late erythoid precursor 1',
#  'Pre B (cycling)',
#  'Late erythoid precursor 3',
#  'Early erythoid precursor',
#  'CD16+ monocyte',
#  'Conventional dendritic cell',
#  'NK T 1',
#  'Late erythoid precursor 2',
#  'Plasma B cell',
#  'Stromal cell',
#  'Megakaryocyte',
#  nan,
#  '6_preB-II_G1',
#  'T cell',
#  '6_preB_G1',
#  '5_preB_G2MS',
#  'Dendritic cell',
#  'Monocyte',
#  '1_HSC',
#  'Erythroid precursor cell',
#  '3_proB_G2MS',
#  '7_immatureB',
#  '4_proB_G1',
#  '2_earlyLymphoid',
#  'Stromal-like cell',
#  'NKT',
#  'non-leukemic',
#  'preleukemic',
#  'non-leukemic?',
#  'leukemic',
#  'leukemic?',
#  'doublets?',
#  'unknown',
#  '0',
#  'preleukemic?']

# %% [markdown]
# ### Files containing DSB and CLR normalized protein counts, do not have cell type annotations, but instead "predicted.id".

# %%
adata_prot_clr.obs['predicted.id'].unique().tolist()
# Out:
# ['NK T 1',
#  'NK',
#  'CD4+ T 1',
#  'CD14+ monocyte 2',
#  '7_immatureB',
#  'CD14+ monocyte 1',
#  'NK T 2',
#  'Early erythoid precursor',
#  'Late erythoid precursor 1',
#  '5_preB_G2MS',
#  'Conventional dendritic cell',
#  'CD4+ T 3',
#  'Late erythoid precursor 2',
#  'Promonocyte',
#  'Stromal cell',
#  '4_proB_G1',
#  '3_proB_G2MS',
#  'HSC',
#  '6_preB-II_G1',
#  'Megakaryocyte',
#  'Plasmacytoid dendritic cell',
#  '2_earlyLymphoid',
#  'CD16+ monocyte',
#  '6_preB_G1',
#  'Plasma B cell',
#  'Late erythoid precursor 3',
#  'Stromal cell like',
#  'CD8+ T']

# %% [markdown]
# ## Proportions using predicted_id

# %%
eg_blasts
# Out:
# View of AnnData object with n_obs × n_vars = 2105 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
#Checking what king of values we have for EG24

egflow=flow[flow['EG_code'] == 'EG21'].dropna(axis=1)

egflow
# Out:
#   EG_code  CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0    EG21   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
#drop EG_code

egflow=egflow.drop("EG_code", axis=1)

egflow
# Out:
#    CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
df=egflow * 100 #multiplied by 100 to get percentages

df1=df.T

df1.plot.bar(xlabel="Marker", ylabel="% of blasts",
            figsize= (15,8),
           fontsize="large") ;

plt.title('Blast phenotype', fontsize=20) ;

# %%
flow_markers=egflow.columns
flow_markers
# Out:
# Index(['CD10', 'CD19', ' CD22', 'CD33', 'CD34', 'CD38', 'HLA-DR'], dtype='object')

# %%
#Selecting common markers between flow and cite-seq

listOfMarkers=flow_markers
column_names=list()    #list including the common markers

for x in listOfMarkers:
    if x in eg_blasts.obsm['protein_expression'].columns:
        print(x, "Yes")
        column_names.append(x)
    else:
        print(x, "No") 
        
print(column_names)
# Out:
# CD10 Yes
# CD19 Yes
#  CD22 No
# CD33 Yes
# CD34 Yes
# CD38 Yes
# HLA-DR Yes
# ['CD10', 'CD19', 'CD33', 'CD34', 'CD38', 'HLA-DR']

# %%
#Number of all cells for calculations

all_cells=len(eg_blasts.obs['cell_type'])

all_cells
# Out:
# 2105

# %%
egflow
# Out:
#    CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
column_names
# Out:
# ['CD10', 'CD19', 'CD33', 'CD34', 'CD38', 'HLA-DR']

# %%
egflow
# Out:
#    CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
#Only leukemic cells selected, now using GMM to detect positive cells/per each marker

#model
gmm = sklearn.mixture.GaussianMixture(n_components = 2,
                                      covariance_type = "full",
                                      random_state = 42
                                        )
#data

data=eg_blasts.obsm['protein_expression']
n_cells=len(eg_blasts.obs['cell_type'])
egflow=egflow * 100 #to get percentages

for column_name in column_names:
    fig, ax =plt.subplots(1,2,tight_layout=True, figsize=(15, 5))
    fig.show()
    
    #CLR
    x= data[column_name]
    x=x.values.reshape(-1, 1)
    gmm.fit(x)
    labels = gmm.predict(x)
    
    x0 = data[column_name].reset_index(drop=True)[labels == 0].mean()
    x1 = data[column_name].reset_index(drop=True)[labels == 1].mean()
    if x0 < x1:
        labels = (~(labels == 1)).astype(int)

    ax1 = sns.kdeplot(data=data, x=column_name, hue=labels, multiple="stack", ax=ax[0]) ;
    ax1.title.set_text('GMM')    
   
    #Calculate zeros
    n_zeros = np.count_nonzero(labels==0)
    result_zeros=(n_zeros/n_cells * 100)
    #Calculate ones
    n_ones=np.count_nonzero(labels)
    result_ones=(n_ones/n_cells * 100)
    #Dataframes
    all_data = {"GMM":[result_ones],
        "Flow": egflow[column_name],
        };

    all_data= pd.DataFrame(data=all_data);
    
    ax2=all_data.plot.bar(rot=15, title=column_name,ax=ax[1]);
    ax2.title.set_text('Proportions')
    
    plt.show()

# %% [markdown]
# ## CLR normalized

# %%
#all CLR data

adata_prot_clr= sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_prot_clr (1).h5ad')

# %%
adata_prot_clr
# Out:
# AnnData object with n_obs × n_vars = 147889 × 33
#     obs: 'nCount_RNA', 'nFeature_RNA', 'bc', 'propmt', 'rna_size', 'ngene', 'prot_size', 'predicted.id', 'hashMax', 'adtMax', 'nHashPos', 'HTO_maxID', 'HTO_secondID', 'HTO_margin', 'HTO_classification', 'HTO_classification.global', 'hash.ID', 'EG_code', 'Donor', 'prediction.score.CD14..monocyte.1', 'prediction.score.CD14..monocyte.2', 'prediction.score.NK', 'prediction.score.CD4..T.1', 'prediction.score.NK.T.1', 'prediction.score.NK.T.2', 'prediction.score.CD4..T.3', 'prediction.score.Conventional.dendritic.cell', 'prediction.score.7_immatureB', 'prediction.score.Late.erythoid.precursor.2', 'prediction.score.Early.erythoid.precursor', 'prediction.score.max', 'n_genes', 'S_score', 'G2M_score', 'phase', 'leiden', 'leiden_r1', 'T.CD4.Naive_score', 'T.CD4.TE_score', 'Tregs_score', 'Tfh_score', 'Th1_score', 'Th1.Th17_score', 'Th17_score', 'Th2_score', 'T.CD8.Naive_score', 'T.CD8.CM_score', 'T.CD8.EM_score', 'T.CD8.TE_score', 'T.gd.Vd2_score', 'T.gd.non.Vd2_score', 'leiden_r1_prot'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts'

# %%
eg_norm=adata_prot_clr[adata_prot_clr.obs['EG_code'] == 'EG21']

# %%
eg_norm.obs
# Out:
#                     nCount_RNA  nFeature_RNA                  bc    propmt  \
# AAACCTGAGTCAAGGC-1     11848.0          3502  AAACCTGAGTCAAGGC-1  0.027515
# AAACCTGCAATGTAAG-1      1616.0           963  AAACCTGCAATGTAAG-1  0.031559
# AAACCTGCATGCAACT-1       836.0           559  AAACCTGCATGCAACT-1  0.049043
# AAACCTGGTCTGGTCG-1     13858.0          3995  AAACCTGGTCTGGTCG-1  0.018112
# AAACCTGGTGCAACGA-1      9932.0          3180  AAACCTGGTGCAACGA-1  0.033327
# ...                        ...           ...                 ...       ...
# TTTGTCAGTCAAAGCG-1      2308.0          1313  TTTGTCAGTCAAAGCG-1  0.222270
# TTTGTCAGTCTCATCC-1       720.0           512  TTTGTCAGTCTCATCC-1  0.072222
# TTTGTCAGTGCGCTTG-1      7592.0          2869  TTTGTCAGTGCGCTTG-1  0.016860
# TTTGTCAGTTGGACCC-1      2746.0          1466  TTTGTCAGTTGGACCC-1  0.037509
# TTTGTCATCAAACGGG-1      1074.0           689  TTTGTCATCAAACGGG-1  0.034451
#
#                     rna_size   ngene  prot_size               predicted.id  \
# AAACCTGAGTCAAGGC-1  4.073645  3502.0   2.843233                Promonocyte
# AAACCTGCAATGTAAG-1  3.208441   963.0   2.546543  Late erythoid precursor 2
# AAACCTGCATGCAACT-1  2.922206   559.0   2.558709           CD14+ monocyte 1
# AAACCTGGTCTGGTCG-1  4.141701  3995.0   2.909556                Promonocyte
# AAACCTGGTGCAACGA-1  3.997037  3180.0   2.954725                7_immatureB
# ...                      ...     ...        ...                        ...
# TTTGTCAGTCAAAGCG-1  3.363236  1313.0   2.549003                         NK
# TTTGTCAGTCTCATCC-1  2.857332   512.0   2.764176                   CD4+ T 3
# TTTGTCAGTGCGCTTG-1  3.880356  2869.0   2.814913  Late erythoid precursor 2
# TTTGTCAGTTGGACCC-1  3.438701  1466.0   2.802774  Late erythoid precursor 2
# TTTGTCATCAAACGGG-1  3.031004   689.0   2.444045  Late erythoid precursor 2
#
#                       hashMax     adtMax  ...  Th1.Th17_score Th17_score  \
# AAACCTGAGTCAAGGC-1  14.998817  10.500050  ...       -0.048419  -0.058883
# AAACCTGCAATGTAAG-1   4.069009   5.856373  ...       -0.030576  -0.009622
# AAACCTGCATGCAACT-1   3.593683   3.537242  ...        0.002254  -0.001790
# AAACCTGGTCTGGTCG-1   5.737773   9.012157  ...       -0.051152  -0.042782
# AAACCTGGTGCAACGA-1   4.069009   8.537240  ...       -0.039661  -0.056924
# ...                       ...        ...  ...             ...        ...
# TTTGTCAGTCAAAGCG-1   5.350916   4.711847  ...       -0.025927  -0.013660
# TTTGTCAGTCTCATCC-1   9.109595   4.265634  ...       -0.032292  -0.032338
# TTTGTCAGTGCGCTTG-1   6.107431  10.129750  ...       -0.066969  -0.051514
# TTTGTCAGTTGGACCC-1   3.089532   4.186352  ...       -0.035692  -0.026567
# TTTGTCATCAAACGGG-1   5.737773   2.105883  ...       -0.062560  -0.046850
#
#                    Th2_score  T.CD8.Naive_score T.CD8.CM_score T.CD8.EM_score  \
# AAACCTGAGTCAAGGC-1 -0.050467          -0.070734      -0.044224      -0.027183
# AAACCTGCAATGTAAG-1 -0.006932          -0.005088      -0.016345       0.010868
# AAACCTGCATGCAACT-1 -0.003680           0.004108      -0.006659       0.020056
# AAACCTGGTCTGGTCG-1 -0.055605          -0.040551      -0.048192      -0.041325
# AAACCTGGTGCAACGA-1 -0.031848          -0.050805      -0.032707      -0.026007
# ...                      ...                ...            ...            ...
# TTTGTCAGTCAAAGCG-1 -0.000286          -0.020601      -0.008356      -0.048938
# TTTGTCAGTCTCATCC-1 -0.035301          -0.005019      -0.030667       0.022408
# TTTGTCAGTGCGCTTG-1 -0.006209          -0.065754      -0.007720      -0.050960
# TTTGTCAGTTGGACCC-1 -0.034643          -0.040710      -0.029081      -0.025422
# TTTGTCATCAAACGGG-1 -0.043623          -0.012227      -0.042802      -0.014722
#
#                    T.CD8.TE_score T.gd.Vd2_score T.gd.non.Vd2_score  \
# AAACCTGAGTCAAGGC-1      -0.026599      -0.031382          -0.031110
# AAACCTGCAATGTAAG-1      -0.016364      -0.022118          -0.016384
# AAACCTGCATGCAACT-1      -0.014520       0.002730          -0.014538
# AAACCTGGTCTGGTCG-1      -0.052492      -0.047070          -0.039916
# AAACCTGGTGCAACGA-1      -0.026221      -0.039979          -0.038085
# ...                           ...            ...                ...
# TTTGTCAGTCAAAGCG-1      -0.061731      -0.011153          -0.045939
# TTTGTCAGTCTCATCC-1       0.011857       0.008999           0.007782
# TTTGTCAGTGCGCTTG-1      -0.059562      -0.051967          -0.059636
# TTTGTCAGTTGGACCC-1      -0.029621      -0.030174          -0.029658
# TTTGTCATCAAACGGG-1      -0.013782      -0.023187          -0.013799
#
#                     leiden_r1_prot
# AAACCTGAGTCAAGGC-1               1
# AAACCTGCAATGTAAG-1               3
# AAACCTGCATGCAACT-1               0
# AAACCTGGTCTGGTCG-1               1
# AAACCTGGTGCAACGA-1               1
# ...                            ...
# TTTGTCAGTCAAAGCG-1               0
# TTTGTCAGTCTCATCC-1               0
# TTTGTCAGTGCGCTTG-1               3
# TTTGTCAGTTGGACCC-1               0
# TTTGTCATCAAACGGG-1               0
#
# [2683 rows x 52 columns]

# %%
eg_norm.obs['predicted.id'].unique().tolist()
# Out:
# ['Promonocyte',
#  'Late erythoid precursor 2',
#  'CD14+ monocyte 1',
#  '7_immatureB',
#  '4_proB_G1',
#  'NK',
#  'NK T 2',
#  '3_proB_G2MS',
#  'NK T 1',
#  'Conventional dendritic cell',
#  '6_preB-II_G1',
#  'Early erythoid precursor',
#  'HSC',
#  'Plasmacytoid dendritic cell',
#  'CD4+ T 3',
#  'CD16+ monocyte',
#  'Late erythoid precursor 1',
#  'Late erythoid precursor 3']

# %%
eg_norm_blasts=eg_norm[eg_norm.obs['predicted.id'] == '7_immatureB']

eg_norm_blasts=eg_norm_blasts.to_df()

eg_norm_blasts
# Out:
#                         CD19      CD10      CD20       CD3       CD2  \
# AAACCTGGTGCAACGA-1  1.595911  4.454080  0.445859  0.351624  0.934145
# AAACGGGCAAATTGCC-1  1.454365  2.970697  0.493550  0.241754  0.647941
# AAACGGGCAACACCTA-1  1.896866  4.269662  0.623520  0.146142  0.664831
# AAAGTAGCAAGCCCAC-1  1.908461  2.351867  2.342398  0.000000  0.402167
# AACACGTAGGCTACGA-1  1.601687  3.533310  0.457246  0.326767  0.934489
# ...                      ...       ...       ...       ...       ...
# TTGCCGTGTTCCGGCA-1  1.777177  2.646296  0.393177  0.253873  0.091974
# TTGGCAAAGAGACTTA-1  0.699785  3.865756  0.225804  0.000000  0.760798
# TTTACTGCAGCCTATA-1  1.422328  2.980388  0.441675  0.169830  0.441675
# TTTCCTCAGGACATTA-1  1.057841  3.943897  0.360384  0.135079  0.624740
# TTTGGTTTCGCGGATC-1  1.279695  3.124023  0.500100  0.000000  0.758724
#
#                        CD11b     HLADR      CD38     CD11c       CD7  ...  \
# AAACCTGGTGCAACGA-1  0.351624  0.611257  0.611257  0.247575  0.000000  ...
# AAACGGGCAAATTGCC-1  0.822526  1.715239  0.310891  0.310891  0.375556  ...
# AAACGGGCAACACCTA-1  0.488238  1.422436  0.580428  0.488238  0.146142  ...
# AAAGTAGCAAGCCCAC-1  0.583387  0.910346  0.094412  0.466292  0.094412  ...
# AACACGTAGGCTACGA-1  0.254532  1.842780  0.676100  0.676100  0.254532  ...
# ...                      ...       ...       ...       ...       ...  ...
# TTGCCGTGTTCCGGCA-1  0.722559  2.659866  0.393177  1.777177  0.091974  ...
# TTGGCAAAGAGACTTA-1  0.225804  1.262232  0.760798  0.565308  0.225804  ...
# TTTACTGCAGCCTATA-1  0.746982  2.106453  0.441675  0.554123  0.000000  ...
# TTTCCTCAGGACATTA-1  0.894563  1.802029  0.254063  0.135079  0.135079  ...
# TTTGGTTTCGCGGATC-1  0.758724  1.946223  0.150333  0.831940  0.396535  ...
#
#                          CD5      CD15      CD64     CD117      CD24  \
# AAACCTGGTGCAACGA-1  0.351624  0.531974  0.445859  1.038845  0.531974
# AAACGGGCAAATTGCC-1  0.547706  0.694527  0.310891  0.694527  0.739039
# AAACGGGCAACACCTA-1  0.273624  0.386677  0.273624  0.488238  1.033058
# AAAGTAGCAAGCCCAC-1  0.180674  0.783055  0.094412  0.827310  0.402167
# AACACGTAGGCTACGA-1  0.394133  0.516611  0.254532  0.572648  0.572648
# ...                      ...       ...       ...       ...       ...
# TTGCCGTGTTCCGGCA-1  0.176196  0.571369  0.091974  0.571369  0.325949
# TTGGCAAAGAGACTTA-1  0.565308  0.699785  0.490618  0.760798  0.924251
# TTTACTGCAGCCTATA-1  0.314962  0.554123  0.314962  0.441675  0.746982
# TTTCCTCAGGACATTA-1  0.360384  0.360384  0.624740  0.456479  0.624740
# TTTGGTTTCGCGGATC-1  0.500100  0.500100  0.280992  0.758724  0.396535
#
#                         CD44      CD58   CD66ace      CD13      CD34
# AAACCTGGTGCAACGA-1  2.623339  1.038845  0.753142  0.247575  1.220176
# AAACGGGCAAATTGCC-1  1.986510  1.005049  0.694527  0.167479  0.971113
# AAACGGGCAACACCTA-1  2.867986  0.882214  0.075738  0.000000  1.235206
# AAAGTAGCAAGCCCAC-1  4.064384  0.949414  0.402167  0.094412  0.637164
# AACACGTAGGCTACGA-1  2.525546  0.934489  0.572648  0.176671  0.813617
# ...                      ...       ...       ...       ...       ...
# TTGCCGTGTTCCGGCA-1  3.226064  1.168054  0.624346  0.176196  0.811983
# TTGGCAAAGAGACTTA-1  2.222808  1.064702  1.396234  0.119262  0.634805
# TTTACTGCAGCCTATA-1  2.272112  1.328812  0.655195  0.000000  0.980554
# TTTCCTCAGGACATTA-1  2.035075  0.544144  0.456479  0.254063  1.464739
# TTTGGTTTCGCGGATC-1  2.135607  0.900158  0.280992  0.150333  0.679722
#
# [363 rows x 33 columns]

# %%
#Checking what king of values we have for EG24

egflow=flow[flow['EG_code'] == 'EG21'].dropna(axis=1)

egflow
# Out:
#   EG_code  CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0    EG21   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
#drop EG_code

egflow=egflow.drop("EG_code", axis=1)

egflow
# Out:
#    CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
df=egflow * 100 #multiplied by 100 to get percentages

df1=df.T

df1.plot.bar(xlabel="Marker", ylabel="% of blasts",
            figsize= (15,8),
           fontsize="large") ;

plt.title('Blast phenotype', fontsize=20) ;

# %%
flow_markers=egflow.columns
flow_markers
# Out:
# Index(['CD10', 'CD19', ' CD22', 'CD33', 'CD34', 'CD38', 'HLA-DR'], dtype='object')

# %%
#Selecting common markers between flow and cite-seq

listOfMarkers=flow_markers
column_names=list()    #list including the common markers

for x in listOfMarkers:
    if x in adata_21_leukemic.columns:
        print(x, "Yes")
        column_names.append(x)
    else:
        print(x, "No") 
        
print(column_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 7
#       4 column_names=list()    #list including the common markers
#       6 for x in listOfMarkers:
# ----> 7     if x in adata_21_leukemic.columns:
#       8         print(x, "Yes")
#       9         column_names.append(x)
#
# AttributeError: 'AnnData' object has no attribute 'columns'

# %%
eg_norm_blasts.shape
# Out:
# (363, 33)

# %%
#Number of all cells for calculations

all_cells=len(eg_norm_blasts)

all_cells
# Out:
# 363

# %%
#Only leukemic cells selected

#model
gmm = sklearn.mixture.GaussianMixture(n_components = 2,
                                      covariance_type = "full",
                                      random_state = 42
                                        )
#data

data=eg_norm_blasts
n_cells=len(eg_norm_blasts)
egflow=egflow * 100 #to get percentages
for column_name in column_names:
    fig, ax =plt.subplots(1,2,tight_layout=True, figsize=(15, 5))
    fig.show()
    
    x= data[column_name]
    x=x.values.reshape(-1, 1)
    gmm.fit(x)
    labels = gmm.predict(x)
    
    ax1 = sns.kdeplot(data=data, x=column_name, hue=labels, multiple="stack", ax=ax[0]) ;
    ax1.title.set_text('GMM')
       
    #Calculate zeros
    n_zeros = np.count_nonzero(labels==0)
    result_zeros=(n_zeros/n_cells * 100)
    #Calculate ones
    n_ones=np.count_nonzero(labels)
    result_ones=(n_ones/n_cells * 100)
    #Dataframes
    all_data = {"GMM":[result_ones],
        "Flow": egflow[column_name],
        };

    all_data= pd.DataFrame(data=all_data);
    
    ax2=all_data.plot.bar(rot=15, title=column_name,ax=ax[1]);
    ax2.title.set_text('Proportions')
    
    plt.show()

# %% [markdown]
# ### Notes:
#
# Here CD34 is interesting, since based on flow cytometry 44% blasts were CD34 positive. Proportion is quite similar in CITE-seq. For other markers blasts were 100% positive and GMM here is forced to divide populations into 2 groups, so comparisons are not reliable.

# %% [markdown]
# ## DSB Normalized

# %%
adata_prot_dsb= sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_prot_dsb (1).h5ad')

# %%
eg_norm_dsb=adata_prot_dsb[adata_prot_dsb.obs['EG_code'] == 'EG21']

# %%
eg_norm_dsb.obs['predicted.id'].unique().tolist()
# Out:
# ['Promonocyte',
#  'Late erythoid precursor 2',
#  'CD14+ monocyte 1',
#  '7_immatureB',
#  '4_proB_G1',
#  'NK',
#  'NK T 2',
#  '3_proB_G2MS',
#  'NK T 1',
#  'Conventional dendritic cell',
#  '6_preB-II_G1',
#  'Early erythoid precursor',
#  'HSC',
#  'Plasmacytoid dendritic cell',
#  'CD4+ T 3',
#  'CD16+ monocyte',
#  'Late erythoid precursor 1',
#  'Late erythoid precursor 3']

# %%
#So few cells assigned as HSC, so no need to include to calculations

eg_norm_dsb[eg_norm.obs['predicted.id'] == 'HSC']
# Out:
# View of AnnData object with n_obs × n_vars = 4 × 33
#     obs: 'nCount_RNA', 'nFeature_RNA', 'bc', 'propmt', 'rna_size', 'ngene', 'prot_size', 'predicted.id', 'hashMax', 'adtMax', 'nHashPos', 'HTO_maxID', 'HTO_secondID', 'HTO_margin', 'HTO_classification', 'HTO_classification.global', 'hash.ID', 'EG_code', 'Donor', 'prediction.score.CD14..monocyte.1', 'prediction.score.CD14..monocyte.2', 'prediction.score.NK', 'prediction.score.CD4..T.1', 'prediction.score.NK.T.1', 'prediction.score.NK.T.2', 'prediction.score.CD4..T.3', 'prediction.score.Conventional.dendritic.cell', 'prediction.score.7_immatureB', 'prediction.score.Late.erythoid.precursor.2', 'prediction.score.Early.erythoid.precursor', 'prediction.score.max', 'n_genes', 'S_score', 'G2M_score', 'phase', 'leiden', 'leiden_r1', 'T.CD4.Naive_score', 'T.CD4.TE_score', 'Tregs_score', 'Tfh_score', 'Th1_score', 'Th1.Th17_score', 'Th17_score', 'Th2_score', 'T.CD8.Naive_score', 'T.CD8.CM_score', 'T.CD8.EM_score', 'T.CD8.TE_score', 'T.gd.Vd2_score', 'T.gd.non.Vd2_score', 'leiden_r1_prot'
#     obsm: 'X_pca', 'X_umap'

# %%
eg_norm_dsb_blasts=eg_norm_dsb[eg_norm.obs['predicted.id'] == '7_immatureB']

eg_norm_dsb_blasts=eg_norm_dsb_blasts.to_df()

eg_norm_dsb_blasts
# Out:
#                         CD19       CD10       CD20       CD3       CD2  \
# AAACCTGGTGCAACGA-1  4.438221   9.818531   0.673002  1.251178  2.093786
# AAACGGGCAAATTGCC-1  5.463347   4.972658   2.073623  1.251178  1.793434
# AAACGGGCAACACCTA-1  8.565085  11.589087   3.597984  0.519090  2.380162
# AAAGTAGCAAGCCCAC-1  7.560582   1.783361  15.208297 -1.148463  0.022469
# AACACGTAGGCTACGA-1  6.016994   7.294318   1.636283  1.928986  3.408543
# ...                      ...        ...        ...       ...       ...
# TTGCCGTGTTCCGGCA-1  6.977696   3.246576   1.170709  1.251178 -1.886838
# TTGGCAAAGAGACTTA-1  0.428962   7.606183  -0.439025 -1.148463  1.477674
# TTTACTGCAGCCTATA-1  2.604528   1.994004   0.138395 -0.276735 -0.858457
# TTTCCTCAGGACATTA-1  1.744193   7.371130   0.138395 -0.276735  0.419767
# TTTGGTTTCGCGGATC-1  2.402029   3.183538   0.673002 -1.148463  0.792971
#
#                        CD11b      HLADR      CD38      CD11c       CD7  ...  \
# AAACCTGGTGCAACGA-1 -0.801853   0.103473  3.892249  -0.673949 -1.143406  ...
# AAACGGGCAAATTGCC-1  2.093245   8.042543  2.477962   0.382520  2.947603  ...
# AAACGGGCAACACCTA-1  0.734802   6.947437  6.255655   2.104898  0.696158  ...
# AAAGTAGCAAGCCCAC-1  0.734802   2.784077 -0.076286   1.297674 -0.181758  ...
# AACACGTAGGCTACGA-1 -0.801853   8.523316  6.255655   2.826984  1.503763  ...
# ...                      ...        ...       ...        ...       ...  ...
# TTGCCGTGTTCCGGCA-1  1.462706  13.465580  3.208695  10.469584 -0.181758  ...
# TTGGCAAAGAGACTTA-1 -1.179817   3.879184  5.712387   1.297674  0.696158  ...
# TTTACTGCAGCCTATA-1  0.178627   6.826090  1.693054   0.382520 -1.143406  ...
# TTTCCTCAGGACATTA-1  1.232317   6.314593  0.845288  -1.270280 -0.181758  ...
# TTTGGTTTCGCGGATC-1  0.464898   6.575785 -0.076286   2.104898  1.503763  ...
#
#                          CD5      CD15      CD64     CD117      CD24  \
# AAACCTGGTGCAACGA-1  0.013102 -0.123091  0.761975  1.365123  1.904487
# AAACGGGCAAATTGCC-1  2.330204  1.809987  0.761975  0.979756  5.049341
# AAACGGGCAACACCTA-1  0.540772  0.247691  0.761975  0.326756  8.378726
# AAAGTAGCAAGCCCAC-1 -0.556825  2.077251 -0.820336  1.365123  1.904487
# AACACGTAGGCTACGA-1  1.032022  0.595988  0.275738  0.326756  3.401579
# ...                      ...       ...       ...       ...       ...
# TTGCCGTGTTCCGGCA-1 -0.556825  0.924371 -0.820336  0.326756  1.337968
# TTGGCAAAGAGACTTA-1  1.491555  0.924371  1.214650  0.555791  5.049341
# TTTACTGCAGCCTATA-1 -0.556825 -0.519465 -0.249437 -1.051770  2.434431
# TTTCCTCAGGACATTA-1  0.013102 -0.945225  1.638099 -0.737840  2.434431
# TTTGGTTTCGCGGATC-1  0.540772 -0.519465 -0.249437  0.084627  0.729447
#
#                          CD44      CD58   CD66ace      CD13      CD34
# AAACCTGGTGCAACGA-1  10.279908  0.814389  3.184479  1.122140  3.073448
# AAACGGGCAAATTGCC-1   8.914554  1.921968  4.416416  1.122140  3.290128
# AAACGGGCAACACCTA-1  14.631759  1.754297 -0.751278 -0.970308  5.562322
# AAAGTAGCAAGCCCAC-1  20.070246  1.400199  1.727408  0.123538  0.979814
# AACACGTAGGCTACGA-1  11.639812  1.400199  3.184479  1.122140  2.118124
# ...                       ...       ...       ...       ...       ...
# TTGCCGTGTTCCGGCA-1  15.556311  2.539359  3.616572  1.122140  2.118124
# TTGGCAAAGAGACTTA-1   8.625781  1.212798  8.267154  0.123538  0.317129
# TTTACTGCAGCCTATA-1   7.100566  1.212798  1.727408 -0.970308  0.979814
# TTTCCTCAGGACATTA-1   7.002198 -1.227995  1.176033  1.122140  4.269048
# TTTGGTTTCGCGGATC-1   7.002198 -0.098498 -0.055904  0.123538 -0.044073
#
# [363 rows x 33 columns]

# %%
#Checking what king of values we have for EG24

egflow_dsb=flow[flow['EG_code'] == 'EG21'].dropna(axis=1)

egflow_dsb
# Out:
#   EG_code  CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0    EG21   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
#drop EG_code

egflow_dsb=egflow_dsb.drop("EG_code", axis=1)

egflow_dsb
# Out:
#    CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
df=egflow_dsb * 100 #multiplied by 100 to get percentages

df1=df.T

df1.plot.bar(xlabel="Marker", ylabel="% of blasts",
            figsize= (15,8),
           fontsize="large") ;

plt.title('Blast phenotype', fontsize=20) ;

# %%
flow_markers_dsb=egflow_dsb.columns
flow_markers_dsb
# Out:
# Index(['CD10', 'CD19', ' CD22', 'CD33', 'CD34', 'CD38', 'HLA-DR'], dtype='object')

# %%
#Selecting common markers between flow and cite-seq

listOfMarkers=flow_markers_dsb
column_names=list()    #list including the common markers

for x in listOfMarkers:
    if x in eg_norm_dsb_blasts.columns:
        print(x, "Yes")
        column_names.append(x)
    else:
        print(x, "No") 
        
print(column_names)
# Out:
# CD10 Yes
# CD19 Yes
#  CD22 No
# CD33 Yes
# CD34 Yes
# CD38 Yes
# HLA-DR No
# ['CD10', 'CD19', 'CD33', 'CD34', 'CD38']

# %%
#Only leukemic cells selected

#model
gmm = sklearn.mixture.GaussianMixture(n_components = 2,
                                      covariance_type = "full",
                                      random_state = 42
                                        )
#data

data_dsb=eg_norm_dsb_blasts
n_cells=len(eg_norm_dsb_blasts)
egflow=egflow_dsb * 100 #to get percentages
for column_name in column_names:
    fig, ax =plt.subplots(1,2,tight_layout=True, figsize=(15, 5))
    fig.show()
    
    x1= data[column_name]
    x1=x1.values.reshape(-1, 1)
    gmm.fit(x1)
    labels1 = gmm.predict(x1)
    
    ax1 = sns.kdeplot(data=data_dsb, x=column_name, hue=labels1, multiple="stack", ax=ax[0]) ;
    ax1.title.set_text('GMM')
       
    #Calculate zeros
    n_zeros = np.count_nonzero(labels1==0)
    result_zeros1=(n_zeros/n_cells * 100)
    #Calculate ones
    n_ones=np.count_nonzero(labels1)
    result_ones1=(n_ones/n_cells * 100)
    #Dataframes
    all_data1 = {"GMM":[result_ones1],
        "Flow": egflow[column_name],
        };

    all_data1= pd.DataFrame(data=all_data1);
    
    ax2=all_data1.plot.bar(rot=15, title=column_name,ax=ax[1]);
    ax2.title.set_text('Proportions')
    
    plt.show()

# %% [markdown]
# ## Preparing files

# %%
#get flow data

flow= pd.read_csv('/Users/tiinatuononen/Desktop/Thesis/Project/data/flow.csv')

# %%
#Checking what king of values we have for EG24

egflow=flow[flow['EG_code'] == 'EG21'].dropna(axis=1)

egflow
# Out:
#   EG_code  CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0    EG21   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
#drop EG_code

egflow=egflow.drop("EG_code", axis=1)

egflow
# Out:
#    CD10  CD19   CD22  CD33  CD34  CD38  HLA-DR
# 0   1.0   1.0    1.0  0.44   1.0   1.0     1.0

# %%
df=egflow * 100 #multiplied by 100 to get percentages

df1=df.T

df1.plot.bar(xlabel="Marker", ylabel="% of blasts",
            figsize= (15,8),
           fontsize="large") ;

plt.title('Blast phenotype', fontsize=20) ;

# %%
#raw protein data, all datasets

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/healthy_malig_!m.h5ad')

adata.shape
# Out:
# (298991, 8051)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 298991 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
#select EG21 sample from big anndata file
adata_21 = adata[adata.obs.eg_code == 'EG21'].copy()

# %% [markdown]
# ## CLR

# %%
#all CLR data

adata_prot_clr= sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_prot_clr (1).h5ad')

# %%
#selecting EG21 sample from normalized protein data

adata_21_clr = adata_prot_clr[adata_prot_clr.obs.EG_code == 'EG21']

# %%
adata_21
# Out:
# AnnData object with n_obs × n_vars = 2394 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_21_clr
# Out:
# View of AnnData object with n_obs × n_vars = 2683 × 33
#     obs: 'nCount_RNA', 'nFeature_RNA', 'bc', 'propmt', 'rna_size', 'ngene', 'prot_size', 'predicted.id', 'hashMax', 'adtMax', 'nHashPos', 'HTO_maxID', 'HTO_secondID', 'HTO_margin', 'HTO_classification', 'HTO_classification.global', 'hash.ID', 'EG_code', 'Donor', 'prediction.score.CD14..monocyte.1', 'prediction.score.CD14..monocyte.2', 'prediction.score.NK', 'prediction.score.CD4..T.1', 'prediction.score.NK.T.1', 'prediction.score.NK.T.2', 'prediction.score.CD4..T.3', 'prediction.score.Conventional.dendritic.cell', 'prediction.score.7_immatureB', 'prediction.score.Late.erythoid.precursor.2', 'prediction.score.Early.erythoid.precursor', 'prediction.score.max', 'n_genes', 'S_score', 'G2M_score', 'phase', 'leiden', 'leiden_r1', 'T.CD4.Naive_score', 'T.CD4.TE_score', 'Tregs_score', 'Tfh_score', 'Th1_score', 'Th1.Th17_score', 'Th17_score', 'Th2_score', 'T.CD8.Naive_score', 'T.CD8.CM_score', 'T.CD8.EM_score', 'T.CD8.TE_score', 'T.gd.Vd2_score', 'T.gd.non.Vd2_score', 'leiden_r1_prot'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts'

# %%
adata_21.obs["cell_type"] == "leukemic"
# Out:
# AAACCTGAGTCAAGGC-1     True
# AAACCTGCAATGTAAG-1     True
# AAACCTGCATGCAACT-1     True
# AAACCTGGTCTGGTCG-1     True
# AAACCTGGTGCAACGA-1     True
#                       ...
# TTTGTCACAGTCGTGC-1     True
# TTTGTCAGTCTCATCC-1     True
# TTTGTCAGTGCGCTTG-1     True
# TTTGTCAGTTGGACCC-1     True
# TTTGTCATCAAACGGG-1    False
# Name: cell_type, Length: 2394, dtype: bool

# %%
adata_21_clr.obs.index
# Out:
# Index(['AAACCTGAGTCAAGGC-1', 'AAACCTGCAATGTAAG-1', 'AAACCTGCATGCAACT-1',
#        'AAACCTGGTCTGGTCG-1', 'AAACCTGGTGCAACGA-1', 'AAACGGGAGCGGATCA-1',
#        'AAACGGGCAAAGCGGT-1', 'AAACGGGCAAATTGCC-1', 'AAACGGGCAACACCTA-1',
#        'AAACGGGCACGAGGTA-1',
#        ...
#        'TTTGGTTCATGTTCCC-1', 'TTTGGTTTCAGGCGAA-1', 'TTTGGTTTCGCGGATC-1',
#        'TTTGTCACAGTCGTGC-1', 'TTTGTCACATGCAATC-1', 'TTTGTCAGTCAAAGCG-1',
#        'TTTGTCAGTCTCATCC-1', 'TTTGTCAGTGCGCTTG-1', 'TTTGTCAGTTGGACCC-1',
#        'TTTGTCATCAAACGGG-1'],
#       dtype='object', length=2683)

# %%
adata_21.obs.index
# Out:
# Index(['AAACCTGAGTCAAGGC-1-132', 'AAACCTGCAATGTAAG-1-132',
#        'AAACCTGCATGCAACT-1-132', 'AAACCTGGTCTGGTCG-1-132',
#        'AAACCTGGTGCAACGA-1-132', 'AAACGGGAGCGGATCA-1-132',
#        'AAACGGGCAAAGCGGT-1-132', 'AAACGGGCAAATTGCC-1-132',
#        'AAACGGGCAACACCTA-1-132', 'AAACGGGCACGAGGTA-1-132',
#        ...
#        'TTTGGTTCACCGCTAG-1-132', 'TTTGGTTCATCACGAT-1-132',
#        'TTTGGTTCATGTTCCC-1-132', 'TTTGGTTTCAGGCGAA-1-132',
#        'TTTGGTTTCGCGGATC-1-132', 'TTTGTCACAGTCGTGC-1-132',
#        'TTTGTCAGTCTCATCC-1-132', 'TTTGTCAGTGCGCTTG-1-132',
#        'TTTGTCAGTTGGACCC-1-132', 'TTTGTCATCAAACGGG-1-132'],
#       dtype='object', length=2394)

# %%
#remove identifiers from the ends

def remove_tail(x):
    return x[:-4]
adata_21.obs.index = pd.Index(pd.Series(adata_21.obs.index).apply(remove_tail))

# %%
adata_21
# Out:
# AnnData object with n_obs × n_vars = 2394 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_21_clr
# Out:
# View of AnnData object with n_obs × n_vars = 2683 × 33
#     obs: 'nCount_RNA', 'nFeature_RNA', 'bc', 'propmt', 'rna_size', 'ngene', 'prot_size', 'predicted.id', 'hashMax', 'adtMax', 'nHashPos', 'HTO_maxID', 'HTO_secondID', 'HTO_margin', 'HTO_classification', 'HTO_classification.global', 'hash.ID', 'EG_code', 'Donor', 'prediction.score.CD14..monocyte.1', 'prediction.score.CD14..monocyte.2', 'prediction.score.NK', 'prediction.score.CD4..T.1', 'prediction.score.NK.T.1', 'prediction.score.NK.T.2', 'prediction.score.CD4..T.3', 'prediction.score.Conventional.dendritic.cell', 'prediction.score.7_immatureB', 'prediction.score.Late.erythoid.precursor.2', 'prediction.score.Early.erythoid.precursor', 'prediction.score.max', 'n_genes', 'S_score', 'G2M_score', 'phase', 'leiden', 'leiden_r1', 'T.CD4.Naive_score', 'T.CD4.TE_score', 'Tregs_score', 'Tfh_score', 'Th1_score', 'Th1.Th17_score', 'Th17_score', 'Th2_score', 'T.CD8.Naive_score', 'T.CD8.CM_score', 'T.CD8.EM_score', 'T.CD8.TE_score', 'T.gd.Vd2_score', 'T.gd.non.Vd2_score', 'leiden_r1_prot'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts'

# %%
#removing cells that are not common between data files

selector = adata_21_clr.obs.index.isin(adata_21.obs.index)

# %%
selector
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
import numpy as np

selector_test = np.array([True,True,False])

# %%
selector_test.sum()
# Out:
# 2

# %%
selector.shape
# Out:
# (2683,)

# %%
selector.sum()
# Out:
# 2394

# %%
#includes only common cells
selected_df = adata_21_clr.to_df()[selector]

# %%
#normalized protein counts

selected_df
# Out:
#                         CD19      CD10      CD20       CD3       CD2  \
# AAACCTGAGTCAAGGC-1  1.585178  3.925845  0.369983  0.261190  0.785678
# AAACCTGCAATGTAAG-1  1.166373  3.874398  0.219611  0.000000  1.240089
# AAACCTGCATGCAACT-1  1.306791  3.190385  0.388973  0.000000  0.949680
# AAACCTGGTCTGGTCG-1  1.441796  4.764038  0.173869  0.000000  0.667571
# AAACCTGGTGCAACGA-1  1.595911  4.454080  0.445859  0.351624  0.934145
# ...                      ...       ...       ...       ...       ...
# TTTGTCACAGTCGTGC-1  1.897901  4.123756  0.135783  0.362069  0.702121
# TTTGTCAGTCTCATCC-1  1.178223  3.234642  0.446062  0.202826  1.068602
# TTTGTCAGTGCGCTTG-1  1.250635  4.134897  0.153726  0.404473  0.509635
# TTTGTCAGTTGGACCC-1  1.254844  3.313349  0.471097  0.337305  0.406437
# TTTGTCATCAAACGGG-1  0.957551  2.639271  0.674568  0.000000  0.826036
#
#                        CD11b     HLADR      CD38     CD11c       CD7  ...  \
# AAACCTGAGTCAAGGC-1  0.557433  1.522067  0.715231  0.139098  0.139098  ...
# AAACCTGCAATGTAAG-1  0.552031  1.595232  0.399571  0.000000  0.801087  ...
# AAACCTGCATGCAACT-1  0.746412  0.746412  0.000000  0.668306  0.275339  ...
# AAACCTGGTCTGGTCG-1  0.565084  1.127812  0.321937  0.173869  0.000000  ...
# AAACCTGGTGCAACGA-1  0.351624  0.611257  0.611257  0.247575  0.000000  ...
# ...                      ...       ...       ...       ...       ...  ...
# TTTGTCACAGTCGTGC-1  0.627326  2.501298  0.897853  0.546481  0.000000  ...
# TTTGTCAGTCTCATCC-1  0.805014  1.366901  0.290645  0.202826  0.446062  ...
# TTTGTCAGTGCGCTTG-1  0.771586  0.978968  0.286938  0.286938  0.286938  ...
# TTTGTCAGTTGGACCC-1  1.031492  1.413190  0.471097  0.743464  0.406437  ...
# TTTGTCATCAAACGGG-1  0.957551  1.127167  0.278436  0.278436  0.278436  ...
#
#                          CD5      CD15      CD64     CD117      CD24  \
# AAACCTGAGTCAAGGC-1  0.261190  0.557433  0.261190  0.851488  1.026343
# AAACCTGCAATGTAAG-1  0.000000  0.219611  0.399571  0.000000  0.219611
# AAACCTGCATGCAACT-1  0.746412  0.746412  0.275339  0.388973  0.746412
# AAACCTGGTCTGGTCG-1  0.760523  0.565084  0.450883  0.173869  0.760523
# AAACCTGGTGCAACGA-1  0.351624  0.531974  0.445859  1.038845  0.531974
# ...                      ...       ...       ...       ...       ...
# TTTGTCACAGTCGTGC-1  0.362069  0.546481  0.135783  0.135783  0.836769
# TTTGTCAGTCTCATCC-1  0.753441  0.945468  0.202826  0.699064  0.202826
# TTTGTCAGTGCGCTTG-1  0.404473  0.845596  0.286938  0.509635  0.978968
# TTTGTCAGTTGGACCC-1  0.589082  0.471097  0.337305  0.743464  0.337305
# TTTGTCATCAAACGGG-1  0.753167  0.674568  0.393117  0.589260  0.393117
#
#                         CD44      CD58   CD66ace      CD13      CD34
# AAACCTGAGTCAAGGC-1  2.627156  0.971387  0.139098  0.000000  1.644541
# AAACCTGCAATGTAAG-1  1.776958  1.000317  0.399571  0.219611  1.595232
# AAACCTGCATGCAACT-1  1.306791  0.949680  0.388973  0.000000  1.118529
# AAACCTGGTCTGGTCG-1  1.983298  1.395845  0.760523  0.173869  1.607011
# AAACCTGGTGCAACGA-1  2.623339  1.038845  0.753142  0.247575  1.220176
# ...                      ...       ...       ...       ...       ...
# TTTGTCACAGTCGTGC-1  2.743628  1.469015  0.135783  0.135783  1.202048
# TTTGTCAGTCTCATCC-1  1.907157  1.596361  0.446062  0.202826  1.245150
# TTTGTCAGTGCGCTTG-1  2.941616  1.096627  0.691658  0.000000  1.150641
# TTTGTCAGTTGGACCC-1  1.760268  1.742868  0.263037  0.263037  0.834556
# TTTGTCATCAAACGGG-1  0.826036  0.893954  0.674568  0.278436  1.177864
#
# [2394 rows x 33 columns]

# %%
adata_21.obsm['protein_expression_clr'] = selected_df

adata_21.obsm
# Out:
# AxisArrays with keys: X_pca, X_totalVI, X_umap, protein_expression, protein_expression_clr

# %%
selected_df.index
# Out:
# Index(['AAACCTGAGTCAAGGC-1', 'AAACCTGCAATGTAAG-1', 'AAACCTGCATGCAACT-1',
#        'AAACCTGGTCTGGTCG-1', 'AAACCTGGTGCAACGA-1', 'AAACGGGAGCGGATCA-1',
#        'AAACGGGCAAAGCGGT-1', 'AAACGGGCAAATTGCC-1', 'AAACGGGCAACACCTA-1',
#        'AAACGGGCACGAGGTA-1',
#        ...
#        'TTTGGTTCACCGCTAG-1', 'TTTGGTTCATCACGAT-1', 'TTTGGTTCATGTTCCC-1',
#        'TTTGGTTTCAGGCGAA-1', 'TTTGGTTTCGCGGATC-1', 'TTTGTCACAGTCGTGC-1',
#        'TTTGTCAGTCTCATCC-1', 'TTTGTCAGTGCGCTTG-1', 'TTTGTCAGTTGGACCC-1',
#        'TTTGTCATCAAACGGG-1'],
#       dtype='object', length=2394)

# %%
adata_21.obs.index
# Out:
# Index(['AAACCTGAGTCAAGGC-1', 'AAACCTGCAATGTAAG-1', 'AAACCTGCATGCAACT-1',
#        'AAACCTGGTCTGGTCG-1', 'AAACCTGGTGCAACGA-1', 'AAACGGGAGCGGATCA-1',
#        'AAACGGGCAAAGCGGT-1', 'AAACGGGCAAATTGCC-1', 'AAACGGGCAACACCTA-1',
#        'AAACGGGCACGAGGTA-1',
#        ...
#        'TTTGGTTCACCGCTAG-1', 'TTTGGTTCATCACGAT-1', 'TTTGGTTCATGTTCCC-1',
#        'TTTGGTTTCAGGCGAA-1', 'TTTGGTTTCGCGGATC-1', 'TTTGTCACAGTCGTGC-1',
#        'TTTGTCAGTCTCATCC-1', 'TTTGTCAGTGCGCTTG-1', 'TTTGTCAGTTGGACCC-1',
#        'TTTGTCATCAAACGGG-1'],
#       dtype='object', length=2394)

# %%
adata_21.obs["cell_type"].unique
# Out:
# ['leukemic', 'leukemic?', 'doublets?', 'NKT', 'non-leukemic']
# Categories (5, object): ['NKT', 'doublets?', 'leukemic', 'leukemic?', 'non-leukemic']

# %%
adata_21_leukemic = adata_21[adata_21.obs.cell_type == 'leukemic']

eg21_blasts_clr=adata_21_leukemic.obsm['protein_expression']

# %%
eg21_blasts_clr
# Out:
#                         CD86  CD274  CD270  CD155  CD112  CD47  CD48  CD40  \
# AAACCTGAGTCAAGGC-1-132     0      0      0      0      0     0     0     0
# AAACCTGCAATGTAAG-1-132     0      0      0      0      0     0     0     0
# AAACCTGCATGCAACT-1-132     0      0      0      0      0     0     0     0
# AAACCTGGTCTGGTCG-1-132     0      0      0      0      0     0     0     0
# AAACCTGGTGCAACGA-1-132     0      0      0      0      0     0     0     0
# ...                      ...    ...    ...    ...    ...   ...   ...   ...
# TTTGGTTTCGCGGATC-1-132     0      0      0      0      0     0     0     0
# TTTGTCACAGTCGTGC-1-132     0      0      0      0      0     0     0     0
# TTTGTCAGTCTCATCC-1-132     0      0      0      0      0     0     0     0
# TTTGTCAGTGCGCTTG-1-132     0      0      0      0      0     0     0     0
# TTTGTCAGTTGGACCC-1-132     0      0      0      0      0     0     0     0
#
#                         CD154  CD52  ...  CD101  CD88  CD224  CD197  CD34  \
# AAACCTGAGTCAAGGC-1-132      0     0  ...      0     0      0      1    28
# AAACCTGCAATGTAAG-1-132      0     0  ...      0     0      0      0    16
# AAACCTGCATGCAACT-1-132      0     0  ...      0     0      0      2    13
# AAACCTGGTCTGGTCG-1-132      0     0  ...      0     0      0      0    21
# AAACCTGGTGCAACGA-1-132      0     0  ...      0     0      0      1    17
# ...                       ...   ...  ...    ...   ...    ...    ...   ...
# TTTGGTTTCGCGGATC-1-132      0     0  ...      0     0      0      3     6
# TTTGTCACAGTCGTGC-1-132      0     0  ...      0     0      0      4    16
# TTTGTCAGTCTCATCC-1-132      0     0  ...      0     0      0      3    22
# TTTGTCAGTGCGCTTG-1-132      0     0  ...      0     0      0      2    13
# TTTGTCAGTTGGACCC-1-132      0     0  ...      0     0      0      4    13
#
#                         CD10  CD90  CD15  CD117  CD66ace
# AAACCTGAGTCAAGGC-1-132   333     0     5      9        1
# AAACCTGCAATGTAAG-1-132   192     0     1      0        2
# AAACCTGCATGCAACT-1-132   147     0     7      3        3
# AAACCTGGTCTGGTCG-1-132   612     0     4      1        6
# AAACCTGGTGCAACGA-1-132   605     0     5     13        8
# ...                      ...   ...   ...    ...      ...
# TTTGGTTTCGCGGATC-1-132   134     0     4      7        2
# TTTGTCACAGTCGTGC-1-132   418     0     5      1        1
# TTTGTCAGTCTCATCC-1-132   217     0    14      9        5
# TTTGTCAGTGCGCTTG-1-132   370     0     8      4        6
# TTTGTCAGTTGGACCC-1-132   264     0     6     11        3
#
# [2105 rows x 141 columns]

# %%
df=egflow * 100 #multiplied by 100 to get percentages

df1=df.T

df1.plot.bar(xlabel="Marker", ylabel="% of blasts",
            figsize= (15,8),
           fontsize="large") ;

plt.title('Blast phenotype', fontsize=20) ;

# %%
#Selecting common markers between flow and cite-seq

listOfMarkers=flow_markers
column_names=list()    #list including the common markers

for x in listOfMarkers:
    if x in eg21_blasts_clr.columns:
        print(x, "Yes")
        column_names.append(x)
    else:
        print(x, "No") 
        
print(column_names)
# Out:
# CD10 Yes
# CD19 Yes
#  CD22 No
# CD33 Yes
# CD34 Yes
# CD38 Yes
# HLA-DR Yes
# ['CD10', 'CD19', 'CD33', 'CD34', 'CD38', 'HLA-DR']

# %%
#Only leukemic cells selected

#model
gmm = sklearn.mixture.GaussianMixture(n_components = 2,
                                      covariance_type = "full",
                                      random_state = 42
                                        )
#data

data=eg21_blasts_clr
n_cells=len(eg21_blasts_clr)
egflow=egflow * 100 #to get percentages
for column_name in column_names:
    fig, ax =plt.subplots(1,2,tight_layout=True, figsize=(15, 5))
    fig.show()
    
    x= data[column_name]
    x=x.values.reshape(-1, 1)
    gmm.fit(x)
    labels = gmm.predict(x)
    
    ax1 = sns.kdeplot(data=data, x=column_name, hue=labels, multiple="stack", ax=ax[0]) ;
    ax1.title.set_text('GMM')
       
    #Calculate zeros
    n_zeros = np.count_nonzero(labels==0)
    result_zeros=(n_zeros/n_cells * 100)
    #Calculate ones
    n_ones=np.count_nonzearo(labels)
    result_ones=(n_ones/n_cells * 100)
    #Dataframes
    all_data = {"GMM":[result_ones],
        "Flow": egflow[column_name],
        };

    all_data= pd.DataFrame(data=all_data);
    
    ax2=all_data.plot.bar(rot=15, title=column_name,ax=ax[1]);
    ax2.title.set_text('Proportions')
    
    plt.show()

# %% [markdown]
# ## DSB

# %%
adata_prot_dsb= sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_prot_dsb (1).h5ad')

# %%
adata_21_dsb=adata_prot_dsb[adata_prot_dsb.obs['EG_code'] == 'EG21']

# %%
adata_21_dsb.copy()
# Out:
# AnnData object with n_obs × n_vars = 2683 × 33
#     obs: 'nCount_RNA', 'nFeature_RNA', 'bc', 'propmt', 'rna_size', 'ngene', 'prot_size', 'predicted.id', 'hashMax', 'adtMax', 'nHashPos', 'HTO_maxID', 'HTO_secondID', 'HTO_margin', 'HTO_classification', 'HTO_classification.global', 'hash.ID', 'EG_code', 'Donor', 'prediction.score.CD14..monocyte.1', 'prediction.score.CD14..monocyte.2', 'prediction.score.NK', 'prediction.score.CD4..T.1', 'prediction.score.NK.T.1', 'prediction.score.NK.T.2', 'prediction.score.CD4..T.3', 'prediction.score.Conventional.dendritic.cell', 'prediction.score.7_immatureB', 'prediction.score.Late.erythoid.precursor.2', 'prediction.score.Early.erythoid.precursor', 'prediction.score.max', 'n_genes', 'S_score', 'G2M_score', 'phase', 'leiden', 'leiden_r1', 'T.CD4.Naive_score', 'T.CD4.TE_score', 'Tregs_score', 'Tfh_score', 'Th1_score', 'Th1.Th17_score', 'Th17_score', 'Th2_score', 'T.CD8.Naive_score', 'T.CD8.CM_score', 'T.CD8.EM_score', 'T.CD8.TE_score', 'T.gd.Vd2_score', 'T.gd.non.Vd2_score', 'leiden_r1_prot'
#     obsm: 'X_pca', 'X_umap'

# %%
adata_21
# Out:
# AnnData object with n_obs × n_vars = 2394 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr'
#     obsp: 'connectivities', 'distances'

# %%
adata_21.obs.index
# Out:
# Index(['AAACCTGAGTCAAGGC-1', 'AAACCTGCAATGTAAG-1', 'AAACCTGCATGCAACT-1',
#        'AAACCTGGTCTGGTCG-1', 'AAACCTGGTGCAACGA-1', 'AAACGGGAGCGGATCA-1',
#        'AAACGGGCAAAGCGGT-1', 'AAACGGGCAAATTGCC-1', 'AAACGGGCAACACCTA-1',
#        'AAACGGGCACGAGGTA-1',
#        ...
#        'TTTGGTTCACCGCTAG-1', 'TTTGGTTCATCACGAT-1', 'TTTGGTTCATGTTCCC-1',
#        'TTTGGTTTCAGGCGAA-1', 'TTTGGTTTCGCGGATC-1', 'TTTGTCACAGTCGTGC-1',
#        'TTTGTCAGTCTCATCC-1', 'TTTGTCAGTGCGCTTG-1', 'TTTGTCAGTTGGACCC-1',
#        'TTTGTCATCAAACGGG-1'],
#       dtype='object', length=2394)

# %%
adata_21_dsb.obs.index
# Out:
# Index(['AAACCTGAGTCAAGGC-1', 'AAACCTGCAATGTAAG-1', 'AAACCTGCATGCAACT-1',
#        'AAACCTGGTCTGGTCG-1', 'AAACCTGGTGCAACGA-1', 'AAACGGGAGCGGATCA-1',
#        'AAACGGGCAAAGCGGT-1', 'AAACGGGCAAATTGCC-1', 'AAACGGGCAACACCTA-1',
#        'AAACGGGCACGAGGTA-1',
#        ...
#        'TTTGGTTCATGTTCCC-1', 'TTTGGTTTCAGGCGAA-1', 'TTTGGTTTCGCGGATC-1',
#        'TTTGTCACAGTCGTGC-1', 'TTTGTCACATGCAATC-1', 'TTTGTCAGTCAAAGCG-1',
#        'TTTGTCAGTCTCATCC-1', 'TTTGTCAGTGCGCTTG-1', 'TTTGTCAGTTGGACCC-1',
#        'TTTGTCATCAAACGGG-1'],
#       dtype='object', length=2683)

# %%
#removing cells that are not common between data files

selector = adata_21_dsb.obs.index.isin(adata_21.obs.index)

# %%
#includes only common cells
selected_df = adata_21_dsb.to_df()[selector]

# %%
selected_df.shape
# Out:
# (2394, 33)

# %%
adata_21.obsm['protein_expression_dsb'] = selected_df

adata_21.obsm
# Out:
# AxisArrays with keys: X_pca, X_totalVI, X_umap, protein_expression, protein_expression_clr, protein_expression_dsb

# %%
adata_21_leukemic
# Out:
# View of AnnData object with n_obs × n_vars = 2105 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
eg21_blasts_dsb=adata_21_leukemic.obsm['protein_expression']

# %%
eg21_blasts_dsb.shape
# Out:
# (2105, 141)

# %%
#Selecting common markers between flow and cite-seq

listOfMarkers=flow_markers
column_names=list()    #list including the common markers

for x in listOfMarkers:
    if x in eg21_blasts_dsb.columns:
        print(x, "Yes")
        column_names.append(x)
    else:
        print(x, "No") 
        
print(column_names)
# Out:
# CD10 Yes
# CD19 Yes
#  CD22 No
# CD33 Yes
# CD34 Yes
# CD38 Yes
# HLA-DR Yes
# ['CD10', 'CD19', 'CD33', 'CD34', 'CD38', 'HLA-DR']

# %%
#Only leukemic cells selected

#model
gmm = sklearn.mixture.GaussianMixture(n_components = 2,
                                      covariance_type = "full",
                                      random_state = 42
                                        )
#data

data=eg21_blasts_dsb
n_cells=len(eg21_blasts_dsb)
egflow=egflow #* 100 #to get percentages
for column_name in column_names:
    fig, ax =plt.subplots(1,2,tight_layout=True, figsize=(15, 5))
    fig.show()
    
    x1= data[column_name]
    x1=x1.values.reshape(-1, 1)
    gmm.fit(x1)
    labels1 = gmm.predict(x1)
    
    ax1 = sns.kdeplot(data=data, x=column_name, hue=labels, multiple="stack", ax=ax[0]) ;
    ax1.title.set_text('GMM')
       
    #Calculate zeros
    n_zeros1 = np.count_nonzero(labels1==0)
    result_zeros1=(n_zeros1/n_cells * 100)
    #Calculate ones
    n_ones1=np.count_nonzero(labels1)
    result_ones1=(n_ones1/n_cells * 100)
    #Dataframes
    all_data1 = {"GMM":[result_ones1],
        "Flow": egflow[column_name],
        };

    all_data1= pd.DataFrame(data=all_data1);
    
    ax2=all_data1.plot.bar(rot=15, title=column_name,ax=ax[1]);
    ax2.title.set_text('Proportions')
    
    plt.show()

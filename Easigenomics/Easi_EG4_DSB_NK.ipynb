# %% [markdown]
# # Easi, EG4, DSB normalized proteins

# %% [markdown]
# - Diagnosis: MLL (mixed-lineage leukemia)
# - BM blasts: 90%

# %% [markdown]
# ### Comments:
# - in this sample, no cell type annotations offered, so this notebook is run for all cells in the sample
# - CD56 not expressed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
import umap

from ridgeplot import ridgeplot

import warnings

warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %%
#raw protein data, all datasets

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_easi_norm.h5ad')

# %%
adata.obs['batch_group']
# Out:
# AAACCTGAGCCCTAAT-1-100    Easi
# AAACCTGCAAGCCGCT-1-100    Easi
# AAACCTGCACTGTCGG-1-100    Easi
# AAACCTGCAGACGCTC-1-100    Easi
# AAACCTGTCCTTAATC-1-100    Easi
#                           ...
# TTTGTCAGTACATCCA-1-158    Easi
# TTTGTCAGTAGGCATG-1-158    Easi
# TTTGTCAGTATGCTTG-1-158    Easi
# TTTGTCATCAAACCAC-1-158    Easi
# TTTGTCATCCATGAAC-1-158    Easi
# Name: batch_group, Length: 121340, dtype: category
# Categories (1, object): ['Easi']

# %%
adata_easi=adata[adata.obs['batch_group'] == 'Easi' ]

adata_easi
# Out:
# View of AnnData object with n_obs × n_vars = 121340 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_easi.obs['POOL'].unique().tolist()
# Out:
# ['EG35',
#  'EG38',
#  'EG58',
#  'EG39',
#  'EG4',
#  'EG48',
#  'EG23',
#  'EG36',
#  'EG61',
#  'EG3',
#  'EG12',
#  'EG46',
#  'EG9',
#  'EG43',
#  'EG56',
#  'EG42',
#  'EG49',
#  'EG37',
#  'EG57',
#  'EG24',
#  'EG11',
#  'EG14',
#  'EG55',
#  'EG28',
#  'EG52',
#  'EG33',
#  'EG10',
#  'EG32',
#  'EG59',
#  'EG16',
#  'EG63',
#  'EG15',
#  'EG21',
#  'EG26',
#  'EG13',
#  'EG53',
#  'EG51',
#  'EG2',
#  'EG40',
#  'EG62',
#  'EG31',
#  'EG7',
#  'EG8',
#  'EG29',
#  'EG41',
#  'EG47',
#  'EG1',
#  'EG6',
#  'EG34',
#  'EG30',
#  'EG60',
#  'EG44',
#  'EG27',
#  'EG22',
#  'EG54',
#  'EG45',
#  'EG5',
#  'EG50',
#  'EG25']

# %%
adata_easi.obs['new_cell_type'].unique().tolist()
# Out:
# ['NK',
#  'non-leukemic',
#  'preleukemic',
#  'non-leukemic?',
#  nan,
#  'leukemic',
#  'leukemic?',
#  'doublets?',
#  'unknown',
#  '0',
#  'preleukemic?']

# %%
#select sample from Easigenomics dataset

adata_sample=adata_easi[adata_easi.obs['POOL'] == 'EG4']

# %%
adata_sample.copy()
# Out:
# AnnData object with n_obs × n_vars = 1587 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs['new_cell_type'].unique().tolist()
# Out:
# [nan]

# %%
adata_sample.obs['POOL'].unique().tolist()
# Out:
# ['EG4']

# %%
#Select only NK- and T-cells (based on new_cell_type annotations)

adata_nk=adata_sample[adata_sample.obs['new_cell_type'] == 'NK' ]

# %%
adata_nk.copy()
# Out:
# AnnData object with n_obs × n_vars = 0 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs['cell_type']
# Out:
# Series([], Name: cell_type, dtype: category
# Categories (0, object): [])

# %%
#surface protein expression of NK- and T-cells
nk_prot=adata_nk.obsm['protein_expression_dsb']

# %%
#surface protein expression of whole sample
prot=adata_sample.obsm['protein_expression_dsb']

# %%
prot
# Out:
#                              CD19      CD10      CD20        CD3        CD2  \
# AAACCTGCACATTTCT-1-104  -0.470350 -0.120521  0.282379   3.362817  13.962214
# AAACCTGCAGCTGCAC-1-104   4.237051  0.566333 -0.175960   4.652137  10.831782
# AAACCTGCATATACGC-1-104   6.990704  2.923814 -0.175960  10.769124  13.590271
# AAACCTGGTCTCGTTC-1-104   0.576541  0.026175 -0.175960  -0.249580  10.309246
# AAACCTGGTTAAGGGC-1-104  10.898200  0.437695 -0.671004  12.016969  13.224285
# ...                           ...       ...       ...        ...        ...
# TTTGCGCAGGCCGAAT-1-104   0.576541  0.812310  0.282379   2.617741   8.724289
# TTTGGTTCATATGGTC-1-104   3.330194 -0.430323  0.282379   6.904141  13.276577
# TTTGTCAAGCGAAGGG-1-104   1.895121  0.167897  2.171087   2.617741   9.036044
# TTTGTCAAGCTATGCT-1-104   2.650492 -0.594282  2.488322   0.840525  12.388309
# TTTGTCATCCGAACGC-1-104   6.799386 -0.594282  0.282379   0.316457  13.837808
#
#                            CD11b     HLADR       CD38     CD11c        CD7  \
# AAACCTGCACATTTCT-1-104  0.064143  0.115787   9.839499  2.923209  17.164001
# AAACCTGCAGCTGCAC-1-104  2.258044  1.261814  14.009034 -0.313231  15.748147
# AAACCTGCATATACGC-1-104  1.132779  1.261814  16.829803  1.497172  16.586756
# AAACCTGGTCTCGTTC-1-104 -0.161256  0.425784   6.659051  0.186893  15.380447
# AAACCTGGTTAAGGGC-1-104  0.272830  0.997203  17.556915  1.497172  17.421030
# ...                          ...       ...        ...       ...        ...
# TTTGCGCAGGCCGAAT-1-104  0.403829 -1.339132   4.890656  1.497172  15.804488
# TTTGGTTCATATGGTC-1-104 -0.971363  0.425784  19.543907  1.088041  19.900928
# TTTGTCAAGCGAAGGG-1-104  0.980526 -0.563030   6.391342 -0.853406  17.282829
# TTTGTCAAGCTATGCT-1-104  0.819569  0.115787   8.517623  1.497172  16.219280
# TTTGTCATCCGAACGC-1-104  2.355718 -1.339132  13.381646  4.619226  10.525496
#
#                         ...       CD5      CD15      CD64      CD117  \
# AAACCTGCACATTTCT-1-104  ...  2.495765 -1.286551  2.957214   8.997627
# AAACCTGCAGCTGCAC-1-104  ...  8.478506  0.735373 -0.178076   9.727426
# AAACCTGCATATACGC-1-104  ...  9.481717  0.594894  2.259780  11.436057
# AAACCTGGTCTCGTTC-1-104  ...  0.855526  0.872003  0.701503   8.803766
# AAACCTGGTTAAGGGC-1-104  ...  7.120286 -0.010294  0.701503  11.709554
# ...                     ...       ...       ...       ...        ...
# TTTGCGCAGGCCGAAT-1-104  ... -0.137413 -0.010294  1.510638  11.295556
# TTTGGTTCATATGGTC-1-104  ...  8.780238  1.848118 -1.141547   4.063725
# TTTGTCAAGCGAAGGG-1-104  ...  2.120607  0.450342  0.701503   4.760304
# TTTGTCAAGCTATGCT-1-104  ...  5.186368 -0.699205 -1.141547   5.988063
# TTTGTCATCCGAACGC-1-104  ...  6.930172  1.504072  2.259780  14.400240
#
#                             CD24       CD44      CD58   CD66ace      CD13  \
# AAACCTGCACATTTCT-1-104 -0.385128   9.168543  1.119241  2.466579  3.525329
# AAACCTGCAGCTGCAC-1-104 -0.385128   8.197853 -1.106121  0.061596  0.058404
# AAACCTGCATATACGC-1-104 -1.273411  12.129786  0.131233  1.350275 -1.006977
# AAACCTGGTCTCGTTC-1-104 -0.385128   6.745280  2.479383 -0.665808  0.058404
# AAACCTGGTTAAGGGC-1-104 -0.385128   9.351630  4.062710  1.927046  0.058404
# ...                          ...        ...       ...       ...       ...
# TTTGCGCAGGCCGAAT-1-104  1.862483   7.155178  0.397434  2.466579  3.525329
# TTTGGTTCATATGGTC-1-104 -0.385128   6.234013  0.397434  2.466579  1.925742
# TTTGTCAAGCGAAGGG-1-104 -0.385128  10.662904 -0.448676  0.730742  0.058404
# TTTGTCAAGCTATGCT-1-104  0.425811   9.556134  0.890198  1.350275  1.031021
# TTTGTCATCCGAACGC-1-104  0.425811   3.146393  0.649979 -0.665808  4.246743
#
#                              CD34
# AAACCTGCACATTTCT-1-104   6.263618
# AAACCTGCAGCTGCAC-1-104   0.099950
# AAACCTGCATATACGC-1-104  -0.333611
# AAACCTGGTCTCGTTC-1-104   7.409352
# AAACCTGGTTAAGGGC-1-104   5.054727
# ...                           ...
# TTTGCGCAGGCCGAAT-1-104   8.811618
# TTTGGTTCATATGGTC-1-104  12.733891
# TTTGTCAAGCGAAGGG-1-104   8.032054
# TTTGTCAAGCTATGCT-1-104   9.957352
# TTTGTCATCCGAACGC-1-104   2.506727
#
# [1587 rows x 33 columns]

# %%
#NK- and T-cells in sample
nk_prot.shape
# Out:
# (0, 33)

# %%
#All cells in sample

prot.shape
# Out:
# (1587, 33)

# %%
#To exclude columns that contain only zeros, all cell types included

prot = pd.DataFrame(prot)
prot != 0
(prot != 0).any(axis=0)
prot.loc[:, (prot != 0).any(axis=0)]
prot = prot.loc[:, (prot != 0).any(axis=0)]

for col in prot:
    print(col)
# Out:
# CD19
# CD10
# CD20
# CD3
# CD2
# CD11b
# HLADR
# CD38
# CD11c
# CD7
# CD45
# CD33
# CD81
# CD73
# CD123
# CD14
# CD45RA
# CD45RO
# CD4
# CD8a
# CD197
# CD127
# CD56
# CD5
# CD15
# CD64
# CD117
# CD24
# CD44
# CD58
# CD66ace
# CD13
# CD34

# %%
#To exclude columns that contain only zeros from NK-only file

nk_prot = pd.DataFrame(nk_prot)
nk_prot != 0
(nk_prot != 0).any(axis=0)
nk_prot.loc[:, (nk_prot != 0).any(axis=0)]
nk_prot = nk_prot.loc[:, (nk_prot != 0).any(axis=0)]

for col in nk_prot:
    print(col)

# %%
#sorting by mean, all cell types

index_sort = prot.mean().sort_values().index
df_sorted_all = prot[index_sort]

# %%
#sorting by mean, NK- and T-cells

index_sort = nk_prot.mean().sort_values().index
df_sorted_nk = nk_prot[index_sort]

# %%
#All cell types

cells= len(prot)

print("In total:", cells, "cells in the sample" )

plt.figure(figsize=(30,10))
plt.ylim(0, 30)
a=sns.boxplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 1587 cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK- and T-cells in the sample" )

plt.figure(figsize=(30,10))
plt.ylim(0, 800)
a=sns.boxplot(data=df_sorted_nk,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK- and- T-cells", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 0 NK- and T-cells in the sample
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [23], line 9
#       7 plt.figure(figsize=(30,10))
#       8 plt.ylim(0, 800)
# ----> 9 a=sns.boxplot(data=df_sorted_nk,  fliersize=0)
#      11 a.set_xticklabels(a.get_xticklabels(),rotation=45)
#      12 a.tick_params(axis='x', labelsize=20)
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/seaborn/categorical.py:2230, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2223 def boxplot(
#    2224     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2225     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2226     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2227     **kwargs
#    2228 ):
# -> 2230     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2231                           orient, color, palette, saturation,
#    2232                           width, dodge, fliersize, linewidth)
#    2234     if ax is None:
#    2235         ax = plt.gca()
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/seaborn/categorical.py:786, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
#     785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
# --> 786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#     789     self.width = width
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/seaborn/categorical.py:707, in _CategoricalPlotter.establish_colors(self, color, palette, saturation)
#     705 # Determine the gray color to use for the lines framing the plot
#     706 light_vals = [rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 707 lum = min(light_vals) * .6
#     708 gray = mpl.colors.rgb2hex((lum, lum, lum))
#     710 # Assign object attributes
#
# ValueError: min() arg is an empty sequence

# %%
#All cells

cells= len(prot)

print("In total:", cells, "cells in the sample" )

plt.figure(figsize=(40,20))
plt.ylim(0, 30)
a=sns.violinplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 1587 cells in the sample

# %%
#NK- and T-cells

cells= len(nk_prot)

print("In total:", cells, "NK- and T-cells in the sample" )

plt.figure(figsize=(40,20))
plt.ylim(0, 800)
a=sns.violinplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK- and T-cells", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

# %%
#All cells
matrix1=prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix1, figsize=(20,20))
plt.title('All cell types', fontsize = 50) ;

# %%
#NK cells
matrix3=nk_prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix3, figsize=(20,20))
plt.title('NK- and T-cells', fontsize = 50) ;

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_sample.obs
b = prot

neurips_umap=pd.concat([a, b], axis=1)

adata_sample.obs=neurips_umap
adata_sample
# Out:
# AnnData object with n_obs × n_vars = 1587 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD3', 'CD8', 'CD56', 'CD19', 'CD33', 'CD11c', 'CD45RA', 'CD123', 'CD7', 'CD4', 'CD44', 'CD14', 'CD45RO', 'CD20', 'CD5', 'HLA-DR', 'CD11b', 'CD64', 'CD58', 'CD24', 'CD13', 'CD2', 'CD81', 'CD38', 'CD127', 'CD45', 'CD73', 'CD197', 'CD34', 'CD10', 'CD15', 'CD117', 'CD66ace'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs
# Out:
#                        cell_type  n_genes  percent_mito  percent_ribo  \
# AAACCTGCACATTTCT-1-104       NaN     4007      0.026531      0.269720
# AAACCTGCAGCTGCAC-1-104       NaN     3407      0.019950      0.327760
# AAACCTGCATATACGC-1-104       NaN     4824      0.028900      0.339810
# AAACCTGGTCTCGTTC-1-104       NaN     3929      0.027119      0.294662
# AAACCTGGTTAAGGGC-1-104       NaN     3783      0.019648      0.366279
# ...                          ...      ...           ...           ...
# TTTGCGCAGGCCGAAT-1-104       NaN     1723      0.066038      0.352702
# TTTGGTTCATATGGTC-1-104       NaN     4745      0.019579      0.318692
# TTTGTCAAGCGAAGGG-1-104       NaN     3551      0.026817      0.293081
# TTTGTCAAGCTATGCT-1-104       NaN     4705      0.032767      0.295371
# TTTGTCATCCGAACGC-1-104       NaN     4631      0.025612      0.407374
#
#                         n_counts leiden_r2  leiden_r2_n_genes_MAD_diff  \
# AAACCTGCACATTTCT-1-104   14059.0       NaN                         NaN
# AAACCTGCAGCTGCAC-1-104   12381.0       NaN                         NaN
# AAACCTGCATATACGC-1-104   20588.0       NaN                         NaN
# AAACCTGGTCTCGTTC-1-104   12869.0       NaN                         NaN
# AAACCTGGTTAAGGGC-1-104   15065.0       NaN                         NaN
# ...                          ...       ...                         ...
# TTTGCGCAGGCCGAAT-1-104    4664.0       NaN                         NaN
# TTTGGTTCATATGGTC-1-104   19511.0       NaN                         NaN
# TTTGTCAAGCGAAGGG-1-104   12082.0       NaN                         NaN
# TTTGTCAAGCTATGCT-1-104   19379.0       NaN                         NaN
# TTTGTCATCCGAACGC-1-104   22294.0       NaN                         NaN
#
#                         leiden_r2_n_counts_MAD_diff  \
# AAACCTGCACATTTCT-1-104                          NaN
# AAACCTGCAGCTGCAC-1-104                          NaN
# AAACCTGCATATACGC-1-104                          NaN
# AAACCTGGTCTCGTTC-1-104                          NaN
# AAACCTGGTTAAGGGC-1-104                          NaN
# ...                                             ...
# TTTGCGCAGGCCGAAT-1-104                          NaN
# TTTGGTTCATATGGTC-1-104                          NaN
# TTTGTCAAGCGAAGGG-1-104                          NaN
# TTTGTCAAGCTATGCT-1-104                          NaN
# TTTGTCATCCGAACGC-1-104                          NaN
#
#                         leiden_r2_percent_mito_MAD_diff filter  ... CD38  \
# AAACCTGCACATTTCT-1-104                              NaN  False  ...   34
# AAACCTGCAGCTGCAC-1-104                              NaN  False  ...   66
# AAACCTGCATATACGC-1-104                              NaN  False  ...  100
# AAACCTGGTCTCGTTC-1-104                              NaN  False  ...   19
# AAACCTGGTTAAGGGC-1-104                              NaN  False  ...  111
# ...                                                 ...    ...  ...  ...
# TTTGCGCAGGCCGAAT-1-104                              NaN  False  ...   13
# TTTGGTTCATATGGTC-1-104                              NaN  False  ...  147
# TTTGTCAAGCGAAGGG-1-104                              NaN  False  ...   18
# TTTGTCAAGCTATGCT-1-104                              NaN  False  ...   27
# TTTGTCATCCGAACGC-1-104                              NaN  False  ...   60
#
#                        CD127 CD45 CD73 CD197 CD34 CD10 CD15 CD117 CD66ace
# AAACCTGCACATTTCT-1-104     6   37    4     9   30   18   14    30       6
# AAACCTGCAGCTGCAC-1-104    15   37   11     5    5   23   26    34       2
# AAACCTGCATATACGC-1-104    16   42    8     4    4   48   25    45       4
# AAACCTGGTCTCGTTC-1-104     2   27   11     1   38   19   27    29       1
# AAACCTGGTTAAGGGC-1-104    12   57   43     4   23   22   21    47       5
# ...                      ...  ...  ...   ...  ...  ...  ...   ...     ...
# TTTGCGCAGGCCGAAT-1-104    10   13   20     1   50   25   21    44       6
# TTTGGTTCATATGGTC-1-104    10   54    3     5  102   16   35    11       6
# TTTGTCAAGCGAAGGG-1-104     4   23    4     0   43   20   24    13       3
# TTTGTCAAGCTATGCT-1-104     3   27    7     3   62   15   17    17       4
# TTTGTCATCCGAACGC-1-104     8   43    8     5   12   15   32    71       1
#
# [1587 rows x 56 columns]

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_nk.obs
b = nk_prot

adata_nk_umap=pd.concat([a, b], axis=1)

adata_nk.obs=adata_nk_umap

adata_nk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 3
#       1 #Adding protein data to anndata file for UMAPs, all cell types
# ----> 3 a = adata_nk.obs
#       4 b = nk_prot
#       6 adata_nk_umap=pd.concat([a, b], axis=1)
#
# NameError: name 'adata_nk' is not defined

# %%
adata_nk.obs["CD56"]

# %%
#NK-cell markers

markers=["CD56"]

# %%
#All cell types
sc.pl.umap(adata_sample, color= "cell_type", color_map= 'viridis')

# %%
#NK- and T-cells

sc.pl.umap(adata_nk, color = "cell_type", color_map = 'viridis')

# %%
#All cell types

sc.pl.umap(adata_sample, color= markers, color_map= 'viridis')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [31], line 3
#       1 #All cell types
# ----> 3 sc.pl.umap(adata_sample, color= markers, color_map= 'viridis')
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:669, in umap(adata, **kwargs)
#     610 @_wraps_plot_scatter
#     611 @_doc_params(
#     612     adata_color_etc=doc_adata_color_etc,
#    (...)
#     616 )
#     617 def umap(adata, **kwargs) -> Union[Axes, List[Axes], None]:
#     618     """\
#     619     Scatter plot in UMAP basis.
#     620
#    (...)
#     667     tl.umap
#     668     """
# --> 669     return embedding(adata, 'umap', **kwargs)
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:257, in embedding(adata, basis, color, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     250 # use itertools.product to make a plot for each color and for each component
#     251 # For example if color=[gene1, gene2] and components=['1,2, '2,3'].
#     252 # The plots are: [
#     253 #     color=gene1, components=[1,2], color=gene1, components=[2,3],
#     254 #     color=gene2, components = [1, 2], color=gene2, components=[2,3],
#     255 # ]
#     256 for count, (value_to_plot, dims) in enumerate(zip(color, dimensions)):
# --> 257     color_source_vector = _get_color_source_vector(
#     258         adata,
#     259         value_to_plot,
#     260         layer=layer,
#     261         use_raw=use_raw,
#     262         gene_symbols=gene_symbols,
#     263         groups=groups,
#     264     )
#     265     color_vector, categorical = _color_vector(
#     266         adata,
#     267         value_to_plot,
#    (...)
#     270         na_color=na_color,
#     271     )
#     273     # Order points
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1169, in _get_color_source_vector(adata, value_to_plot, use_raw, gene_symbols, layer, groups)
#    1167     values = adata.raw.obs_vector(value_to_plot)
#    1168 else:
# -> 1169     values = adata.obs_vector(value_to_plot, layer=layer)
#    1170 if groups and is_categorical_dtype(values):
#    1171     values = values.replace(values.categories.difference(groups), np.nan)
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/anndata/_core/anndata.py:1397, in AnnData.obs_vector(self, k, layer)
#    1391         warnings.warn(
#    1392             "In a future version of AnnData, access to `.X` by passing"
#    1393             " `layer='X'` will be removed. Instead pass `layer=None`.",
#    1394             FutureWarning,
#    1395         )
#    1396         layer = None
# -> 1397 return get_vector(self, k, "obs", "var", layer=layer)
#
# File ~/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/anndata/_core/index.py:179, in get_vector(adata, k, coldim, idxdim, layer)
#     175     raise ValueError(
#     176         f"Key {k} could be found in both .{idxdim}_names and .{coldim}.columns"
#     177     )
#     178 elif (in_col + in_idx) == 0:
# --> 179     raise KeyError(
#     180         f"Could not find key {k} in .{idxdim}_names or .{coldim}.columns."
#     181     )
#     182 elif in_col:
#     183     return getattr(adata, coldim)[k].values
#
# KeyError: 'Could not find key CD56 in .var_names or .obs.columns.'

# %%
#NK- and T-cells

sc.pl.umap(adata_nk, color = markers, color_map = 'viridis')

# %%
#NK- and T-cells

for column_name in markers:
    fig, ax =plt.subplots(1,2 ,tight_layout=True, figsize=(15, 5), sharex=True)
    fig.show()

    ax1 = sns.kdeplot(data=prot, x=column_name, multiple="stack", ax=ax[0]) ;
    ax2 = sns.kdeplot(data=nk_prot, x=column_name, color = "g", multiple="stack", ax=ax[1]) ;


    ax1.title.set_text('All cell types')    
    ax2.title.set_text('NK- and T-cells')
    
    plt.show()

# %%
#NK markers, all cell types

plt.figure(figsize=(20,10))
a=sns.violinplot(data=prot[markers],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK-cell markers", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

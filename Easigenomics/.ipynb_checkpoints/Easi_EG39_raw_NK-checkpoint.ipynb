# %% [markdown]
# # Easi, EG39, raw proteins

# %% [markdown]
# - Diagnosis: MDS
# - BM blasts: 11%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
import umap

from ridgeplot import ridgeplot

import warnings

warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %%
#raw protein data, all datasets

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/healthy_malig_!m.h5ad')

# %%
adata.obs['batch_group']
# Out:
# GTAGTACCAATCCTTT-1-s4d1    Neurips
# CTCAAGAGTCACAGAG-1-s4d1    Neurips
# CTGTGGGTCATGCGGC-1-s4d1    Neurips
# CGTGATAGTTATCTGG-1-s4d1    Neurips
# AGATCCAAGATCGGTG-1-s4d1    Neurips
#                             ...
# TTTGTCAGTCATGCAT-1-17        Caron
# TTTGTCAGTGCTTCTC-1-17        Caron
# TTTGTCAGTGGACGAT-1-17        Caron
# TTTGTCATCAACGAAA-1-17        Caron
# TTTGTCATCTAACTGG-1-17        Caron
# Name: batch_group, Length: 298991, dtype: category
# Categories (5, object): ['Caron', 'Easi', 'Granja', 'Neurips', 'Seurat']

# %%
adata_easi=adata[adata.obs['batch_group'] == 'Easi' ]

adata_easi
# Out:
# View of AnnData object with n_obs × n_vars = 121340 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_easi.obs['POOL'].unique().tolist()
# Out:
# ['EG35',
#  'EG38',
#  'EG58',
#  'EG39',
#  'EG4',
#  'EG48',
#  'EG23',
#  'EG36',
#  'EG61',
#  'EG3',
#  'EG12',
#  'EG46',
#  'EG9',
#  'EG43',
#  'EG56',
#  'EG42',
#  'EG49',
#  'EG37',
#  'EG57',
#  'EG24',
#  'EG11',
#  'EG14',
#  'EG55',
#  'EG28',
#  'EG52',
#  'EG33',
#  'EG10',
#  'EG32',
#  'EG59',
#  'EG16',
#  'EG63',
#  'EG15',
#  'EG21',
#  'EG26',
#  'EG13',
#  'EG53',
#  'EG51',
#  'EG2',
#  'EG40',
#  'EG62',
#  'EG31',
#  'EG7',
#  'EG8',
#  'EG29',
#  'EG41',
#  'EG47',
#  'EG1',
#  'EG6',
#  'EG34',
#  'EG30',
#  'EG60',
#  'EG44',
#  'EG27',
#  'EG22',
#  'EG54',
#  'EG45',
#  'EG5',
#  'EG50',
#  'EG25']

# %%
adata_easi.obs['new_cell_type'].unique().tolist()
# Out:
# ['NK',
#  'non-leukemic',
#  'preleukemic',
#  'non-leukemic?',
#  nan,
#  'leukemic',
#  'leukemic?',
#  'doublets?',
#  'unknown',
#  '0',
#  'preleukemic?']

# %%
#select sample from Easigenomics dataset

adata_sample=adata_easi[adata_easi.obs['POOL'] == 'EG39']

# %%
adata_sample.copy()
# Out:
# AnnData object with n_obs × n_vars = 5455 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs['new_cell_type'].unique().tolist()
# Out:
# ['preleukemic', 'non-leukemic?', 'NK', 'non-leukemic']

# %%
adata_sample.obs['POOL'].unique().tolist()
# Out:
# ['EG39']

# %%
#Select only NK- and T-cells (based on new_cell_type annotations)

adata_nk=adata_sample[adata_sample.obs['new_cell_type'] == 'NK' ]

# %%
adata_nk.copy()
# Out:
# AnnData object with n_obs × n_vars = 538 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs['cell_type']
# Out:
# AAACCTGCAATGCCAT-1-103    NKT
# AAACGGGGTCATGCAT-1-103    NKT
# AAAGATGAGACTAGAT-1-103    NKT
# AAAGATGAGCTTCGCG-1-103    NKT
# AAAGATGGTAACGTTC-1-103    NKT
#                          ...
# TTTGGTTAGCTAAACA-1-103    NKT
# TTTGGTTGTAGCGCTC-1-103    NKT
# TTTGGTTTCCTCATTA-1-103    NKT
# TTTGTCACAGCGATCC-1-103    NKT
# TTTGTCACATATGCTG-1-103    NKT
# Name: cell_type, Length: 538, dtype: category
# Categories (1, object): ['NKT']

# %%
#surface protein expression of NK- and T-cells
nk_prot=adata_nk.obsm['protein_expression']

# %%
#surface protein expression of whole sample
prot=adata_sample.obsm['protein_expression']

# %%
#NK- and T-cells in sample
nk_prot.shape
# Out:
# (538, 141)

# %%
#All cells in sample

prot.shape
# Out:
# (5455, 141)

# %%
#To exclude columns that contain only zeros, all cell types included

prot = pd.DataFrame(prot)
prot != 0
(prot != 0).any(axis=0)
prot.loc[:, (prot != 0).any(axis=0)]
prot = prot.loc[:, (prot != 0).any(axis=0)]

for col in prot:
    print(col)
# Out:
# CD3
# CD8
# CD56
# CD19
# CD33
# CD11c
# CD45RA
# CD123
# CD7
# CD4
# CD44
# CD14
# CD45RO
# CD20
# CD5
# HLA-DR
# CD11b
# CD64
# CD58
# CD24
# CD13
# CD2
# CD81
# CD38
# CD127
# CD45
# CD73
# CD197
# CD34
# CD10
# CD15
# CD117
# CD66ace

# %%
#To exclude columns that contain only zeros from NK-only file

nk_prot = pd.DataFrame(nk_prot)
nk_prot != 0
(nk_prot != 0).any(axis=0)
nk_prot.loc[:, (nk_prot != 0).any(axis=0)]
nk_prot = nk_prot.loc[:, (nk_prot != 0).any(axis=0)]

for col in nk_prot:
    print(col)
# Out:
# CD3
# CD8
# CD56
# CD19
# CD33
# CD11c
# CD45RA
# CD123
# CD7
# CD4
# CD44
# CD14
# CD45RO
# CD20
# CD5
# HLA-DR
# CD11b
# CD64
# CD58
# CD24
# CD13
# CD2
# CD81
# CD38
# CD127
# CD45
# CD73
# CD197
# CD34
# CD10
# CD15
# CD117
# CD66ace

# %%
#sorting by mean, all cell types

index_sort = prot.mean().sort_values().index
df_sorted_all = prot[index_sort]

# %%
#sorting by mean, NK- and T-cells

index_sort = nk_prot.mean().sort_values().index
df_sorted_nk = nk_prot[index_sort]

# %%
#All cell types

cells= len(prot)

print("In total:", cells, "cells in the sample" )

plt.figure(figsize=(30,10))
plt.ylim(0, 800)
a=sns.boxplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 5455 cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK- and T-cells in the sample" )

plt.figure(figsize=(30,10))
plt.ylim(0, 800)
a=sns.boxplot(data=df_sorted_nk,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK- and- T-cells", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 538 NK- and T-cells in the sample

# %%
#All cells

cells= len(prot)

print("In total:", cells, "cells in the sample" )

plt.figure(figsize=(40,20))
plt.ylim(0, 800)
a=sns.violinplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 5455 cells in the sample

# %%
#NK- and T-cells

cells= len(nk_prot)

print("In total:", cells, "NK- and T-cells in the sample" )

plt.figure(figsize=(40,20))
plt.ylim(0, 800)
a=sns.violinplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK- and T-cells", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 538 NK- and T-cells in the sample

# %%
#All cells
matrix1=prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix1, figsize=(20,20))
plt.title('All cell types', fontsize = 50) ;

# %%
#NK cells
matrix3=nk_prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix3, figsize=(20,20))
plt.title('NK- and T-cells', fontsize = 50) ;

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_sample.obs
b = prot

neurips_umap=pd.concat([a, b], axis=1)

adata_sample.obs=neurips_umap
adata_sample
# Out:
# AnnData object with n_obs × n_vars = 5455 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD3', 'CD8', 'CD56', 'CD19', 'CD33', 'CD11c', 'CD45RA', 'CD123', 'CD7', 'CD4', 'CD44', 'CD14', 'CD45RO', 'CD20', 'CD5', 'HLA-DR', 'CD11b', 'CD64', 'CD58', 'CD24', 'CD13', 'CD2', 'CD81', 'CD38', 'CD127', 'CD45', 'CD73', 'CD197', 'CD34', 'CD10', 'CD15', 'CD117', 'CD66ace'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs
# Out:
#                             cell_type  n_genes  percent_mito  percent_ribo  \
# AAACCTGAGCGACGTA-1-103    preleukemic     4371      0.050416      0.310388
# AAACCTGAGCGTGTCC-1-103  non-leukemic?      547      0.000000      0.145070
# AAACCTGAGGAACTGC-1-103    preleukemic     4825      0.040210      0.338300
# AAACCTGAGTCGATAA-1-103    preleukemic     2853      0.095387      0.336862
# AAACCTGAGTGGAGTC-1-103    preleukemic     3225      0.017760      0.321180
# ...                               ...      ...           ...           ...
# TTTGTCACAGCGATCC-1-103            NKT     1627      0.026577      0.277943
# TTTGTCACATATGCTG-1-103            NKT     1962      0.003545      0.389401
# TTTGTCAGTTCGTGAT-1-103    preleukemic     3000      0.049894      0.300257
# TTTGTCATCCTAGTGA-1-103  non-leukemic?     1883      0.001248      0.080583
# TTTGTCATCGGATGTT-1-103    preleukemic     1875      0.139221      0.152727
#
#                         n_counts leiden_r2  leiden_r2_n_genes_MAD_diff  \
# AAACCTGAGCGACGTA-1-103   16721.0       NaN                         NaN
# AAACCTGAGCGTGTCC-1-103    1420.0       NaN                         NaN
# AAACCTGAGGAACTGC-1-103   20940.0       NaN                         NaN
# AAACCTGAGTCGATAA-1-103    8974.0       NaN                         NaN
# AAACCTGAGTGGAGTC-1-103   10642.0       NaN                         NaN
# ...                          ...       ...                         ...
# TTTGTCACAGCGATCC-1-103    4026.0       NaN                         NaN
# TTTGTCACATATGCTG-1-103    5642.0       NaN                         NaN
# TTTGTCAGTTCGTGAT-1-103    8959.0       NaN                         NaN
# TTTGTCATCCTAGTGA-1-103    7210.0       NaN                         NaN
# TTTGTCATCGGATGTT-1-103    3850.0       NaN                         NaN
#
#                         leiden_r2_n_counts_MAD_diff  \
# AAACCTGAGCGACGTA-1-103                          NaN
# AAACCTGAGCGTGTCC-1-103                          NaN
# AAACCTGAGGAACTGC-1-103                          NaN
# AAACCTGAGTCGATAA-1-103                          NaN
# AAACCTGAGTGGAGTC-1-103                          NaN
# ...                                             ...
# TTTGTCACAGCGATCC-1-103                          NaN
# TTTGTCACATATGCTG-1-103                          NaN
# TTTGTCAGTTCGTGAT-1-103                          NaN
# TTTGTCATCCTAGTGA-1-103                          NaN
# TTTGTCATCGGATGTT-1-103                          NaN
#
#                         leiden_r2_percent_mito_MAD_diff filter  ... CD38  \
# AAACCTGAGCGACGTA-1-103                              NaN  False  ...    9
# AAACCTGAGCGTGTCC-1-103                              NaN  False  ...    3
# AAACCTGAGGAACTGC-1-103                              NaN  False  ...   12
# AAACCTGAGTCGATAA-1-103                              NaN  False  ...    1
# AAACCTGAGTGGAGTC-1-103                              NaN  False  ...    6
# ...                                                 ...    ...  ...  ...
# TTTGTCACAGCGATCC-1-103                              NaN  False  ...   14
# TTTGTCACATATGCTG-1-103                              NaN  False  ...    7
# TTTGTCAGTTCGTGAT-1-103                              NaN  False  ...    7
# TTTGTCATCCTAGTGA-1-103                              NaN  False  ...    3
# TTTGTCATCGGATGTT-1-103                              NaN  False  ...    3
#
#                        CD127 CD45 CD73 CD197 CD34 CD10 CD15 CD117 CD66ace
# AAACCTGAGCGACGTA-1-103     0   29   25     8   32   22   19    44       5
# AAACCTGAGCGTGTCC-1-103     4    9   39     4    4   12   20     3       9
# AAACCTGAGGAACTGC-1-103     3   20    7     9   25   16   23    77      13
# AAACCTGAGTCGATAA-1-103     0    9    3     4    5    3   11    24       2
# AAACCTGAGTGGAGTC-1-103     3   11   36     7   29   19   15     8       8
# ...                      ...  ...  ...   ...  ...  ...  ...   ...     ...
# TTTGTCACAGCGATCC-1-103     4  127   29     4    3   23   17     5      15
# TTTGTCACATATGCTG-1-103     4   83   19    11    9   20   24     6       4
# TTTGTCAGTTCGTGAT-1-103     3   14    6     1   16   10   21    53       5
# TTTGTCATCCTAGTGA-1-103     5    3    5     3    3    9   18    11       4
# TTTGTCATCGGATGTT-1-103     1   25   24     1   25   14   28    69      10
#
# [5455 rows x 56 columns]

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_nk.obs
b = nk_prot

adata_nk_umap=pd.concat([a, b], axis=1)

adata_nk.obs=adata_nk_umap

adata_nk
# Out:
# AnnData object with n_obs × n_vars = 538 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD3', 'CD8', 'CD56', 'CD19', 'CD33', 'CD11c', 'CD45RA', 'CD123', 'CD7', 'CD4', 'CD44', 'CD14', 'CD45RO', 'CD20', 'CD5', 'HLA-DR', 'CD11b', 'CD64', 'CD58', 'CD24', 'CD13', 'CD2', 'CD81', 'CD38', 'CD127', 'CD45', 'CD73', 'CD197', 'CD34', 'CD10', 'CD15', 'CD117', 'CD66ace'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs["CD56"]
# Out:
# AAACCTGCAATGCCAT-1-103    10
# AAACGGGGTCATGCAT-1-103    20
# AAAGATGAGACTAGAT-1-103    18
# AAAGATGAGCTTCGCG-1-103    16
# AAAGATGGTAACGTTC-1-103    18
#                           ..
# TTTGGTTAGCTAAACA-1-103    11
# TTTGGTTGTAGCGCTC-1-103    10
# TTTGGTTTCCTCATTA-1-103     1
# TTTGTCACAGCGATCC-1-103    10
# TTTGTCACATATGCTG-1-103    22
# Name: CD56, Length: 538, dtype: int64

# %%
#NK-cell markers

markers=["CD56"]

# %%
#All cell types
sc.pl.umap(adata_sample, color= "cell_type", color_map= 'viridis')

# %%
#NK- and T-cells

sc.pl.umap(adata_nk, color = "cell_type", color_map = 'viridis')

# %%
#All cell types

sc.pl.umap(adata_sample, color= markers, color_map= 'viridis')

# %%
#NK- and T-cells

sc.pl.umap(adata_nk, color = markers, color_map = 'viridis')

# %%
#NK and T-cells

for column_name in markers:
    fig, ax =plt.subplots(1,2 ,tight_layout=True, figsize=(15, 5), sharex=True)
    fig.show()

    ax1 = sns.kdeplot(data=prot, x=column_name, multiple="stack", ax=ax[0]) ;
    ax2 = sns.kdeplot(data=nk_prot, x=column_name, color = "g", multiple="stack", ax=ax[1]) ;


    ax1.title.set_text('All cell types')    
    ax2.title.set_text('NK- and T-cells')
    
    plt.show()

# %%
#NK markers

plt.figure(figsize=(20,10))
a=sns.violinplot(data=nk_prot[markers],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK-cell markers", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

# %% [markdown]
# # Easi, EG48, CLR normalized proteins

# %% [markdown]
# Sample description:
# - Diagnosis: AML
# - BM blasts: 35%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
import umap

from ridgeplot import ridgeplot

import warnings

warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:53: LightningDeprecationWarning: pytorch_lightning.utilities.warnings.rank_zero_deprecation has been deprecated in v1.6 and will be removed in v1.8. Use the equivalent function from the pytorch_lightning.utilities.rank_zero module instead.
#   new_rank_zero_deprecation(
# /Users/tiinatuononen/opt/anaconda3/envs/tiina-env/lib/python3.10/site-packages/pytorch_lightning/utilities/warnings.py:58: LightningDeprecationWarning: The `pytorch_lightning.loggers.base.rank_zero_experiment` is deprecated in v1.7 and will be removed in v1.9. Please use `pytorch_lightning.loggers.logger.rank_zero_experiment` instead.
#   return new_rank_zero_deprecation(*args, **kwargs)

# %%
#raw protein data, all datasets

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_easi_norm.h5ad')

# %%
adata.obs['batch_group']
# Out:
# AAACCTGAGCCCTAAT-1-100    Easi
# AAACCTGCAAGCCGCT-1-100    Easi
# AAACCTGCACTGTCGG-1-100    Easi
# AAACCTGCAGACGCTC-1-100    Easi
# AAACCTGTCCTTAATC-1-100    Easi
#                           ...
# TTTGTCAGTACATCCA-1-158    Easi
# TTTGTCAGTAGGCATG-1-158    Easi
# TTTGTCAGTATGCTTG-1-158    Easi
# TTTGTCATCAAACCAC-1-158    Easi
# TTTGTCATCCATGAAC-1-158    Easi
# Name: batch_group, Length: 121340, dtype: category
# Categories (1, object): ['Easi']

# %%
adata_easi=adata[adata.obs['batch_group'] == 'Easi' ]

adata_easi
# Out:
# View of AnnData object with n_obs × n_vars = 121340 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_easi.obs['POOL'].unique().tolist()
# Out:
# ['EG35',
#  'EG38',
#  'EG58',
#  'EG39',
#  'EG4',
#  'EG48',
#  'EG23',
#  'EG36',
#  'EG61',
#  'EG3',
#  'EG12',
#  'EG46',
#  'EG9',
#  'EG43',
#  'EG56',
#  'EG42',
#  'EG49',
#  'EG37',
#  'EG57',
#  'EG24',
#  'EG11',
#  'EG14',
#  'EG55',
#  'EG28',
#  'EG52',
#  'EG33',
#  'EG10',
#  'EG32',
#  'EG59',
#  'EG16',
#  'EG63',
#  'EG15',
#  'EG21',
#  'EG26',
#  'EG13',
#  'EG53',
#  'EG51',
#  'EG2',
#  'EG40',
#  'EG62',
#  'EG31',
#  'EG7',
#  'EG8',
#  'EG29',
#  'EG41',
#  'EG47',
#  'EG1',
#  'EG6',
#  'EG34',
#  'EG30',
#  'EG60',
#  'EG44',
#  'EG27',
#  'EG22',
#  'EG54',
#  'EG45',
#  'EG5',
#  'EG50',
#  'EG25']

# %%
adata_easi.obs['new_cell_type'].unique().tolist()
# Out:
# ['NK',
#  'non-leukemic',
#  'preleukemic',
#  'non-leukemic?',
#  nan,
#  'leukemic',
#  'leukemic?',
#  'doublets?',
#  'unknown',
#  '0',
#  'preleukemic?']

# %%
#select sample from Easigenomics dataset

adata_sample=adata_easi[adata_easi.obs['POOL'] == 'EG48']

# %%
adata_sample.copy()
# Out:
# AnnData object with n_obs × n_vars = 1734 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs['new_cell_type'].unique().tolist()
# Out:
# ['leukemic', 'leukemic?', 'non-leukemic', 'NK']

# %%
adata_sample.obs['POOL'].unique().tolist()
# Out:
# ['EG48']

# %%
#Select only NK- and T-cells (based on new_cell_type annotations)

adata_nk=adata_sample[adata_sample.obs['new_cell_type'] == 'NK' ]

# %%
adata_nk.copy()
# Out:
# AnnData object with n_obs × n_vars = 57 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs['cell_type']
# Out:
# AAGTCTGTCGCGATCG-1-105    NKT
# ACGATGTCACAACGTT-1-105    NKT
# ACGGGCTGTTAAAGTG-1-105    NKT
# ACTTGTTGTCAAAGCG-1-105    NKT
# ACTTTCATCGACCAGC-1-105    NKT
# AGGTCCGGTCAGTGGA-1-105    NKT
# AGTTGGTAGGCATTGG-1-105    NKT
# ATCTACTAGTGATCGG-1-105    NKT
# ATTGGTGTCAACACCA-1-105    NKT
# CACCACTCACACCGAC-1-105    NKT
# CACTCCATCTCAACTT-1-105    NKT
# CAGCATAGTCCAGTGC-1-105    NKT
# CAGTCCTAGGACGAAA-1-105    NKT
# CATCCACAGAGGTACC-1-105    NKT
# CCATGTCCAGCGAACA-1-105    NKT
# CGAACATAGCAATATG-1-105    NKT
# CGAACATAGTCACGCC-1-105    NKT
# CGAATGTGTCTGCAAT-1-105    NKT
# CGGCTAGAGCGCTTAT-1-105    NKT
# CGGGTCAGTGCACCAC-1-105    NKT
# CGGTTAATCACCCTCA-1-105    NKT
# CGTGTCTTCAAGATCC-1-105    NKT
# CTAACTTCAGCTATTG-1-105    NKT
# CTAATGGGTTCACCTC-1-105    NKT
# CTACATTGTCTCTCTG-1-105    NKT
# CTACCCACAATCTACG-1-105    NKT
# CTAGTGAAGGCTCATT-1-105    NKT
# CTCAGAAAGCGTGAGT-1-105    NKT
# GAATAAGTCAACACCA-1-105    NKT
# GACCTGGCATCCAACA-1-105    NKT
# GACGTTATCGCTTAGA-1-105    NKT
# GAGCAGATCAATACCG-1-105    NKT
# GCGACCAGTGTTGAGG-1-105    NKT
# GGACAGACATTCACTT-1-105    NKT
# GGCCGATCAGGTGCCT-1-105    NKT
# GGGACCTTCACTTACT-1-105    NKT
# GGTGCGTGTGCGAAAC-1-105    NKT
# GGTGTTACAAGTACCT-1-105    NKT
# GTCGGGTGTGCGCTTG-1-105    NKT
# GTCTTCGTCGCGGATC-1-105    NKT
# GTCTTCGTCTTCAACT-1-105    NKT
# GTGAAGGAGACAGACC-1-105    NKT
# GTGAAGGCAGGCGATA-1-105    NKT
# GTTACAGGTGTGAAAT-1-105    NKT
# GTTCGGGCATGAGCGA-1-105    NKT
# GTTCTCGCATTAGCCA-1-105    NKT
# GTTCTCGGTCATATGC-1-105    NKT
# GTTTCTAGTGCAGTAG-1-105    NKT
# TCGAGGCCAATCTACG-1-105    NKT
# TCTCTAAGTCTGATTG-1-105    NKT
# TCTTCGGTCATGTCCC-1-105    NKT
# TGACGGCTCGGAGGTA-1-105    NKT
# TGTGGTAGTCAGAGGT-1-105    NKT
# TTCGGTCAGGTGACCA-1-105    NKT
# TTCGGTCGTAAAGGAG-1-105    NKT
# TTTATGCAGCCTATGT-1-105    NKT
# TTTGCGCAGGCAGTCA-1-105    NKT
# Name: cell_type, dtype: category
# Categories (1, object): ['NKT']

# %%
#surface protein expression of NK- and T-cells
nk_prot=adata_nk.obsm['protein_expression_clr']

# %%
#surface protein expression of whole sample
prot=adata_sample.obsm['protein_expression_clr']

# %%
#NK- and T-cells in sample
nk_prot.shape
# Out:
# (57, 33)

# %%
#All cells in sample

prot.shape
# Out:
# (1734, 33)

# %%
#To exclude columns that contain only zeros, all cell types included

prot = pd.DataFrame(prot)
prot != 0
(prot != 0).any(axis=0)
prot.loc[:, (prot != 0).any(axis=0)]
prot = prot.loc[:, (prot != 0).any(axis=0)]

for col in prot:
    print(col)
# Out:
# CD19
# CD10
# CD20
# CD3
# CD2
# CD11b
# HLADR
# CD38
# CD11c
# CD7
# CD45
# CD33
# CD81
# CD73
# CD123
# CD14
# CD45RA
# CD45RO
# CD4
# CD8a
# CD197
# CD127
# CD56
# CD5
# CD15
# CD64
# CD117
# CD24
# CD44
# CD58
# CD66ace
# CD13
# CD34

# %%
#To exclude columns that contain only zeros from NK-only file

nk_prot = pd.DataFrame(nk_prot)
nk_prot != 0
(nk_prot != 0).any(axis=0)
nk_prot.loc[:, (nk_prot != 0).any(axis=0)]
nk_prot = nk_prot.loc[:, (nk_prot != 0).any(axis=0)]

for col in nk_prot:
    print(col)
# Out:
# CD19
# CD10
# CD20
# CD3
# CD2
# CD11b
# HLADR
# CD38
# CD11c
# CD7
# CD45
# CD33
# CD81
# CD73
# CD123
# CD14
# CD45RA
# CD45RO
# CD4
# CD8a
# CD197
# CD127
# CD56
# CD5
# CD15
# CD64
# CD117
# CD24
# CD44
# CD58
# CD66ace
# CD13
# CD34

# %%
#sorting by mean, all cell types

index_sort = prot.mean().sort_values().index
df_sorted_all = prot[index_sort]

# %%
#sorting by mean, NK- and T-cells

index_sort = nk_prot.mean().sort_values().index
df_sorted_nk = nk_prot[index_sort]

# %%
#All cell types

cells= len(prot)

print("In total:", cells, "cells in the sample" )

plt.figure(figsize=(30,10))
plt.ylim(0, 10)
a=sns.boxplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 1734 cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK- and T-cells in the sample" )

plt.figure(figsize=(30,10))
plt.ylim(0, 10)
a=sns.boxplot(data=df_sorted_nk,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK- and- T-cells", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 57 NK- and T-cells in the sample

# %%
#All cells

cells= len(prot)

print("In total:", cells, "cells in the sample" )

plt.figure(figsize=(40,20))
plt.ylim(0, 10)
a=sns.violinplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 1734 cells in the sample

# %%
#NK- and T-cells

cells= len(nk_prot)

print("In total:", cells, "NK- and T-cells in the sample" )

plt.figure(figsize=(40,20))
plt.ylim(0, 10)
a=sns.violinplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK- and T-cells", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 57 NK- and T-cells in the sample

# %%
#All cells
matrix1=prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix1, figsize=(20,20))
plt.title('All cell types', fontsize = 50) ;

# %%
#NK cells
matrix3=nk_prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix3, figsize=(20,20))
plt.title('NK- and T-cells', fontsize = 50) ;

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_sample.obs
b = prot

neurips_umap=pd.concat([a, b], axis=1)

adata_sample.obs=neurips_umap
adata_sample
# Out:
# AnnData object with n_obs × n_vars = 1734 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD19', 'CD10', 'CD20', 'CD3', 'CD2', 'CD11b', 'HLADR', 'CD38', 'CD11c', 'CD7', 'CD45', 'CD33', 'CD81', 'CD73', 'CD123', 'CD14', 'CD45RA', 'CD45RO', 'CD4', 'CD8a', 'CD197', 'CD127', 'CD56', 'CD5', 'CD15', 'CD64', 'CD117', 'CD24', 'CD44', 'CD58', 'CD66ace', 'CD13', 'CD34'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs
# Out:
#                        cell_type  n_genes  percent_mito  percent_ribo  \
# AAACCTGAGCGATGAC-1-105  leukemic     2117      0.032469      0.176369
# AAACCTGCAGACACTT-1-105  leukemic     2773      0.141606      0.212001
# AAACCTGGTCCATCCT-1-105  leukemic     1078      0.072713      0.320563
# AAACCTGTCCGGGTGT-1-105  leukemic     2432      0.025701      0.289294
# AAACGGGAGTGTACGG-1-105  leukemic     2690      0.057902      0.195208
# ...                          ...      ...           ...           ...
# TTTGTCAAGGATATAC-1-105  leukemic     2435      0.095709      0.313241
# TTTGTCAAGTACCGGA-1-105  leukemic     1976      0.047701      0.154011
# TTTGTCAAGTGGGATC-1-105  leukemic     1747      0.096144      0.230596
# TTTGTCACACAACGCC-1-105  leukemic     1314      0.128471      0.282369
# TTTGTCACATTCCTGC-1-105  leukemic     1386      0.119554      0.191007
#
#                         n_counts leiden_r2  leiden_r2_n_genes_MAD_diff  \
# AAACCTGAGCGATGAC-1-105    5205.0       NaN                         NaN
# AAACCTGCAGACACTT-1-105    8566.0       NaN                         NaN
# AAACCTGGTCCATCCT-1-105    2558.0       NaN                         NaN
# AAACCTGTCCGGGTGT-1-105    7743.0       NaN                         NaN
# AAACGGGAGTGTACGG-1-105    6511.0       NaN                         NaN
# ...                          ...       ...                         ...
# TTTGTCAAGGATATAC-1-105    7084.0       NaN                         NaN
# TTTGTCAAGTACCGGA-1-105    4675.0       NaN                         NaN
# TTTGTCAAGTGGGATC-1-105    3994.0       NaN                         NaN
# TTTGTCACACAACGCC-1-105    2989.0       NaN                         NaN
# TTTGTCACATTCCTGC-1-105    2869.0       NaN                         NaN
#
#                         leiden_r2_n_counts_MAD_diff  \
# AAACCTGAGCGATGAC-1-105                          NaN
# AAACCTGCAGACACTT-1-105                          NaN
# AAACCTGGTCCATCCT-1-105                          NaN
# AAACCTGTCCGGGTGT-1-105                          NaN
# AAACGGGAGTGTACGG-1-105                          NaN
# ...                                             ...
# TTTGTCAAGGATATAC-1-105                          NaN
# TTTGTCAAGTACCGGA-1-105                          NaN
# TTTGTCAAGTGGGATC-1-105                          NaN
# TTTGTCACACAACGCC-1-105                          NaN
# TTTGTCACATTCCTGC-1-105                          NaN
#
#                         leiden_r2_percent_mito_MAD_diff filter  ...       CD5  \
# AAACCTGAGCGATGAC-1-105                              NaN  False  ...  0.400091
# AAACCTGCAGACACTT-1-105                              NaN  False  ...  0.484992
# AAACCTGGTCCATCCT-1-105                              NaN  False  ...  0.362045
# AAACCTGTCCGGGTGT-1-105                              NaN  False  ...  0.317670
# AAACGGGAGTGTACGG-1-105                              NaN  False  ...  0.236048
# ...                                                 ...    ...  ...       ...
# TTTGTCAAGGATATAC-1-105                              NaN  False  ...  0.329719
# TTTGTCAAGTACCGGA-1-105                              NaN  False  ...  0.429116
# TTTGTCAAGTGGGATC-1-105                              NaN  False  ...  0.434599
# TTTGTCACACAACGCC-1-105                              NaN  False  ...  0.503943
# TTTGTCACATTCCTGC-1-105                              NaN  False  ...  0.167300
#
#                             CD15      CD64     CD117      CD24      CD44  \
# AAACCTGAGCGATGAC-1-105  0.961815  0.848149  0.423371  0.219922  3.237008
# AAACCTGCAGACACTT-1-105  0.929023  0.204546  1.701583  0.249754  3.380008
# AAACCTGGTCCATCCT-1-105  0.982956  0.525172  1.157295  0.226727  3.404001
# AAACCTGTCCGGGTGT-1-105  1.079904  1.041061  0.261701  0.344522  3.893583
# AAACGGGAGTGTACGG-1-105  1.116392  0.294386  0.648572  0.294386  3.032038
# ...                          ...       ...       ...       ...       ...
# TTTGTCAAGGATATAC-1-105  1.004190  0.105794  1.776664  0.154770  3.720504
# TTTGTCAAGTACCGGA-1-105  1.030537  0.329120  0.603336  0.293436  1.916549
# TTTGTCAAGTGGGATC-1-105  1.081997  0.240726  0.309612  0.166741  3.677760
# TTTGTCACACAACGCC-1-105  0.944903  0.179459  1.373350  0.179459  3.446900
# TTTGTCACATTCCTGC-1-105  1.058411  0.873870  0.265064  0.310581  3.560356
#
#                             CD58   CD66ace      CD13      CD34
# AAACCTGAGCGATGAC-1-105  1.491492  0.301141  0.100225  0.649007
# AAACCTGCAGACACTT-1-105  1.691180  0.584664  0.204546  2.349079
# AAACCTGGTCCATCCT-1-105  1.924716  0.546447  0.197318  0.546447
# AAACCTGTCCGGGTGT-1-105  1.639102  0.468926  0.232496  0.640492
# AAACGGGAGTGTACGG-1-105  2.813602  0.375970  0.205551  1.233770
# ...                          ...       ...       ...       ...
# TTTGTCAAGGATATAC-1-105  2.666617  0.329719  0.246065  0.638029
# TTTGTCAAGTACCGGA-1-105  2.448574  0.256430  0.178040  1.894813
# TTTGTCAAGTGGGATC-1-105  2.512886  0.434599  0.086842  1.911167
# TTTGTCACACAACGCC-1-105  2.319765  0.283386  0.331561  1.130353
# TTTGTCACATTCCTGC-1-105  1.856697  0.310581  0.058932  0.708995
#
# [1734 rows x 56 columns]

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_nk.obs
b = nk_prot

adata_nk_umap=pd.concat([a, b], axis=1)

adata_nk.obs=adata_nk_umap

adata_nk
# Out:
# AnnData object with n_obs × n_vars = 57 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD19', 'CD10', 'CD20', 'CD3', 'CD2', 'CD11b', 'HLADR', 'CD38', 'CD11c', 'CD7', 'CD45', 'CD33', 'CD81', 'CD73', 'CD123', 'CD14', 'CD45RA', 'CD45RO', 'CD4', 'CD8a', 'CD197', 'CD127', 'CD56', 'CD5', 'CD15', 'CD64', 'CD117', 'CD24', 'CD44', 'CD58', 'CD66ace', 'CD13', 'CD34'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs["CD56"]
# Out:
# AAGTCTGTCGCGATCG-1-105    0.463921
# ACGATGTCACAACGTT-1-105    1.077240
# ACGGGCTGTTAAAGTG-1-105    0.415643
# ACTTGTTGTCAAAGCG-1-105    1.002636
# ACTTTCATCGACCAGC-1-105    1.591302
# AGGTCCGGTCAGTGGA-1-105    0.443057
# AGTTGGTAGGCATTGG-1-105    1.002533
# ATCTACTAGTGATCGG-1-105    0.979335
# ATTGGTGTCAACACCA-1-105    0.351304
# CACCACTCACACCGAC-1-105    0.779290
# CACTCCATCTCAACTT-1-105    0.472847
# CAGCATAGTCCAGTGC-1-105    0.699195
# CAGTCCTAGGACGAAA-1-105    1.027338
# CATCCACAGAGGTACC-1-105    0.506659
# CCATGTCCAGCGAACA-1-105    0.565468
# CGAACATAGCAATATG-1-105    0.654197
# CGAACATAGTCACGCC-1-105    1.262883
# CGAATGTGTCTGCAAT-1-105    0.718152
# CGGCTAGAGCGCTTAT-1-105    0.503363
# CGGGTCAGTGCACCAC-1-105    1.281296
# CGGTTAATCACCCTCA-1-105    0.438187
# CGTGTCTTCAAGATCC-1-105    1.322424
# CTAACTTCAGCTATTG-1-105    1.174486
# CTAATGGGTTCACCTC-1-105    0.457909
# CTACATTGTCTCTCTG-1-105    0.493014
# CTACCCACAATCTACG-1-105    0.756119
# CTAGTGAAGGCTCATT-1-105    0.511729
# CTCAGAAAGCGTGAGT-1-105    1.122207
# GAATAAGTCAACACCA-1-105    0.987321
# GACCTGGCATCCAACA-1-105    0.444733
# GACGTTATCGCTTAGA-1-105    0.532058
# GAGCAGATCAATACCG-1-105    1.127643
# GCGACCAGTGTTGAGG-1-105    1.454512
# GGACAGACATTCACTT-1-105    0.341844
# GGCCGATCAGGTGCCT-1-105    0.487380
# GGGACCTTCACTTACT-1-105    0.681089
# GGTGCGTGTGCGAAAC-1-105    1.476924
# GGTGTTACAAGTACCT-1-105    0.478012
# GTCGGGTGTGCGCTTG-1-105    1.408220
# GTCTTCGTCGCGGATC-1-105    0.541569
# GTCTTCGTCTTCAACT-1-105    0.581490
# GTGAAGGAGACAGACC-1-105    0.409282
# GTGAAGGCAGGCGATA-1-105    0.474070
# GTTACAGGTGTGAAAT-1-105    1.344605
# GTTCGGGCATGAGCGA-1-105    0.326738
# GTTCTCGCATTAGCCA-1-105    0.557237
# GTTCTCGGTCATATGC-1-105    0.167038
# GTTTCTAGTGCAGTAG-1-105    0.463030
# TCGAGGCCAATCTACG-1-105    1.515588
# TCTCTAAGTCTGATTG-1-105    1.513723
# TCTTCGGTCATGTCCC-1-105    0.697378
# TGACGGCTCGGAGGTA-1-105    0.372123
# TGTGGTAGTCAGAGGT-1-105    0.385940
# TTCGGTCAGGTGACCA-1-105    0.329562
# TTCGGTCGTAAAGGAG-1-105    0.868820
# TTTATGCAGCCTATGT-1-105    0.808807
# TTTGCGCAGGCAGTCA-1-105    1.377141
# Name: CD56, dtype: float64

# %%
#NK-cell markers

markers=["CD56"]

# %%
#All cell types
sc.pl.umap(adata_sample, color= "cell_type", color_map= 'viridis')

# %%
#NK- and T-cells

sc.pl.umap(adata_nk, color = "cell_type", color_map = 'viridis')

# %%
#All cell types

sc.pl.umap(adata_sample, color= markers, color_map= 'viridis')

# %%
#NK- and T-cells

sc.pl.umap(adata_nk, color = markers, color_map = 'viridis')

# %%
#NK and T-cells

for column_name in markers:
    fig, ax =plt.subplots(1,2 ,tight_layout=True, figsize=(15, 5), sharex=True, sharey=True)
    fig.show()

    ax1 = sns.kdeplot(data=prot, x=column_name, multiple="stack", ax=ax[0]) ;
    ax2 = sns.kdeplot(data=nk_prot, x=column_name, color = "g", multiple="stack", ax=ax[1]) ;


    ax1.title.set_text('All cell types')    
    ax2.title.set_text('NK- and T-cells')
    
    plt.show()

# %%
#NK markers

plt.figure(figsize=(5,5))
a=sns.violinplot(data=nk_prot[markers],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=10)
plt.title("NK-cell markers", fontsize=20)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=10)

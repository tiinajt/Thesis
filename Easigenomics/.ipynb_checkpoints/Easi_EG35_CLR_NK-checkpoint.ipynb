# %% [markdown]
# # Easi, EG35, CLR normalized proteins

# %% [markdown]
# - Diagnosis: Aplastic anemia
# - BM blasts: 1%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
import umap

from ridgeplot import ridgeplot

import warnings

warnings.filterwarnings('ignore')

# %%
#protein data, all datasets

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_easi_norm.h5ad')

# %%
adata.obs['batch_group']
# Out:
# AAACCTGAGCCCTAAT-1-100    Easi
# AAACCTGCAAGCCGCT-1-100    Easi
# AAACCTGCACTGTCGG-1-100    Easi
# AAACCTGCAGACGCTC-1-100    Easi
# AAACCTGTCCTTAATC-1-100    Easi
#                           ...
# TTTGTCAGTACATCCA-1-158    Easi
# TTTGTCAGTAGGCATG-1-158    Easi
# TTTGTCAGTATGCTTG-1-158    Easi
# TTTGTCATCAAACCAC-1-158    Easi
# TTTGTCATCCATGAAC-1-158    Easi
# Name: batch_group, Length: 121340, dtype: category
# Categories (1, object): ['Easi']

# %%
adata_easi=adata[adata.obs['batch_group'] == 'Easi' ]

adata_easi
# Out:
# View of AnnData object with n_obs × n_vars = 121340 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_easi.obs['POOL'].unique().tolist()
# Out:
# ['EG35',
#  'EG38',
#  'EG58',
#  'EG39',
#  'EG4',
#  'EG48',
#  'EG23',
#  'EG36',
#  'EG61',
#  'EG3',
#  'EG12',
#  'EG46',
#  'EG9',
#  'EG43',
#  'EG56',
#  'EG42',
#  'EG49',
#  'EG37',
#  'EG57',
#  'EG24',
#  'EG11',
#  'EG14',
#  'EG55',
#  'EG28',
#  'EG52',
#  'EG33',
#  'EG10',
#  'EG32',
#  'EG59',
#  'EG16',
#  'EG63',
#  'EG15',
#  'EG21',
#  'EG26',
#  'EG13',
#  'EG53',
#  'EG51',
#  'EG2',
#  'EG40',
#  'EG62',
#  'EG31',
#  'EG7',
#  'EG8',
#  'EG29',
#  'EG41',
#  'EG47',
#  'EG1',
#  'EG6',
#  'EG34',
#  'EG30',
#  'EG60',
#  'EG44',
#  'EG27',
#  'EG22',
#  'EG54',
#  'EG45',
#  'EG5',
#  'EG50',
#  'EG25']

# %%
adata_easi.obs['new_cell_type'].unique().tolist()
# Out:
# ['NK',
#  'non-leukemic',
#  'preleukemic',
#  'non-leukemic?',
#  nan,
#  'leukemic',
#  'leukemic?',
#  'doublets?',
#  'unknown',
#  '0',
#  'preleukemic?']

# %%
#select sample from Easigenomics dataset

adata_sample=adata_easi[adata_easi.obs['POOL'] == 'EG35']

# %%
adata_sample.copy()
# Out:
# AnnData object with n_obs × n_vars = 2188 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs['new_cell_type'].unique().tolist()
# Out:
# ['NK', 'non-leukemic']

# %%
adata_sample.obs['POOL'].unique().tolist()
# Out:
# ['EG35']

# %%
#Select only NK- and T-cells (based on new_cell_type annotations)

adata_nk=adata_sample[adata_sample.obs['new_cell_type'] == 'NK' ]

# %%
adata_nk.copy()
# Out:
# AnnData object with n_obs × n_vars = 1226 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs['cell_type']
# Out:
# AAACCTGAGCCCTAAT-1-100    NKT
# AAACCTGCAGACGCTC-1-100    NKT
# AAACCTGTCCTTAATC-1-100    NKT
# AAACGGGGTCTCTCGT-1-100    NKT
# AAAGATGTCCAGTAGT-1-100    NKT
#                          ...
# TTTGCGCTCATGTAGC-1-100    NKT
# TTTGGTTCACGCATCG-1-100    NKT
# TTTGGTTTCCGAAGAG-1-100    NKT
# TTTGTCAAGAATTGTG-1-100    NKT
# TTTGTCACATTCACTT-1-100    NKT
# Name: cell_type, Length: 1226, dtype: category
# Categories (1, object): ['NKT']

# %%
#surface protein expression of NK- and T-cells
nk_prot=adata_nk.obsm['protein_expression_clr']

# %%
#surface protein expression of whole sample
prot=adata_sample.obsm['protein_expression_clr']

# %%
#NK- and T-cells in sample
nk_prot.shape
# Out:
# (1226, 33)

# %%
#All cells in sample

prot.shape
# Out:
# (2188, 33)

# %%
#To exclude columns that contain only zeros, all cell types included

prot = pd.DataFrame(prot)
prot != 0
(prot != 0).any(axis=0)
prot.loc[:, (prot != 0).any(axis=0)]
prot = prot.loc[:, (prot != 0).any(axis=0)]

for col in prot:
    print(col)
# Out:
# CD19
# CD10
# CD20
# CD3
# CD2
# CD11b
# HLADR
# CD38
# CD11c
# CD7
# CD45
# CD33
# CD81
# CD73
# CD123
# CD14
# CD45RA
# CD45RO
# CD4
# CD8a
# CD197
# CD127
# CD56
# CD5
# CD15
# CD64
# CD117
# CD24
# CD44
# CD58
# CD66ace
# CD13
# CD34

# %%
#To exclude columns that contain only zeros from NK-only file

nk_prot = pd.DataFrame(nk_prot)
nk_prot != 0
(nk_prot != 0).any(axis=0)
nk_prot.loc[:, (nk_prot != 0).any(axis=0)]
nk_prot = nk_prot.loc[:, (nk_prot != 0).any(axis=0)]

for col in nk_prot:
    print(col)
# Out:
# CD19
# CD10
# CD20
# CD3
# CD2
# CD11b
# HLADR
# CD38
# CD11c
# CD7
# CD45
# CD33
# CD81
# CD73
# CD123
# CD14
# CD45RA
# CD45RO
# CD4
# CD8a
# CD197
# CD127
# CD56
# CD5
# CD15
# CD64
# CD117
# CD24
# CD44
# CD58
# CD66ace
# CD13
# CD34

# %%
#sorting by mean, all cell types

index_sort = prot.mean().sort_values().index
df_sorted_all = prot[index_sort]

# %%
#sorting by mean, NK- and T-cells

index_sort = nk_prot.mean().sort_values().index
df_sorted_nk = nk_prot[index_sort]

# %%
#All cell types

cells= len(prot)

print("In total:", cells, "cells in the sample" )

plt.figure(figsize=(30,10))
plt.ylim(0,10)
a=sns.boxplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 2188 cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK- and T-cells in the sample" )

plt.figure(figsize=(30,10))
plt.ylim(0, 10)
a=sns.boxplot(data=df_sorted_nk,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK- and- T-cells", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 1226 NK- and T-cells in the sample

# %%
#All cells

cells= len(prot)

print("In total:", cells, "cells in the sample" )

plt.figure(figsize=(40,20))
plt.ylim(0, 10)
a=sns.violinplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("All cell types", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 2188 cells in the sample

# %%
#NK cells

cells= len(nk_prot)

print("In total:", cells, "NK- and T-cells in the sample" )

plt.figure(figsize=(40,20))
plt.ylim(0, 10)
a=sns.violinplot(data=df_sorted_all,  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK- and T-cells", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
# Out:
# In total: 1226 NK- and T-cells in the sample

# %%
#All cells
matrix1=prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix1, figsize=(20,20))
plt.title('All cell types', fontsize = 50) ;

# %%
#NK cells
matrix3=nk_prot.corr(method='pearson', min_periods=1)
sns.clustermap(matrix3, figsize=(20,20))
plt.title('NK- and T-cells', fontsize = 50) ;

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_sample.obs
b = prot

neurips_umap=pd.concat([a, b], axis=1)

adata_sample.obs=neurips_umap
adata_sample
# Out:
# AnnData object with n_obs × n_vars = 2188 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD19', 'CD10', 'CD20', 'CD3', 'CD2', 'CD11b', 'HLADR', 'CD38', 'CD11c', 'CD7', 'CD45', 'CD33', 'CD81', 'CD73', 'CD123', 'CD14', 'CD45RA', 'CD45RO', 'CD4', 'CD8a', 'CD197', 'CD127', 'CD56', 'CD5', 'CD15', 'CD64', 'CD117', 'CD24', 'CD44', 'CD58', 'CD66ace', 'CD13', 'CD34'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_sample.obs
# Out:
#                            cell_type  n_genes  percent_mito  percent_ribo  \
# AAACCTGAGCCCTAAT-1-100           NKT     1104      0.072933      0.140216
# AAACCTGCAAGCCGCT-1-100  non-leukemic     2954      0.000086      0.362812
# AAACCTGCACTGTCGG-1-100  non-leukemic     1767      0.005680      0.165269
# AAACCTGCAGACGCTC-1-100           NKT     1928      0.035144      0.433632
# AAACCTGTCCTTAATC-1-100           NKT     1750      0.029976      0.421151
# ...                              ...      ...           ...           ...
# TTTGGTTCACGCATCG-1-100           NKT     2347      0.037616      0.232698
# TTTGGTTGTATAATGG-1-100  non-leukemic     3605      0.053122      0.195860
# TTTGGTTTCCGAAGAG-1-100           NKT     2857      0.058289      0.283304
# TTTGTCAAGAATTGTG-1-100           NKT     1718      0.039038      0.256813
# TTTGTCACATTCACTT-1-100           NKT     2070      0.017926      0.314615
#
#                         n_counts leiden_r2  leiden_r2_n_genes_MAD_diff  \
# AAACCTGAGCCCTAAT-1-100    1947.0       NaN                         NaN
# AAACCTGCAAGCCGCT-1-100   11579.0       NaN                         NaN
# AAACCTGCACTGTCGG-1-100    3697.0       NaN                         NaN
# AAACCTGCAGACGCTC-1-100    7142.0       NaN                         NaN
# AAACCTGTCCTTAATC-1-100    5371.0       NaN                         NaN
# ...                          ...       ...                         ...
# TTTGGTTCACGCATCG-1-100    6141.0       NaN                         NaN
# TTTGGTTGTATAATGG-1-100   12029.0       NaN                         NaN
# TTTGGTTTCCGAAGAG-1-100    8475.0       NaN                         NaN
# TTTGTCAAGAATTGTG-1-100    4073.0       NaN                         NaN
# TTTGTCACATTCACTT-1-100    5467.0       NaN                         NaN
#
#                         leiden_r2_n_counts_MAD_diff  \
# AAACCTGAGCCCTAAT-1-100                          NaN
# AAACCTGCAAGCCGCT-1-100                          NaN
# AAACCTGCACTGTCGG-1-100                          NaN
# AAACCTGCAGACGCTC-1-100                          NaN
# AAACCTGTCCTTAATC-1-100                          NaN
# ...                                             ...
# TTTGGTTCACGCATCG-1-100                          NaN
# TTTGGTTGTATAATGG-1-100                          NaN
# TTTGGTTTCCGAAGAG-1-100                          NaN
# TTTGTCAAGAATTGTG-1-100                          NaN
# TTTGTCACATTCACTT-1-100                          NaN
#
#                         leiden_r2_percent_mito_MAD_diff filter  ...       CD5  \
# AAACCTGAGCCCTAAT-1-100                              NaN  False  ...  0.507486
# AAACCTGCAAGCCGCT-1-100                              NaN  False  ...  0.625459
# AAACCTGCACTGTCGG-1-100                              NaN  False  ...  0.611467
# AAACCTGCAGACGCTC-1-100                              NaN  False  ...  1.135601
# AAACCTGTCCTTAATC-1-100                              NaN  False  ...  1.088464
# ...                                                 ...    ...  ...       ...
# TTTGGTTCACGCATCG-1-100                              NaN  False  ...  0.385929
# TTTGGTTGTATAATGG-1-100                              NaN  False  ...  0.480730
# TTTGGTTTCCGAAGAG-1-100                              NaN  False  ...  0.582245
# TTTGTCAAGAATTGTG-1-100                              NaN  False  ...  0.743550
# TTTGTCACATTCACTT-1-100                              NaN  False  ...  0.922601
#
#                             CD15      CD64     CD117      CD24      CD44  \
# AAACCTGAGCCCTAAT-1-100  1.108744  0.640390  0.418344  0.285596  2.054122
# AAACCTGCAAGCCGCT-1-100  1.584069  0.360852  0.479715  0.309047  1.905325
# AAACCTGCACTGTCGG-1-100  0.803020  0.831660  0.230656  0.256078  3.010364
# AAACCTGCAGACGCTC-1-100  1.039049  0.164727  0.406398  0.382255  2.121294
# AAACCTGTCCTTAATC-1-100  0.838606  0.422162  0.363054  0.267275  2.193482
# ...                          ...       ...       ...       ...       ...
# TTTGGTTCACGCATCG-1-100  1.007595  0.434013  0.135332  0.434013  2.589113
# TTTGGTTGTATAATGG-1-100  0.863598  0.242425  0.344655  0.522264  2.321431
# TTTGGTTTCCGAAGAG-1-100  0.874545  0.167478  0.167478  0.396213  3.075601
# TTTGTCAAGAATTGTG-1-100  1.110879  0.292300  0.518204  0.323490  2.391558
# TTTGTCACATTCACTT-1-100  0.887564  0.230997  0.297489  0.329148  2.816681
#
#                             CD58   CD66ace      CD13      CD34
# AAACCTGAGCCCTAAT-1-100  0.589328  0.779578  0.285596  0.779578
# AAACCTGCAAGCCGCT-1-100  1.033409  1.546218  0.335285  0.850094
# AAACCTGCACTGTCGG-1-100  0.280870  0.557241  0.439080  0.628908
# AAACCTGCAGACGCTC-1-100  0.429972  0.560815  0.194650  0.796464
# AAACCTGTCCTTAATC-1-100  0.696512  0.556246  0.123380  0.780162
# ...                          ...       ...       ...       ...
# TTTGGTTCACGCATCG-1-100  0.644866  0.644866  0.226023  0.818909
# TTTGGTTGTATAATGG-1-100  0.707424  0.740671  0.344655  0.834254
# TTTGGTTTCCGAAGAG-1-100  0.375555  0.455744  0.192854  0.767648
# TTTGTCAAGAATTGTG-1-100  0.439348  0.492603  0.260105  0.567519
# TTTGTCACATTCACTT-1-100  0.551732  0.794195  0.159767  0.600416
#
# [2188 rows x 56 columns]

# %%
#Adding protein data to anndata file for UMAPs, all cell types

a = adata_nk.obs
b = nk_prot

adata_nk_umap=pd.concat([a, b], axis=1)

adata_nk.obs=adata_nk_umap

adata_nk
# Out:
# AnnData object with n_obs × n_vars = 1226 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group', 'CD19', 'CD10', 'CD20', 'CD3', 'CD2', 'CD11b', 'HLADR', 'CD38', 'CD11c', 'CD7', 'CD45', 'CD33', 'CD81', 'CD73', 'CD123', 'CD14', 'CD45RA', 'CD45RO', 'CD4', 'CD8a', 'CD197', 'CD127', 'CD56', 'CD5', 'CD15', 'CD64', 'CD117', 'CD24', 'CD44', 'CD58', 'CD66ace', 'CD13', 'CD34'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
adata_nk.obs["CD56"]
# Out:
# AAACCTGAGCCCTAAT-1-100    0.664975
# AAACCTGCAGACGCTC-1-100    0.560815
# AAACCTGTCCTTAATC-1-100    0.800025
# AAACGGGGTCTCTCGT-1-100    0.421871
# AAAGATGTCCAGTAGT-1-100    0.731533
#                             ...
# TTTGCGCTCATGTAGC-1-100    0.507309
# TTTGGTTCACGCATCG-1-100    0.910434
# TTTGGTTTCCGAAGAG-1-100    0.332913
# TTTGTCAAGAATTGTG-1-100    0.591293
# TTTGTCACATTCACTT-1-100    0.774428
# Name: CD56, Length: 1226, dtype: float64

# %%
#NK-cell markers

markers=["CD56"]

# %%
#All cell types
sc.pl.umap(adata_sample, color= "cell_type", color_map= 'viridis')

# %%
#NK- and T-cells

sc.pl.umap(adata_nk, color = "cell_type", color_map = 'viridis')

# %%
#All cell types

sc.pl.umap(adata_sample, color= markers, color_map= 'viridis')

# %%
#NK- and T-cells

sc.pl.umap(adata_nk, color = markers, color_map = 'viridis')

# %%
#NK and T-cells

for column_name in markers:
    fig, ax =plt.subplots(1,2 ,tight_layout=True, figsize=(15, 5), sharex=True)
    fig.show()

    ax1 = sns.kdeplot(data=prot, x=column_name, multiple="stack", ax=ax[0]) ;
    ax2 = sns.kdeplot(data=nk_prot, x=column_name, color = "g", multiple="stack", ax=ax[1]) ;


    ax1.title.set_text('All cell types')    
    ax2.title.set_text('NK- and T-cells')
    
    plt.show()

# %%
#NK markers

plt.figure(figsize=(20,10))
a=sns.violinplot(data=nk_prot[markers],  fliersize=0)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)
plt.title("NK-cell markers", fontsize=30)

a.set_xticklabels(a.get_xticklabels(),rotation=45) 
a.tick_params(axis='x', labelsize=20)

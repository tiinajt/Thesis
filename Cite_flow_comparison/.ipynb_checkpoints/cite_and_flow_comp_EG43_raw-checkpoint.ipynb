# %% [markdown]
# # EG43 CITE-seq and flow cytometry comparisons

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import anndata as ad
import scvi
import scanpy as sc
from ridgeplot import ridgeplot

import sklearn.mixture

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# Sample used in this notebook is EG40.
#
# ### Sample information:
# - AML
# - diagnosis
# - 85% of bonemarrow cells are blasts

# %% [markdown]
# ## Preparing files

# %%
#raw protein data, all datasets, raw + CLR and DSB normalized

adata = sc.read_h5ad('/Users/tiinatuononen/Desktop/Thesis/Project/data/adata_easi_norm.h5ad')

adata.shape
# Out:
# (121340, 8051)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 121340 × 8051
#     obs: 'cell_type', 'n_genes', 'percent_mito', 'percent_ribo', 'n_counts', 'leiden_r2', 'leiden_r2_n_genes_MAD_diff', 'leiden_r2_n_counts_MAD_diff', 'leiden_r2_percent_mito_MAD_diff', 'filter', 'model_group', 'BATCH', 'POOL', 'SAMPLE_SET', 'SAMPLE_TYPE', 'SAMPLE_TISSUE', 'DIAGNOSIS', 'SUBTYPE', 'STATUS', 'eg_code', 'leiden_r1', 'new_cell_type', 'batch_group'
#     uns: 'neighbors', 'new_cell_type_colors', 'umap'
#     obsm: 'X_pca', 'X_totalVI', 'X_umap', 'protein_expression', 'protein_expression_clr', 'protein_expression_dsb'
#     obsp: 'connectivities', 'distances'

# %%
#select sample
adata_sample=adata[adata.obs['eg_code'] == 'EG43']

# %%
#selecting only leukemic cells

eg_blasts=adata_sample[adata_sample.obs['new_cell_type'] == 'leukemic']

eg_blasts.obs['new_cell_type']
# Out:
# AAACCTGAGAAGGTTT-1-113    leukemic
# AAACCTGAGATCGGGT-1-113    leukemic
# AAACCTGAGTAGGCCA-1-113    leukemic
# AAACCTGCAGTATGCT-1-113    leukemic
# AAACCTGGTAGCTTGT-1-113    leukemic
#                             ...
# TTTGTCAGTCGACTAT-1-113    leukemic
# TTTGTCAGTCTAACGT-1-113    leukemic
# TTTGTCATCGATAGAA-1-113    leukemic
# TTTGTCATCTAACCGA-1-113    leukemic
# TTTGTCATCTCGAGTA-1-113    leukemic
# Name: new_cell_type, Length: 2208, dtype: category
# Categories (1, object): ['leukemic']

# %%
#select DSB normalized protein counts

prot=eg_blasts.obsm['protein_expression']

prot
# Out:
#                         CD86  CD274  CD270  CD155  CD112  CD47  CD48  CD40  \
# AAACCTGAGAAGGTTT-1-113     0      0      0      0      0     0     0     0
# AAACCTGAGATCGGGT-1-113     0      0      0      0      0     0     0     0
# AAACCTGAGTAGGCCA-1-113     0      0      0      0      0     0     0     0
# AAACCTGCAGTATGCT-1-113     0      0      0      0      0     0     0     0
# AAACCTGGTAGCTTGT-1-113     0      0      0      0      0     0     0     0
# ...                      ...    ...    ...    ...    ...   ...   ...   ...
# TTTGTCAGTCGACTAT-1-113     0      0      0      0      0     0     0     0
# TTTGTCAGTCTAACGT-1-113     0      0      0      0      0     0     0     0
# TTTGTCATCGATAGAA-1-113     0      0      0      0      0     0     0     0
# TTTGTCATCTAACCGA-1-113     0      0      0      0      0     0     0     0
# TTTGTCATCTCGAGTA-1-113     0      0      0      0      0     0     0     0
#
#                         CD154  CD52  ...  CD101  CD88  CD224  CD197  CD34  \
# AAACCTGAGAAGGTTT-1-113      0     0  ...      0     0      0      0    11
# AAACCTGAGATCGGGT-1-113      0     0  ...      0     0      0      7     8
# AAACCTGAGTAGGCCA-1-113      0     0  ...      0     0      0      0    10
# AAACCTGCAGTATGCT-1-113      0     0  ...      0     0      0      3     6
# AAACCTGGTAGCTTGT-1-113      0     0  ...      0     0      0      2     5
# ...                       ...   ...  ...    ...   ...    ...    ...   ...
# TTTGTCAGTCGACTAT-1-113      0     0  ...      0     0      0      6     6
# TTTGTCAGTCTAACGT-1-113      0     0  ...      0     0      0      2     6
# TTTGTCATCGATAGAA-1-113      0     0  ...      0     0      0      4    10
# TTTGTCATCTAACCGA-1-113      0     0  ...      0     0      0     12    19
# TTTGTCATCTCGAGTA-1-113      0     0  ...      0     0      0      2     8
#
#                         CD10  CD90  CD15  CD117  CD66ace
# AAACCTGAGAAGGTTT-1-113     8     0    20      3        4
# AAACCTGAGATCGGGT-1-113    12     0    15      1        9
# AAACCTGAGTAGGCCA-1-113     3     0    21      2        6
# AAACCTGCAGTATGCT-1-113    10     0    15      4        6
# AAACCTGGTAGCTTGT-1-113    12     0     5      9        5
# ...                      ...   ...   ...    ...      ...
# TTTGTCAGTCGACTAT-1-113    13     0    13      3        5
# TTTGTCAGTCTAACGT-1-113    15     0    12      3        1
# TTTGTCATCGATAGAA-1-113     7     0    18      2        3
# TTTGTCATCTAACCGA-1-113    23     0    56     11       12
# TTTGTCATCTCGAGTA-1-113    11     0    10      6       12
#
# [2208 rows x 141 columns]

# %%
#convert excel to csv (flow data)

#read_file = pd.read_excel (r'/Users/tiinatuononen/Desktop/Thesis/Project/data/flow.xlsx')
#read_file.to_csv (r'/Users/tiinatuononen/Desktop/Thesis/Project/data/flow.csv', index = None, header=True)

# %%
#get flow data

flow= pd.read_csv('/Users/tiinatuononen/Desktop/Thesis/Project/data/flow.csv')

# %% [markdown]
# ### Depending on used dataset, celltype annotations are varying (made by different groups). "new_cell_types" is made based on these, it is a "standardized" version of cell type annotations.

# %%
#Cell types offered by new_cell_type

adata.obs['new_cell_type'].unique().tolist()
# Out:
# ['NK',
#  'non-leukemic',
#  'preleukemic',
#  'non-leukemic?',
#  nan,
#  'leukemic',
#  'leukemic?',
#  'doublets?',
#  'unknown',
#  '0',
#  'preleukemic?']

# %%
#cell type annotations offered by cell_type

adata.obs['cell_type'].unique().tolist()
# Out:
# ['NKT',
#  'non-leukemic',
#  'preleukemic',
#  'non-leukemic?',
#  nan,
#  'leukemic',
#  'leukemic?',
#  'doublets?',
#  'unknown',
#  '0',
#  'preleukemic?']

# %%
#flow results for selected sample

egflow=flow[flow['EG_code'] == 'EG43'].dropna(axis=1)

egflow
# Out:
#    EG_code  CD2  CD4   CD7  CD56  CD99  CD123  HLA-DR
# 21    EG43  1.0  1.0  0.71  0.79   1.0    1.0     1.0

# %%
#drop EG_code

egflow=egflow.drop("EG_code", axis=1)

egflow
# Out:
#     CD2  CD4   CD7  CD56  CD99  CD123  HLA-DR
# 21  1.0  1.0  0.71  0.79   1.0    1.0     1.0

# %%
df=egflow * 100 #multiplied by 100 to get percentages

df1=df.T

df1.plot.bar(xlabel="Marker", ylabel="% of blasts",
            figsize= (15,8),
           fontsize="large") ;

plt.title('Blast phenotype', fontsize=20) ;

# %%
egflow=egflow*100

# %%
flow_markers=egflow.columns
flow_markers
# Out:
# Index(['CD2', 'CD4', 'CD7', 'CD56', 'CD99', 'CD123', 'HLA-DR'], dtype='object')

# %%
#Selecting common markers between flow and cite-seq

listOfMarkers=flow_markers
column_names=list()    #list including the common markers

for x in listOfMarkers:
    if x in prot.columns:
        print(x, "Yes")
        column_names.append(x)
    else:
        print(x, "No") 
        
print(column_names)
# Out:
# CD2 Yes
# CD4 Yes
# CD7 Yes
# CD56 Yes
# CD99 No
# CD123 Yes
# HLA-DR Yes
# ['CD2', 'CD4', 'CD7', 'CD56', 'CD123', 'HLA-DR']

# %%
prot.shape
# Out:
# (2208, 141)

# %%
#model
gmm = sklearn.mixture.GaussianMixture(n_components = 2,
                                      covariance_type = "full",
                                      random_state = 42
                                        )
#data

data=prot
n_cells=len(prot)
egflow=egflow
for column_name in column_names:
    fig, ax =plt.subplots(1,2,tight_layout=True, figsize=(15, 5))
    fig.show()
    
    x= data[column_name]
    x=x.values.reshape(-1, 1)
    gmm.fit(x)
    labels = gmm.predict(x)
    
    x0 = data[column_name].reset_index(drop=True)[labels == 0].mean()
    x1 = data[column_name].reset_index(drop=True)[labels == 1].mean()
    if x0 < x1:
        labels = (~(labels == 1)).astype(int)
    
    ax1 = sns.kdeplot(data=data, x=column_name, hue=labels, multiple="stack", ax=ax[0]) ;
    ax1.title.set_text('GMM')
       
    #Calculate zeros
    n_zeros = np.count_nonzero(labels==0)
    result_zeros=(n_zeros/n_cells * 100)
    #Calculate ones
    n_ones=np.count_nonzero(labels)
    result_ones=(n_ones/n_cells * 100)
    #Dataframes
    all_data = {"GMM":[result_ones],
        "Flow": egflow[column_name],
        };

    all_data= pd.DataFrame(data=all_data);
    
    ax2=all_data.plot.bar(rot=15, title=column_name,ax=ax[1]);
    ax2.title.set_text('Proportions')
    
    print("Percentage of positive cells, based on GMM:", result_ones)
    
    plt.show()
# Out:
# Percentage of positive cells, based on GMM: 77.62681159420289
# Percentage of positive cells, based on GMM: 80.16304347826086
# Percentage of positive cells, based on GMM: 91.21376811594203
# Percentage of positive cells, based on GMM: 62.59057971014492
# Percentage of positive cells, based on GMM: 80.48007246376811
# Percentage of positive cells, based on GMM: 82.29166666666666
